# %%
# !python --version
# Out:
# Python 3.11.12

# %% [markdown]
# # AHoJ-DB Užklausa
#
# https://apoholo.cz/db/search?pdb_ids=&uniprot_ids=&ligands=ADP%20ATP%20AMP%20GTP%20GDP%20FAD%20NAD%20NAP%20NDP%20HEM%20HEC%20PLM%20OLA%20MYR%20CIT%20CLA%20CHL%20BCL%20BCB&res_threshold=1.5
#
# Rezoliucija: 1.5 Angstromų.
# Ligandai: ADP ATP AMP GTP GDP FAD NAD NAP NDP HEM HEC PLM OLA MYR CIT CLA CHL BCL BCB

# %% [markdown]
# # Duomenų filtravimas

# %%
import pandas as pd
import re

df = pd.read_csv('ahojdb_search_result.csv')
filtered_df = df[df[' num_apo_sites'] > 0]
filtered_df = filtered_df[filtered_df[' num_holo_sites'] > 0]
for index, row in filtered_df.iterrows():
    filtered_df.replace(row[' target_uniprot_ids'], re.sub('\\s.*', '', row[' target_uniprot_ids'].strip()), inplace=True)
filtered_df = filtered_df.drop_duplicates(subset=[' target_uniprot_ids'])
filtered_df.to_csv('filtered_ahojdb_search_result.csv')

# %% [markdown]
# # Paruošiame Apo and Holo porų duomenis

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

records = []

def parse_row(tr, prefix):
    cols = tr.find_all('td')
    d = {
        f'{prefix}_structure': cols[0].get_text(strip=True),
        f'{prefix}_aligned_chain': cols[1].get_text(strip=True),
        f'{prefix}_resolution': cols[2].get_text(strip=True),
        f'{prefix}_MBR': cols[3].get_text(strip=True),
        f'{prefix}_disorder_percent': cols[4].get_text(strip=True),
        f'{prefix}_RMSD': float(cols[5].get_text(strip=True)),
        f'{prefix}_pocket_RMSD': cols[6].get_text(strip=True),
        f'{prefix}_TM_score': cols[7].get_text(strip=True),
        f'{prefix}_SASA': cols[8].get_text(strip=True),
        f'{prefix}_volume': cols[9].get_text(strip=True),
    }
    if prefix == 'holo':
        d[f'{prefix}_ligands'] = cols[10].get_text(strip=True)
    return d

for entry_key in filtered_df['entry_key']:
    url = f'http://apoholo.cz/db/entry/{entry_key}'
    html = requests.get(url).content.decode()
    soup = BeautifulSoup(html, 'html.parser')

    # --- APO table ---
    apo_table = soup.find('span', class_='label', string='Found APO Sites:') \
                    .find_next('table')
    apo_rows = apo_table.find('tbody').find_all('tr')
    apo_records = [parse_row(r, 'apo') for r in apo_rows]
    apo_rmsd_vals = [r['apo_RMSD'] for r in apo_records]

    # --- HOLO table ---
    holo_table = soup.find('span', class_='label', string='Found HOLO Sites:') \
                     .find_next('table')
    holo_rows = holo_table.find('tbody').find_all('tr')
    holo_records = [parse_row(r, 'holo') for r in holo_rows]
    holo_rmsd_vals = [r['holo_RMSD'] for r in holo_records]

    # --- Compute per‐entry stats ---
    stats = {
        'entry_key': entry_key,
        'apo_count': len(apo_rmsd_vals),
        'apo_RMSD_min': min(apo_rmsd_vals),
        'apo_RMSD_max': max(apo_rmsd_vals),
        'apo_RMSD_avg': sum(apo_rmsd_vals) / len(apo_rmsd_vals),
        'holo_count': len(holo_rmsd_vals),
        'holo_RMSD_min': min(holo_rmsd_vals),
        'holo_RMSD_max': max(holo_rmsd_vals),
        'holo_RMSD_avg': sum(holo_rmsd_vals) / len(holo_rmsd_vals),
    }

    first_apo = apo_records[0]
    first_holo = holo_records[0]
    uniprot = filtered_df.loc[
        filtered_df['entry_key'] == entry_key, ' target_uniprot_ids'
    ].iloc[0]

    rec = {
        **stats,
        **first_apo,
        **first_holo,
        'uniprot_id': uniprot
    }
    records.append(rec)

df = pd.DataFrame(records)

print(df.head())

print("=== GLOBAL APO RMSD ===")
print("  min:", df['apo_RMSD_min'].min())
print("  max:", df['apo_RMSD_max'].max())
print("  avg:", df['apo_RMSD_avg'].mean())
print("  total count:", df['apo_count'].sum())

print("=== GLOBAL HOLO RMSD ===")
print("  min:", df['holo_RMSD_min'].min())
print("  max:", df['holo_RMSD_max'].max())
print("  avg:", df['holo_RMSD_avg'].mean())
print("  total count:", df['holo_count'].sum())
# Out:
#          entry_key  apo_count  apo_RMSD_min  apo_RMSD_max  apo_RMSD_avg  \
# 0   1bab-B-HEM-147          2          0.96          1.23      1.095000
# 1  1byq-A-ADP-2001         19          0.84          1.76      1.615789
# 2   1d2u-A-HEM-185          1          0.86          0.86      0.860000
# 3  1dgf-A-NDP-4000         11          0.23          0.38      0.302727
# 4  1e6u-A-NAP-1317          1          0.46          0.46      0.460000
#
#    holo_count  holo_RMSD_min  holo_RMSD_max  holo_RMSD_avg apo_structure  ...  \
# 0         650           0.06           1.97       0.634169        5vmm/B  ...
# 1         368           0.72           2.55       1.449891        5j80/A  ...
# 2          48           0.19           1.06       0.689583        2ofm/X  ...
# 3          30           0.18           0.49       0.326667        1dgh/D  ...
# 4           6           0.10           0.45       0.280000        1gfs/A  ...
#
#   holo_resolution holo_MBR holo_disorder_percent holo_RMSD  holo_pocket_RMSD  \
# 0            1.07       20                     0      0.37              0.32
# 1            1.17       14                     0      1.66              1.98
# 2            0.85       22                     0      0.64              0.31
# 3             1.8       20                     0      0.25              0.79
# 4             1.5       26                     0      0.22              0.47
#
#   holo_TM_score holo_SASA holo_volume holo_ligands uniprot_id
# 0          0.99    720.21       635.0     K HEM XE     P68871
# 1          0.92     293.6       156.0          NL8     P07900
# 2          0.99    739.43       733.0          HEM     Q94734
# 3           1.0    785.73       553.0          HEM     P04040
# 4           1.0   1012.33       286.0      NAP SO4     P32055
#
# [5 rows x 31 columns]
# === GLOBAL APO RMSD ===
#   min: 0.08
#   max: 7.21
#   avg: 1.1648301044789164
#   total count: 2972
# === GLOBAL HOLO RMSD ===
#   min: 0.05
#   max: 6.84
#   avg: 0.8027285303178909
#   total count: 9496

# %%
df.to_csv('apo_holo_pairs_with_RMSD_info.csv')

# %% [markdown]
# # Surenkame holo konformacijų struktūrų jonų ir ligandų informaciją.

# %%
import requests
import pandas as pd

# Function to fetch PDB information using RCSB API
def fetch_pdb_info(pdb_id):
    url = f'https://data.rcsb.org/rest/v1/core/entry/{pdb_id[:4]}'
    response = requests.get(url)

    if response.status_code != 200:
        return {
            "PDB_ID": pdb_id,
            "Status": "Failed to fetch",
            "Conformers": None,
            "Ligands": None,
            "Ions": None,
            "Other_Ligands": None,
            "Other_Ions": None
        }

    data = response.json()

    if(pdb_id == '1kmv'):
        print('data', data)

    conformers = data.get('rcsb_entry_info', {}).get('polymer_entity_count_protein', None)

    # Define known ligands and ions
    known_ligands = {"BCB", "BCL", "CHL", "CLA", "CIT", "MYR", "OLA", "PLM",
                     "HEC", "HEM", "NDP", "NAP", "NAD", "FAD", "GDP", "GTP",
                     "AMP", "ATP", "ADP"}
    known_ions = {"MG", "ZN", "CL", "CA", "NA", "MN", "K", "FE", "CU", "CO"}

    ligands = []
    ions = []
    other_ligands = []
    other_ions = []

    # Extract ligands and ions from nonpolymer_entities
    nonpolymer_entities = data.get('nonpolymer_entities', [])

    for entity in nonpolymer_entities:
        chem_comp_name = entity.get('chem_comp', {}).get('id', '')

        if chem_comp_name in known_ligands:
            ligands.append(chem_comp_name)

        elif chem_comp_name in known_ions:
            ions.append(chem_comp_name)

        else:
            chem_comp_type = entity.get('rcsb_nonpolymer_entity', {}).get('chem_comp_type', '').upper()

            if 'ION' in chem_comp_type:
                other_ions.append(chem_comp_name)

            else:
                other_ligands.append(chem_comp_name)

    bound_components = data.get('rcsb_entry_info', {}).get('nonpolymer_bound_components', [])

    for component in bound_components:
        if component not in ligands and component not in ions:

            if component in known_ligands:
                ligands.append(component)

            elif component in known_ions:
                ions.append(component)

            else:
                other_ligands.append(component)

    return {
        "PDB_ID": pdb_id,
        "Status": "Success",
        "Conformers": conformers,
        "Ligands": ligands,
        "Ions": ions,
        "Other_Ligands": other_ligands,
        "Other_Ions": other_ions
    }

df = pd.read_csv('apo_holo_pairs_with_RMSD_info.csv')
results = []

for index, row in df.iterrows():
    holo_pdb = row['holo_structure'][:4]
    apo_pdb = row['apo_structure'][:4]
    print(f"Fetching information for Holo PDB ID: {holo_pdb}")
    result = fetch_pdb_info(holo_pdb)
    result["Apo_PDB_ID"] = apo_pdb
    result["Holo_PDB_ID"] = holo_pdb
    results.append(result)

results_df = pd.DataFrame(results)

# Filter results: keep only rows where Other_Ligands are empty
filtered_results_df = results_df[(results_df['Other_Ligands'].apply(len) == 0)]

filtered_results_df = filtered_results_df[["Apo_PDB_ID", "Holo_PDB_ID", "Ligands", "Ions"]]

# Display the filtered results
print(filtered_results_df)
filtered_results_df.to_csv("apo_holo_pair_ligand_and_ion_data.csv", index=False)
# Out:
# Fetching information for Holo PDB ID: 2w72
# Fetching information for Holo PDB ID: 6tn5
# Fetching information for Holo PDB ID: 1x8q
# Fetching information for Holo PDB ID: 1dgg
# Fetching information for Holo PDB ID: 1e7s
# Fetching information for Holo PDB ID: 3ip0
# Fetching information for Holo PDB ID: 4etp
# Fetching information for Holo PDB ID: 1xgk
# Fetching information for Holo PDB ID: 1kmv
# data {'audit_author': [{'name': 'Klon, A.E.', 'pdbx_ordinal': 1}, {'name': 'Heroux, A.', 'pdbx_ordinal': 2}, {'name': 'Ross, L.J.', 'pdbx_ordinal': 3}, {'name': 'Pathak, V.', 'pdbx_ordinal': 4}, {'name': 'Johnson, C.A.', 'pdbx_ordinal': 5}, {'name': 'Piper, J.R.', 'pdbx_ordinal': 6}, {'name': 'Borhani, D.W.', 'pdbx_ordinal': 7}], 'cell': {'angle_alpha': 90.0, 'angle_beta': 90.0, 'angle_gamma': 90.0, 'length_a': 41.3, 'length_b': 54.99, 'length_c': 82.68, 'zpdb': 4}, 'citation': [{'country': 'UK', 'id': 'primary', 'journal_abbrev': 'J.Mol.Biol.', 'journal_id_astm': 'JMOBAK', 'journal_id_csd': '0070', 'journal_id_issn': '0022-2836', 'journal_volume': '320', 'page_first': '677', 'page_last': '693', 'pdbx_database_id_doi': '10.1016/S0022-2836(02)00469-2', 'pdbx_database_id_pub_med': 12096917, 'rcsb_authors': ['Klon, A.E.', 'Heroux, A.', 'Ross, L.J.', 'Pathak, V.', 'Johnson, C.A.', 'Piper, J.R.', 'Borhani, D.W.'], 'rcsb_is_primary': 'Y', 'rcsb_journal_abbrev': 'J Mol Biology', 'title': 'Atomic structures of human dihydrofolate reductase complexed with NADPH and two lipophilic antifolates at 1.09 a and 1.05 a resolution.', 'year': 2002}], 'database2': [{'database_code': '1KMV', 'database_id': 'PDB', 'pdbx_doi': '10.2210/pdb1kmv/pdb', 'pdbx_database_accession': 'pdb_00001kmv'}, {'database_code': 'RCSB015122', 'database_id': 'RCSB'}, {'database_code': 'D_1000015122', 'database_id': 'WWPDB'}], 'diffrn': [{'ambient_temp': 100.0, 'crystal_id': '1', 'id': '1'}], 'diffrn_detector': [{'details': 'PT-COATED MIRROR', 'detector': 'CCD', 'diffrn_id': '1', 'pdbx_collection_date': '1998-06-18T00:00:00+0000', 'type': 'BRANDEIS - B4'}], 'diffrn_radiation': [{'diffrn_id': '1', 'monochromator': 'SI (111)', 'pdbx_diffrn_protocol': 'SINGLE WAVELENGTH', 'pdbx_monochromatic_or_laue_ml': 'M', 'pdbx_scattering_type': 'x-ray', 'wavelength_id': '1'}], 'diffrn_source': [{'diffrn_id': '1', 'pdbx_synchrotron_beamline': 'X25', 'pdbx_synchrotron_site': 'NSLS', 'pdbx_wavelength': '0.90', 'source': 'SYNCHROTRON', 'type': 'NSLS BEAMLINE X25'}], 'entry': {'id': '1KMV'}, 'exptl': [{'crystals_number': 1, 'method': 'X-RAY DIFFRACTION'}], 'exptl_crystal': [{'density_matthews': 2.2, 'density_percent_sol': 45.0, 'id': '1'}], 'exptl_crystal_grow': [{'crystal_id': '1', 'method': 'VAPOR DIFFUSION, HANGING DROP', 'p_h': 8.0, 'pdbx_details': 'THE TERNARY COMPLEX OF DHFR WITH NADPH AND SRI-9662 WAS FORMED BY MIXING HUMAN DHFR (20 MG/ML IN 25 MM KPO4 (PH 7.0), 0.1 MM EDTA, AND 3 MM NAN3) WITH 60 MM NADPH, FOLLOWED 15 MINUTES LATER BY 60 MM OF INHIBITOR IN DMSO (FINAL CONCENTRATIONS OF 2 MM NADPH AND 2 MM INHIBITOR). THIS COMPLEX SOLUTION WAS MIXED WITH AN EQUAL VOLUME OF PRECIPITANT CONTAINING 24-33% PEG 4000, 0.2 M LI2SO4, 0.1 M TRIS CL (PH 7.9-8.4), 5% GLYCEROL, AND EQUILIBRATED WITH THE PRECIPITANT BY HANGING DROP VAPOR DIFFUSION AT 277 K. THE CRYSTAL GREW IN ABOUT 3 WEEKS. THE CRYSTAL WAS FLASH-COOLED DIRECTLY IN LIQUID NITROGEN AFTER HARVESTING INTO MOTHER LIQUOR CONTAINING 10% GLYCEROL., pH 8.00, VAPOR DIFFUSION, HANGING DROP', 'temp': 277.0}], 'pdbx_audit_revision_category': [{'category': 'chem_comp_atom', 'data_content_type': 'Structure model', 'ordinal': 1, 'revision_ordinal': 4}, {'category': 'chem_comp_bond', 'data_content_type': 'Structure model', 'ordinal': 2, 'revision_ordinal': 4}, {'category': 'database_2', 'data_content_type': 'Structure model', 'ordinal': 3, 'revision_ordinal': 4}, {'category': 'struct_site', 'data_content_type': 'Structure model', 'ordinal': 4, 'revision_ordinal': 4}, {'category': 'pdbx_initial_refinement_model', 'data_content_type': 'Structure model', 'ordinal': 5, 'revision_ordinal': 5}], 'pdbx_audit_revision_details': [{'data_content_type': 'Structure model', 'ordinal': 1, 'provider': 'repository', 'revision_ordinal': 1, 'type': 'Initial release'}], 'pdbx_audit_revision_group': [{'data_content_type': 'Structure model', 'group': 'Version format compliance', 'ordinal': 1, 'revision_ordinal': 2}, {'data_content_type': 'Structure model', 'group' ...
# Fetching information for Holo PDB ID: 6yqm
# Fetching information for Holo PDB ID: 1lc0
# Fetching information for Holo PDB ID: 1m7h
# Fetching information for Holo PDB ID: 3czy
# Fetching information for Holo PDB ID: 8dr9
# Fetching information for Holo PDB ID: 7p4r
# Fetching information for Holo PDB ID: 2cnq
# Fetching information for Holo PDB ID: 1us0
# Fetching information for Holo PDB ID: 4b1y
# Fetching information for Holo PDB ID: 4dfx
# Fetching information for Holo PDB ID: 2gt4
# Fetching information for Holo PDB ID: 1b16
# Fetching information for Holo PDB ID: 2a94
# Fetching information for Holo PDB ID: 5yce
# Fetching information for Holo PDB ID: 2bcg
# Fetching information for Holo PDB ID: 1uux
# Fetching information for Holo PDB ID: 1zk4
# Fetching information for Holo PDB ID: 6dyf
# Fetching information for Holo PDB ID: 2bzz
# Fetching information for Holo PDB ID: 2j46
# Fetching information for Holo PDB ID: 2cdb
# Fetching information for Holo PDB ID: 2evw
# Fetching information for Holo PDB ID: 2ux9
# Fetching information for Holo PDB ID: 2dxu
# Fetching information for Holo PDB ID: 4jp3
# Fetching information for Holo PDB ID: 2iyx
# Fetching information for Holo PDB ID: 2j9e
# Fetching information for Holo PDB ID: 2rk1
# Fetching information for Holo PDB ID: 7uld
# Fetching information for Holo PDB ID: 2q0k
# Fetching information for Holo PDB ID: 2qw8
# Fetching information for Holo PDB ID: 4pf4
# Fetching information for Holo PDB ID: 2wzc
# Fetching information for Holo PDB ID: 2xzw
# Fetching information for Holo PDB ID: 2y5d
# Fetching information for Holo PDB ID: 3a7i
# Fetching information for Holo PDB ID: 5us8
# Fetching information for Holo PDB ID: 6esa
# Fetching information for Holo PDB ID: 6fch
# Fetching information for Holo PDB ID: 6fgd
# Fetching information for Holo PDB ID: 5bn8
# Fetching information for Holo PDB ID: 8fo2
# Fetching information for Holo PDB ID: 6ekk
# Fetching information for Holo PDB ID: 6jsc
# Fetching information for Holo PDB ID: 6lxa
# Fetching information for Holo PDB ID: 6m5p
# Fetching information for Holo PDB ID: 6loz
# Fetching information for Holo PDB ID: 6ntb
# Fetching information for Holo PDB ID: 7tpw
# Fetching information for Holo PDB ID: 6r3y
# Fetching information for Holo PDB ID: 5y6n
# Fetching information for Holo PDB ID: 6teq
# Fetching information for Holo PDB ID: 6tm3
# Fetching information for Holo PDB ID: 7tx0
# Fetching information for Holo PDB ID: 6ok4
# Fetching information for Holo PDB ID: 6x9a
# Fetching information for Holo PDB ID: 8a0f
# Fetching information for Holo PDB ID: 6lb4
# Fetching information for Holo PDB ID: 6f7u
# Fetching information for Holo PDB ID: 7d4o
# Fetching information for Holo PDB ID: 7qzn
# Fetching information for Holo PDB ID: 7kru
# Fetching information for Holo PDB ID: 6d5x
# Fetching information for Holo PDB ID: 7sne
# Fetching information for Holo PDB ID: 3apt
# Fetching information for Holo PDB ID: 5n81
# Fetching information for Holo PDB ID: 8crh
# Fetching information for Holo PDB ID: 2vb1
# Fetching information for Holo PDB ID: 8bci
# Fetching information for Holo PDB ID: 5j4l
# Fetching information for Holo PDB ID: 8d0u
# Fetching information for Holo PDB ID: 8evx
# Fetching information for Holo PDB ID: 8u96
# Fetching information for Holo PDB ID: 9b20
#     Apo_PDB_ID Holo_PDB_ID Ligands  Ions
# 0         5vmm        2w72   [HEM]   [K]
# 1         5j80        6tn5      []    []
# 2         2ofm        1x8q   [HEM]    []
# 4         1gfs        1e7s      []    []
# 7         1k6i        1xgk      []   [K]
# ..         ...         ...     ...   ...
# 148       8bci        8bci      []    []
# 149       6tuu        5j4l      []    []
# 150       8d0p        8d0u      []    []
# 152       8sbn        8u96      []    []
# 153       9b1z        9b20      []  [MG]
#
# [119 rows x 4 columns]

# %%
# !rm -rf /content/cif_files

# %% [markdown]
# # Atsisiunčiame struktūrų CIF failus.
#
# Peržiūrime struktūras rankiniu būdu, užtikrindami jonų egzistvimą holo struktūrose bei panašumą su apo struktūromis.

# %%
import os
import requests
import pandas as pd

# Function to download CIF files
def download_cif(pdb_id, output_dir):
    url = f'https://files.rcsb.org/download/{pdb_id}.cif'
    response = requests.get(url)

    if response.status_code == 200:
        filepath = os.path.join(output_dir, f"{pdb_id}.cif")
        with open(filepath, 'wb') as file:
            file.write(response.content)
        print(f"Downloaded: {pdb_id}.cif")
        return True
    else:
        print(f"Failed to download: {pdb_id}.cif")
        return False

# Load the DataFrame from the previous script's filtered results
input_csv = "reviewed_apo_holo_pair_ligand_and_ion_data.tsv"
output_dir = "cif_files"
os.makedirs(output_dir, exist_ok=True)

# Read the filtered results CSV
filtered_results_df = pd.read_csv(input_csv, sep='\t')

# Download CIF files for both apo and holo IDs
for index, row in filtered_results_df.iterrows():
    apo = row['Apo_PDB_ID'][:4]
    holo = row['Holo_PDB_ID'][:4]
    print(f"Processing pair: Apo - {apo}, Holo - {holo}")
    download_cif(apo, output_dir)  # Download CIF for apo
    download_cif(holo, output_dir)  # Download CIF for holo
# Out:
# Processing pair: Apo - 5vmm, Holo - 2w72
# Downloaded: 5vmm.cif
# Downloaded: 2w72.cif
# Processing pair: Apo - 5j80, Holo - 6tn5
# Downloaded: 5j80.cif
# Downloaded: 6tn5.cif
# Processing pair: Apo - 2ofm, Holo - 1x8q
# Downloaded: 2ofm.cif
# Downloaded: 1x8q.cif
# Processing pair: Apo - 1gfs, Holo - 1e7s
# Downloaded: 1gfs.cif
# Downloaded: 1e7s.cif
# Processing pair: Apo - 1k6i, Holo - 1xgk
# Downloaded: 1k6i.cif
# Downloaded: 1xgk.cif
# Processing pair: Apo - 1pdb, Holo - 1kmv
# Downloaded: 1pdb.cif
# Downloaded: 1kmv.cif
# Processing pair: Apo - 1d6j, Holo - 1m7h
# Downloaded: 1d6j.cif
# Downloaded: 1m7h.cif
# Processing pair: Apo - 3n80, Holo - 8dr9
# Downloaded: 3n80.cif
# Downloaded: 8dr9.cif
# Processing pair: Apo - 2cnu, Holo - 2cnq
# Downloaded: 2cnu.cif
# Downloaded: 2cnq.cif
# Processing pair: Apo - 1xgd, Holo - 1us0
# Downloaded: 1xgd.cif
# Downloaded: 1us0.cif
# Processing pair: Apo - 7u8k, Holo - 4b1y
# Downloaded: 7u8k.cif
# Downloaded: 4b1y.cif
# Processing pair: Apo - 1ufp, Holo - 5yce
# Downloaded: 1ufp.cif
# Downloaded: 5yce.cif
# Processing pair: Apo - 3cue, Holo - 2bcg
# Downloaded: 3cue.cif
# Downloaded: 2bcg.cif
# Processing pair: Apo - 7a2b, Holo - 1zk4
# Downloaded: 7a2b.cif
# Downloaded: 1zk4.cif
# Processing pair: Apo - 1apc, Holo - 6dyf
# Downloaded: 1apc.cif
# Downloaded: 6dyf.cif
# Processing pair: Apo - 1ffh, Holo - 2j46
# Downloaded: 1ffh.cif
# Downloaded: 2j46.cif
# Processing pair: Apo - 2cd9, Holo - 2cdb
# Downloaded: 2cd9.cif
# Downloaded: 2cdb.cif
# Processing pair: Apo - 4jp2, Holo - 4jp3
# Downloaded: 4jp2.cif
# Downloaded: 4jp3.cif
# Processing pair: Apo - 2j9d, Holo - 2j9e
# Downloaded: 2j9d.cif
# Downloaded: 2j9e.cif
# Processing pair: Apo - 2rh2, Holo - 2rk1
# Downloaded: 2rh2.cif
# Downloaded: 2rk1.cif
# Processing pair: Apo - 2g9i, Holo - 7uld
# Downloaded: 2g9i.cif
# Downloaded: 7uld.cif
# Processing pair: Apo - 3ish, Holo - 2q0k
# Downloaded: 3ish.cif
# Downloaded: 2q0k.cif
# Processing pair: Apo - 2qys, Holo - 2qw8
# Downloaded: 2qys.cif
# Downloaded: 2qw8.cif
# Processing pair: Apo - 1jks, Holo - 4pf4
# Downloaded: 2fr2.cif
# Downloaded: 6r3y.cif
# Processing pair: Apo - 5jmt, Holo - 5y6n
# Downloaded: 5jmt.cif
# Downloaded: 5y6n.cif
# Processing pair: Apo - 6x2e, Holo - 6ok4
# Downloaded: 6x2e.cif
# Downloaded: 6ok4.cif
# Processing pair: Apo - 6x99, Holo - 6x9a
# Downloaded: 6x99.cif
# Downloaded: 6x9a.cif
# Processing pair: Apo - 6xxh, Holo - 8a0f
# Downloaded: 6xxh.cif
# Downloaded: 8a0f.cif
# Processing pair: Apo - 7d48, Holo - 7d4o
# Downloaded: 7d48.cif
# Downloaded: 7d4o.cif
# Processing pair: Apo - 6iau, Holo - 7qzn
# Downloaded: 6iau.cif
# Downloaded: 7qzn.cif
# Processing pair: Apo - 1dkg, Holo - 7kru
# Downloaded: 1dkg.cif
# Downloaded: 7kru.cif
# Processing pair: Apo - 8eac, Holo - 3apt
# Downloaded: 8eac.cif
# Downloaded: 3apt.cif
# Processing pair: Apo - 7zzx, Holo - 8crh
# Downloaded: 7zzx.cif
# Downloaded: 8crh.cif
# Processing pair: Apo - 6tuu, Holo - 5j4l
# Downloaded: 6tuu.cif
# Downloaded: 5j4l.cif
# Processing pair: Apo - 8d0p, Holo - 8d0u
# Downloaded: 8d0p.cif
# Downloaded: 8d0u.cif
# Processing pair: Apo - 8sbn, Holo - 8u96
# Downloaded: 8sbn.cif
# Downloaded: 8u96.cif
# Processing pair: Apo - 9b1z, Holo - 9b20
# Downloaded: 9b1z.cif
# Downloaded: 9b20.cif

# %%
rmsd_df = pd.read_csv('apo_holo_pairs_with_RMSD_info.csv')
reviewed_df = pd.read_csv('reviewed_apo_holo_pair_ligand_and_ion_data.tsv', sep='\t')

reviewed_ids = set(reviewed_df['PDB_ID'].str.upper())

rmsd_df['holo_id'] = rmsd_df['holo_structure'].str[:4].str.upper()

fi_df = rmsd_df[rmsd_df['holo_id'].isin(reviewed_ids)].copy()

fi_df = fi_df[['holo_id', 'apo_count', 'apo_RMSD_min', 'apo_RMSD_max', 'apo_RMSD_avg', 'holo_count', 'holo_RMSD_min', 'holo_RMSD_max', 'holo_RMSD_avg']]
print(fi_df)
# Out:
#     holo_id  apo_count  apo_RMSD_min  apo_RMSD_max  apo_RMSD_avg  holo_count  \
# 0      2W72          2          0.96          1.23      1.095000         650
# 1      6TN5         19          0.84          1.76      1.615789         368
# 2      1X8Q          1          0.86          0.86      0.860000          48
# 4      1E7S          1          0.46          0.46      0.460000           6
# 7      1XGK          1          0.20          0.20      0.200000          28
# ..      ...        ...           ...           ...           ...         ...
# 146    8CRH          1          0.99          0.99      0.990000           4
# 149    5J4L          7          0.86          1.31      1.094286          78
# 150    8D0U          1          0.24          0.24      0.240000           6
# 152    8U96          3          0.90          1.29      1.090000           4
# 153    9B20          2          1.13          1.13      1.130000           4
#
#      holo_RMSD_min  holo_RMSD_max  holo_RMSD_avg
# 0             0.06           1.97       0.634169
# 1             0.72           2.55       1.449891
# 2             0.19           1.06       0.689583
# 4             0.10           0.45       0.280000
# 7             0.25           1.13       0.616786
# ..             ...            ...            ...
# 146           0.87           1.17       1.000000
# 149           0.70           1.47       1.036282
# 150           0.09           0.25       0.153333
# 152           0.13           0.76       0.445000
# 153           0.62           1.03       0.825000
#
# [90 rows x 9 columns]

# %%
fi_df.to_csv('reviewed_RMSD_info.csv', index=False)

# %%
# !rm -rf /content/structures_from_pdb.zip
# !zip -r structures_from_pdb.zip /content/cif_files/
# Out:
#   adding: content/cif_files/ (stored 0%)
#   adding: content/cif_files/8d0p.pdb (deflated 75%)
#   adding: content/cif_files/1dkg.pdb (deflated 76%)
#   adding: content/cif_files/1us0.pdb (deflated 76%)
#   adding: content/cif_files/3x39.pdb (deflated 76%)
#   adding: content/cif_files/1gfs.pdb (deflated 76%)
#   adding: content/cif_files/6v6u.pdb (deflated 75%)
#   adding: content/cif_files/6fgd.pdb (deflated 75%)
#   adding: content/cif_files/2rh2.pdb (deflated 77%)
#   adding: content/cif_files/6iep.pdb (deflated 76%)
#   adding: content/cif_files/3mjs.pdb (deflated 76%)
#   adding: content/cif_files/5y1g.pdb (deflated 76%)
#   adding: content/cif_files/3mjc.pdb (deflated 76%)
#   adding: content/cif_files/7u8k.pdb (deflated 79%)
#   adding: content/cif_files/2qw8.pdb (deflated 76%)
#   adding: content/cif_files/6x2e.pdb (deflated 76%)
#   adding: content/cif_files/1k6i.pdb (deflated 76%)
#   adding: content/cif_files/1pdb.pdb (deflated 77%)
#   adding: content/cif_files/8uw0.pdb (deflated 76%)
#   adding: content/cif_files/6epp.pdb (deflated 74%)
#   adding: content/cif_files/8dqt.pdb (deflated 76%)
#   adding: content/cif_files/5l3z.pdb (deflated 75%)
#   adding: content/cif_files/5lvo.pdb (deflated 75%)
#   adding: content/cif_files/3ncr.pdb (deflated 76%)
#   adding: content/cif_files/7zzx.pdb (deflated 75%)
#   adding: content/cif_files/6azp.pdb (deflated 76%)
#   adding: content/cif_files/2cnq.pdb (deflated 76%)
#   adding: content/cif_files/6n4a.pdb (deflated 76%)
#   adding: content/cif_files/8a0f.pdb (deflated 75%)
#   adding: content/cif_files/3tw8.pdb (deflated 74%)
#   adding: content/cif_files/1d6j.pdb (deflated 76%)
#   adding: content/cif_files/3cue.pdb (deflated 76%)
#   adding: content/cif_files/2j46.pdb (deflated 75%)
#   adding: content/cif_files/5dcw.pdb (deflated 75%)
#   adding: content/cif_files/3k74.pdb (deflated 76%)
#   adding: content/cif_files/4dcv.pdb (deflated 76%)
#   adding: content/cif_files/3oif.pdb (deflated 76%)
#   adding: content/cif_files/6iau.pdb (deflated 76%)
#   adding: content/cif_files/5jbj.pdb (deflated 75%)
#   adding: content/cif_files/4ccr.pdb (deflated 76%)
#   adding: content/cif_files/5chp.pdb (deflated 77%)
#   adding: content/cif_files/6nlf.pdb (deflated 76%)
#   adding: content/cif_files/1ffh.pdb (deflated 76%)
#   adding: content/cif_files/1xgd.pdb (deflated 76%)
#   adding: content/cif_files/5v1m.pdb (deflated 75%)
#   adding: content/cif_files/2qys.pdb (deflated 76%)
#   adding: content/cif_files/5vmm.pdb (deflated 75%)
#   adding: content/cif_files/4jp3.pdb (deflated 76%)
#   adding: content/cif_files/4qx6.pdb (deflated 76%)
#   adding: content/cif_files/2cdb.pdb (deflated 76%)
#   adding: content/cif_files/5u95.pdb (deflated 74%)
#   adding: content/cif_files/6m65.pdb (deflated 77%)
#   adding: content/cif_files/2hjg.pdb (deflated 77%)
#   adding: content/cif_files/6ekk.pdb (deflated 75%)
#   adding: content/cif_files/3fwk.pdb (deflated 75%)
#   adding: content/cif_files/6jsd.pdb (deflated 75%)
#   adding: content/cif_files/2exv.pdb (deflated 78%)
#   adding: content/cif_files/5l40.pdb (deflated 75%)
#   adding: content/cif_files/4trm.pdb (deflated 74%)
#   adding: content/cif_files/2w72.pdb (deflated 76%)
#   adding: content/cif_files/6nlg.pdb (deflated 77%)
#   adding: content/cif_files/4jl5.pdb (deflated 75%)
#   adding: content/cif_files/5ggb.pdb (deflated 75%)
#   adding: content/cif_files/3uwk.pdb (deflated 77%)
#   adding: content/cif_files/6xxh.pdb (deflated 75%)
#   adding: content/cif_files/2ofm.pdb (deflated 76%)
#   adding: content/cif_files/6x9a.pdb (deflated 75%)
#   adding: content/cif_files/6ok4.pdb (deflated 75%)

# %%
# !pip install gemmi
# Out:
# Collecting gemmi
#   Downloading gemmi-0.7.1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (2.3 kB)
# Downloading gemmi-0.7.1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.5/2.5 MB 30.3 MB/s eta 0:00:00
# Installing collected packages: gemmi
# Successfully installed gemmi-0.7.1

# %% [markdown]
# # Skaičiuojame ligandų ir jonų kiekį holo struktūrose

# %%
import gemmi
from collections import Counter
import os
import pandas as pd
import re

# Define known ligands and ions
KNOWN_LIGANDS = {"BCB", "BCL", "CHL", "CLA", "CIT", "MYR", "OLA", "PLM", "HEC", "HEM", "NDP", "NAP", "NAD", "FAD", "GDP", "GTP", "AMP", "ATP", "ADP"}
KNOWN_LIGAND_MAP = {
    "BACTERIOCHLOROPHYLL B": "BCB",
    "BACTERIOCHLOROPHYLL": "BCL",
    "CHLOROPHYLL A": "CHL",
    "CHLOROPHYLL B": "CLA",
    "CITRIC ACID": "CIT",
    "MYRISTIC ACID": "MYR",
    "OLEIC ACID": "OLA",
    "PALMITIC ACID": "PLM",
    "HEMATOPOIETIC ENZYME COMPLEX": "HEC",
    "HEME C": "HEC",
    "HEME": "HEM",
    "PROTOPORPHYRIN IX CONTAINING FE": "HEM",
    "NADP NICOTINAMIDE-ADENINE-DINUCLEOTIDE PHOSPHATE": "NDP",
    "NADPH DIHYDRO-NICOTINAMIDE-ADENINE-DINUCLEOTIDE PHOSPHATE": "NDP",
    "NICOTINAMIDE-ADENINE-DINUCLEOTIDE": "NAD",
    "FLAVIN-ADENINE DINUCLEOTIDE": "FAD",
    "GUANOSINE-5'-DIPHOSPHATE": "GDP",
    "GUANOSINE-5'-TRIPHOSPHATE": "GTP",
    "ADENOSINE MONOPHOSPHATE": "AMP",
    "ADENOSINE-5'-TRIPHOSPHATE": "ATP",
    "ADENOSINE-5'-DIPHOSPHATE": "ADP",
}

KNOWN_IONS = {"MG", "ZN", "CL", "CA", "NA", "MN", "K", "FE", "CU", "CO"}
KNOWN_ION_MAP = {
    "MAGNESIUM ION": "MG",
    "ZINC ION": "ZN",
    "CHLORIDE ION": "CL",
    "CALCIUM ION": "CA",
    "SODIUM ION": "NA",
    "MANGANESE ION": "MN",
    "POTASSIUM ION": "K",
    "FE ION": "FE",
    "COPPER ION": "CU",
    "COBALT ION": "CO",
}

def parse_cif(file_path):
    doc = gemmi.cif.read_file(file_path)
    block = doc.sole_block()
    entity = []
    count = []
    for element in block.find_loop("_entity.pdbx_number_of_molecules"):
        count.append(element)
    for element in block.find_loop("_entity.pdbx_description"):
        entity.append(element)

    entity_dict = dict(zip(entity, count))
    filtered_ion_dict = dict()
    filtered_ligand_dict = dict()

    for key, value in entity_dict.items():
        key = key.strip("'")
        key = re.sub('\\(.*\\) ', '', key)
        key = key.strip("\"")

        if key in KNOWN_LIGAND_MAP:
            filtered_ligand_dict[KNOWN_LIGAND_MAP[key]] = value

        if key in KNOWN_ION_MAP:
            filtered_ion_dict[KNOWN_ION_MAP[key]] = value

    return filtered_ligand_dict, filtered_ion_dict

# Main function to process CIF files in a directory
def process_cif_directory(directory, holo_ids):
    results = []
    for file_name in os.listdir(directory):
        if file_name.endswith(".cif"):
            file_path = os.path.join(directory, file_name)

            if file_name[:4] not in holo_ids:
                continue

            print(f"Processing {file_name}...")
            filtered_ligand_dict, filtered_ion_dict  = parse_cif(file_path)

            results.append({
                "Holo_id": file_name[0:4],
                "Ligands": list(filtered_ligand_dict.keys()),
                "Ligand_count": list(filtered_ligand_dict.values()),
                "Ions": list(filtered_ion_dict.keys()),
                "Ions_count": list(filtered_ion_dict.values())
            })

    # Convert to DataFrame
    results_df = pd.DataFrame(results)
    return results_df

df = pd.read_csv("reviewed_apo_holo_pair_ligand_and_ion_data.tsv", sep='\t')
holo_ids = list()

for id in df["Holo_PDB_ID"]:
    holo_ids.append(id)

# Path to directory containing CIF files
cif_directory = "/content/cif_files"

# Process CIF files and get results
cif_results_df = process_cif_directory(cif_directory, holo_ids)

cif_results_df.to_csv("ligand_and_ion_counts.csv", index=False)
print(cif_results_df)
# Out:
# Processing 7d4o.cif...
# Processing 5yce.cif...
# Processing 5gme.cif...
# Processing 6x9a.cif...
# Processing 3lq3.cif...
# Processing 4cnz.cif...
# Processing 6m65.cif...
# Processing 4gkb.cif...
# Processing 6tn5.cif...
# Processing 3apt.cif...
# Processing 1zk4.cif...
# Processing 7r3d.cif...
# Processing 4pf4.cif...
# Processing 6jsc.cif...
# Processing 2bcg.cif...
# Processing 5aus.cif...
# Processing 1m7h.cif...
# Processing 8d0u.cif...
# Processing 8dr9.cif...
# Processing 2rk1.cif...
# Processing 2w72.cif...
# Processing 5c4n.cif...
# Processing 1xgk.cif...
# Processing 5dcy.cif...
# Processing 3keq.cif...
# Processing 5v1m.cif...
# Processing 5j4l.cif...
# Processing 4b1y.cif...
# Processing 5iwu.cif...
# Processing 1e7s.cif...
# Processing 5b4t.cif...
# Processing 6r3y.cif...
# Processing 9b20.cif...
# Processing 1kmv.cif...
# Processing 2exv.cif...
# Processing 5l3z.cif...
# Processing 3g59.cif...
# Processing 6dyf.cif...
# Processing 6bmt.cif...
# Processing 6ntb.cif...
# Processing 4jp3.cif...
# Processing 6nlg.cif...
# Processing 6ok4.cif...
# Processing 8u96.cif...
# Processing 6d4b.cif...
# Processing 3mjs.cif...
# Processing 4qx6.cif...
# Processing 7uld.cif...
# Processing 5lvo.cif...
# Processing 2y5d.cif...
# Processing 2j46.cif...
# Processing 4gta.cif...
# Processing 3uwk.cif...
# Processing 8uw0.cif...
# Processing 4qnr.cif...
# Processing 5jbg.cif...
# Processing 2cnq.cif...
# Processing 5luh.cif...
# Processing 8crh.cif...
# Processing 8onv.cif...
# Processing 4pmj.cif...
# Processing 4ohu.cif...
# Processing 4jl5.cif...
# Processing 3oif.cif...
# Processing 7mo5.cif...
# Processing 2cdb.cif...
# Processing 6h0m.cif...
# Processing 2j9e.cif...
# Processing 5y1g.cif...
# Processing 7kru.cif...
# Processing 4up3.cif...
# Processing 5y6n.cif...
# Processing 6qaj.cif...
# Processing 6fgd.cif...
# Processing 3ncr.cif...
# Processing 4xye.cif...
# Processing 2q0k.cif...
# Processing 1x8q.cif...
# Processing 5ugv.cif...
# Processing 6ekk.cif...
# Processing 2qw8.cif...
# Processing 8a0f.cif...
# Processing 5bst.cif...
# Processing 5iqx.cif...
# Processing 1us0.cif...
# Processing 2hjg.cif...
# Processing 5f0z.cif...
# Processing 6v6u.cif...
# Processing 4bga.cif...
# Processing 7qzn.cif...
#    Holo_id     Ligands Ligand_count      Ions Ions_count
# 0     7d4o  [ATP, ADP]       [2, 2]      [MG]        [6]
# 1     5yce       [HEM]          [1]        []         []
# 2     5gme  [ADP, AMP]       [1, 1]        []         []
# 3     6x9a       [FAD]          [2]        []         []
# 4     3lq3  [ADP, AMP]       [1, 1]      [MG]        [1]
# ..     ...         ...          ...       ...        ...
# 85    2hjg       [GDP]          [2]      [ZN]        [1]
# 86    5f0z       [ADP]          [1]  [CA, NA]     [1, 1]
# 87    6v6u       [GDP]          [1]      [MG]        [1]
# 88    4bga       [ADP]          [4]   [K, MG]     [8, 3]
# 89    7qzn       [NAD]          [2]        []         []
#
# [90 rows x 5 columns]

# %% [markdown]
# # Suporuojame struktūras su uniprot identifikatoriumi

# %%
reviewed_holo_id_df = pd.read_csv("/content/reviewed_apo_holo_pair_ligand_and_ion_data.tsv", sep='\t')
uniprot_id_df = pd.read_csv("/content/apo_holo_pairs_with_RMSD_info.csv")

for index, row in uniprot_id_df.iterrows():
    uniprot_id_df.replace(row['holo_structure'], row['holo_structure'][0:4], inplace=True)
    uniprot_id_df.replace(row['uniprot_id'], re.sub('\\s.*', '', row['uniprot_id'].strip()), inplace=True)

print(uniprot_id_df['holo_structure'], reviewed_holo_id_df['Holo_PDB_ID'])

merged_df = uniprot_id_df.merge(
    reviewed_holo_id_df[['Holo_PDB_ID']],
    left_on='holo_structure',
    right_on='Holo_PDB_ID',
    how='inner'
)

reviewed_uniprot_ids = merged_df['uniprot_id'].tolist()

merged_df[['uniprot_id', 'Holo_PDB_ID']].to_csv('uniprot_holo_pdb_list.tsv', sep='\t', index=False)
# Out:
# 0      2w72
# 1      6tn5
# 2      1x8q
# 3      1dgg
# 4      1e7s
#        ...
# 149    5j4l
# 150    8d0u
# 151    8evx
# 152    8u96
# 153    9b20
# Name: holo_structure, Length: 154, dtype: object 0     2w72
# 1     6tn5
# 2     1x8q
# 3     1e7s
# 4     1xgk
#       ...
# 85    8crh
# 86    5j4l
# 87    8d0u
# 88    8u96
# 89    9b20
# Name: Holo_PDB_ID, Length: 90, dtype: object

# %%
# !rm -rf /content/uniprot_entries
# !rm -rf /content/uniprot_entries.zip

# %% [markdown]
# # Atsisiunčiame struktūrų sekas FASTA formatu naudojantis uniprot identifikatoriais ir API

# %%
import os
import requests

def download_fasta_sequences(uniprot_ids, output_dir):
    base_url = "https://rest.uniprot.org/uniprotkb/"
    headers = {"Accept": "text/x-fasta"}

    # Create output directory if it doesn't exist
    os.makedirs(output_dir, exist_ok=True)

    for uniprot_id in uniprot_ids:
        uniprot_id = uniprot_id.strip()
        print(f"Fetching FASTA sequence for UniProt ID: {uniprot_id}...")
        url = f"{base_url}{uniprot_id}.fasta"
        response = requests.get(url, headers=headers)

        if response.status_code == 200:
            # Save the FASTA sequence to a file named `uniprot_id.fasta`
            file_path = os.path.join(output_dir, f"{uniprot_id}.fasta")
            with open(file_path, "w") as fasta_file:
                fasta_file.write(response.text)
            print(f"Sequence saved to {file_path}")
        else:
            print(f"Failed to fetch FASTA sequence for {uniprot_id}. Status code: {response.status_code}")

# List of UniProt IDs to download
uniprot_holo_pdb_list = pd.read_csv("/content/uniprot_holo_pdb_list.tsv", sep='\t')

reviewed_uniprot_ids = uniprot_holo_pdb_list['uniprot_id'].tolist()
# Output directory
output_dir = "/content/uniprot_entries/"
os.makedirs(output_dir, exist_ok=True)
print(reviewed_uniprot_ids)
# Download the sequences
download_fasta_sequences(reviewed_uniprot_ids, output_dir)
# Out:
# ['P68871', 'P07900', 'Q94734', 'P32055', 'Q5AU62', 'P00374', 'Q12657', 'P05091', 'P27616', 'P15121', 'P68135', 'P02185', 'P01123', 'Q84EX5', 'P0ABE7', 'O07347', 'O93715', 'Q53W82', 'Q60381', 'P00383', 'O28028', 'P56431', 'Q15GI4', 'P53355', 'Q13WK4', 'P0ABQ4', 'Q9Y259', 'Q6FNA9', 'P62826', 'Q8E565', 'P70731', 'Q93NW7', 'G3XD33', 'O28527', 'P54616', 'D0VWQ0', 'O15530', 'Q8TX37', 'C4LW95', 'Q9HZN8', 'P01116', 'Q9WYT0', 'A0A0H3KNE7', 'O66490', 'P37344', 'P9WGR1', 'O68098', 'G8NVB5', 'P15452', 'P0A9S1', 'O24146', 'P61586', 'Q92NR7', 'Q9HY79', 'K7WDL7', 'A0A0A1EQY0', 'A0A0H3AER7', 'Q97UL5', 'O32553', 'G0YYQ5', 'G9VYV4', 'Q8ZPX9', 'P05164', 'Q9BPX1', 'P9WP23', 'P50743', 'A0QUZ2', 'P00099', 'D6PBM7', 'Q8E3E8', 'Q9BQ65', 'P00720', 'Q03555', 'Q15286', 'Q8NTB9', 'B5II98', 'P9WFG7', 'A0A024B7W1', 'P0CE13', 'F7X6I3', 'P49366', 'P0DSP4', 'S9Q235', 'P0A6Y8', 'Q5SLG6', 'A0A0L0P1H8', 'O74036', 'Q9Y231', 'A0A0H3FR62', 'A0A0H3GVQ7']
# Fetching FASTA sequence for UniProt ID: P68871...
# Sequence saved to /content/uniprot_entries/P68871.fasta
# Fetching FASTA sequence for UniProt ID: P07900...
# Sequence saved to /content/uniprot_entries/P07900.fasta
# Fetching FASTA sequence for UniProt ID: Q94734...
# Sequence saved to /content/uniprot_entries/Q94734.fasta
# Fetching FASTA sequence for UniProt ID: P32055...
# Sequence saved to /content/uniprot_entries/P32055.fasta
# Fetching FASTA sequence for UniProt ID: Q5AU62...
# Sequence saved to /content/uniprot_entries/Q5AU62.fasta
# Fetching FASTA sequence for UniProt ID: P00374...
# Sequence saved to /content/uniprot_entries/P00374.fasta
# Fetching FASTA sequence for UniProt ID: Q12657...
# Sequence saved to /content/uniprot_entries/Q12657.fasta
# Fetching FASTA sequence for UniProt ID: P05091...
# Sequence saved to /content/uniprot_entries/P05091.fasta
# Fetching FASTA sequence for UniProt ID: P27616...
# Sequence saved to /content/uniprot_entries/P27616.fasta
# Fetching FASTA sequence for UniProt ID: P15121...
# Sequence saved to /content/uniprot_entries/P15121.fasta
# Fetching FASTA sequence for UniProt ID: P68135...
# Sequence saved to /content/uniprot_entries/P68135.fasta
# Fetching FASTA sequence for UniProt ID: P02185...
# Sequence saved to /content/uniprot_entries/P02185.fasta
# Fetching FASTA sequence for UniProt ID: P01123...
# Sequence saved to /content/uniprot_entries/P01123.fasta
# Fetching FASTA sequence for UniProt ID: Q84EX5...
# Sequence saved to /content/uniprot_entries/Q84EX5.fasta
# Fetching FASTA sequence for UniProt ID: P0ABE7...
# Sequence saved to /content/uniprot_entries/P0ABE7.fasta
# Fetching FASTA sequence for UniProt ID: O07347...
# Sequence saved to /content/uniprot_entries/O07347.fasta
# Fetching FASTA sequence for UniProt ID: O93715...
# Sequence saved to /content/uniprot_entries/O93715.fasta
# Fetching FASTA sequence for UniProt ID: Q53W82...
# Sequence saved to /content/uniprot_entries/Q53W82.fasta
# Fetching FASTA sequence for UniProt ID: Q60381...
# Sequence saved to /content/uniprot_entries/Q60381.fasta
# Fetching FASTA sequence for UniProt ID: P00383...
# Sequence saved to /content/uniprot_entries/P00383.fasta
# Fetching FASTA sequence for UniProt ID: O28028...
# Sequence saved to /content/uniprot_entries/O28028.fasta
# Fetching FASTA sequence for UniProt ID: P56431...
# Sequence saved to /content/uniprot_entries/P56431.fasta
# Fetching FASTA sequence for UniProt ID: Q15GI4...
# Sequence saved to /content/uniprot_entries/Q15GI4.fasta
# Fetching FASTA sequence for UniProt ID: P53355...
# Sequence saved to /content/uniprot_entries/P53355.fasta
# Fetching FASTA sequence for UniProt ID: Q13WK4...
# Sequence saved to /content/uniprot_entries/Q13WK4.fasta
# Fetching FASTA sequence for UniProt ID: P0ABQ4...
# Sequence saved to /content/uniprot_entries/P0ABQ4.fasta
# Fetching FASTA sequence for UniProt ID: Q9Y259...
# Sequence saved to /content/uniprot_entries/Q9Y259.fasta
# Fetching FASTA sequence for UniProt ID: Q6FNA9...
# Sequence saved to /content/uniprot_entries/Q6FNA9.fasta
# Fetching FASTA sequence for UniProt ID: P62826...
# Sequence saved to /content/uniprot_entries/P62826.fasta
# Fetching FASTA sequence for UniProt ID: Q8E565...
# Sequence saved to /content/uniprot_entries/Q8E565.fasta
# Fetching FASTA sequence for UniProt ID: P70731...
# Sequence saved to /content/uniprot_entries/P70731.fasta
# Fetching FASTA sequence for UniProt ID: Q93NW7...
# Sequence saved to /content/uniprot_entries/Q93NW7.fasta
# Fetching FASTA sequence for UniProt ID: G3XD33...
# Sequence saved to /content/uniprot_entries/G3XD33.fasta
# Fetching FASTA sequence for UniProt ID: O28527...
# Sequence saved to /content/uniprot_entries/O28527.fasta
# Fetching FASTA sequence for UniProt ID: P54616...
# Sequence saved to /content/uniprot_entries/P54616.fasta
# Fetching FASTA sequence for UniProt ID: D0VWQ0...
# Sequence saved to /content/uniprot_entries/D0VWQ0.fasta
# Fetching FASTA sequence for UniProt ID: O15530...
# Sequence saved to /content/uniprot_entries/O15530.fasta
# Fetching FASTA sequence for UniProt ID: Q8TX37...
# Sequence saved to /content/uniprot_entries/Q8TX37.fasta
# Fetching FASTA sequence for UniProt ID: C4LW95...
# Sequence saved to /content/uniprot_entries/C4LW95.fasta
# Fetching FASTA sequence for UniProt ID: Q9HZN8...
# Sequence saved to /content/uniprot_entries/Q9HZN8.fasta
# Fetching FASTA sequence for UniProt ID: P01116...
# Sequence saved to /content/uniprot_entries/P01116.fasta
# Fetching FASTA sequence for UniProt ID: Q9WYT0...
# Sequence saved to /content/uniprot_entries/Q9WYT0.fasta
# Fetching FASTA sequence for UniProt ID: A0A0H3KNE7...
# Sequence saved to /content/uniprot_entries/A0A0H3KNE7.fasta
# Fetching FASTA sequence for UniProt ID: O66490...
# Sequence saved to /content/uniprot_entries/O66490.fasta
# Fetching FASTA sequence for UniProt ID: P37344...
# Sequence saved to /content/uniprot_entries/P37344.fasta
# Fetching FASTA sequence for UniProt ID: P9WGR1...
# Sequence saved to /content/uniprot_entries/P9WGR1.fasta
# Fetching FASTA sequence for UniProt ID: O68098...
# Sequence saved to /content/uniprot_entries/O68098.fasta
# Fetching FASTA sequence for UniProt ID: G8NVB5...
# Sequence saved to /content/uniprot_entries/G8NVB5.fasta
# Fetching FASTA sequence for UniProt ID: P15452...
# Sequence saved to /content/uniprot_entries/P15452.fasta
# Fetching FASTA sequence for UniProt ID: P0A9S1...
# Sequence saved to /content/uniprot_entries/P0A9S1.fasta
# Fetching FASTA sequence for UniProt ID: O24146...
# Sequence saved to /content/uniprot_entries/O24146.fasta
# Fetching FASTA sequence for UniProt ID: P61586...
# Sequence saved to /content/uniprot_entries/P61586.fasta
# Fetching FASTA sequence for UniProt ID: Q92NR7...
# Sequence saved to /content/uniprot_entries/Q92NR7.fasta
# Fetching FASTA sequence for UniProt ID: Q9HY79...
# Sequence saved to /content/uniprot_entries/Q9HY79.fasta
# Fetching FASTA sequence for UniProt ID: K7WDL7...
# Sequence saved to /content/uniprot_entries/K7WDL7.fasta
# Fetching FASTA sequence for UniProt ID: A0A0A1EQY0...
# Sequence saved to /content/uniprot_entries/A0A0A1EQY0.fasta
# Fetching FASTA sequence for UniProt ID: A0A0H3AER7...
# Sequence saved to /content/uniprot_entries/A0A0H3AER7.fasta
# Fetching FASTA sequence for UniProt ID: Q97UL5...
# Sequence saved to /content/uniprot_entries/Q97UL5.fasta
# Fetching FASTA sequence for UniProt ID: O32553...
# Sequence saved to /content/uniprot_entries/O32553.fasta
# Fetching FASTA sequence for UniProt ID: G0YYQ5...
# Sequence saved to /content/uniprot_entries/G0YYQ5.fasta
# Fetching FASTA sequence for UniProt ID: G9VYV4...
# Sequence saved to /content/uniprot_entries/G9VYV4.fasta
# Fetching FASTA sequence for UniProt ID: Q8ZPX9...
# Sequence saved to /content/uniprot_entries/Q8ZPX9.fasta
# Fetching FASTA sequence for UniProt ID: P05164...
# Sequence saved to /content/uniprot_entries/P05164.fasta
# Fetching FASTA sequence for UniProt ID: Q9BPX1...
# Sequence saved to /content/uniprot_entries/Q9BPX1.fasta
# Fetching FASTA sequence for UniProt ID: P9WP23...
# Sequence saved to /content/uniprot_entries/P9WP23.fasta
# Fetching FASTA sequence for UniProt ID: P50743...
# Sequence saved to /content/uniprot_entries/P50743.fasta
# Fetching FASTA sequence for UniProt ID: A0QUZ2...
# Sequence saved to /content/uniprot_entries/A0QUZ2.fasta
# Fetching FASTA sequence for UniProt ID: P00099...
# Sequence saved to /content/uniprot_entries/P00099.fasta
# Fetching FASTA sequence for UniProt ID: D6PBM7...
# Sequence saved to /content/uniprot_entries/D6PBM7.fasta
# Fetching FASTA sequence for UniProt ID: Q8E3E8...
# Sequence saved to /content/uniprot_entries/Q8E3E8.fasta
# Fetching FASTA sequence for UniProt ID: Q9BQ65...
# Sequence saved to /content/uniprot_entries/Q9BQ65.fasta
# Fetching FASTA sequence for UniProt ID: P00720...
# Sequence saved to /content/uniprot_entries/P00720.fasta
# Fetching FASTA sequence for UniProt ID: Q03555...
# Sequence saved to /content/uniprot_entries/Q03555.fasta
# Fetching FASTA sequence for UniProt ID: Q15286...
# Sequence saved to /content/uniprot_entries/Q15286.fasta
# Fetching FASTA sequence for UniProt ID: Q8NTB9...
# Sequence saved to /content/uniprot_entries/Q8NTB9.fasta
# Fetching FASTA sequence for UniProt ID: B5II98...
# Sequence saved to /content/uniprot_entries/B5II98.fasta
# Fetching FASTA sequence for UniProt ID: P9WFG7...
# Sequence saved to /content/uniprot_entries/P9WFG7.fasta
# Fetching FASTA sequence for UniProt ID: A0A024B7W1...
# Sequence saved to /content/uniprot_entries/A0A024B7W1.fasta
# Fetching FASTA sequence for UniProt ID: P0CE13...
# Sequence saved to /content/uniprot_entries/P0CE13.fasta
# Fetching FASTA sequence for UniProt ID: F7X6I3...
# Sequence saved to /content/uniprot_entries/F7X6I3.fasta
# Fetching FASTA sequence for UniProt ID: P49366...
# Sequence saved to /content/uniprot_entries/P49366.fasta
# Fetching FASTA sequence for UniProt ID: P0DSP4...
# Sequence saved to /content/uniprot_entries/P0DSP4.fasta
# Fetching FASTA sequence for UniProt ID: S9Q235...
# Sequence saved to /content/uniprot_entries/S9Q235.fasta
# Fetching FASTA sequence for UniProt ID: P0A6Y8...
# Sequence saved to /content/uniprot_entries/P0A6Y8.fasta
# Fetching FASTA sequence for UniProt ID: Q5SLG6...
# Sequence saved to /content/uniprot_entries/Q5SLG6.fasta
# Fetching FASTA sequence for UniProt ID: A0A0L0P1H8...
# Sequence saved to /content/uniprot_entries/A0A0L0P1H8.fasta
# Fetching FASTA sequence for UniProt ID: O74036...
# Sequence saved to /content/uniprot_entries/O74036.fasta
# Fetching FASTA sequence for UniProt ID: Q9Y231...
# Sequence saved to /content/uniprot_entries/Q9Y231.fasta
# Fetching FASTA sequence for UniProt ID: A0A0H3FR62...
# Sequence saved to /content/uniprot_entries/A0A0H3FR62.fasta
# Fetching FASTA sequence for UniProt ID: A0A0H3GVQ7...
# Sequence saved to /content/uniprot_entries/A0A0H3GVQ7.fasta

# %%
# !zip -r uniprot_entries.zip /content/uniprot_entries/
# Out:
#   adding: content/uniprot_entries/ (stored 0%)
#   adding: content/uniprot_entries/P0A6Y8.fasta (deflated 34%)
#   adding: content/uniprot_entries/P01123.fasta (deflated 20%)
#   adding: content/uniprot_entries/P0DSP4.fasta (deflated 27%)
#   adding: content/uniprot_entries/A0A0L0P1H8.fasta (deflated 22%)
#   adding: content/uniprot_entries/Q92NR7.fasta (deflated 24%)
#   adding: content/uniprot_entries/P00099.fasta (deflated 18%)
#   adding: content/uniprot_entries/O07347.fasta (deflated 32%)
#   adding: content/uniprot_entries/P62826.fasta (deflated 22%)
#   adding: content/uniprot_entries/P01116.fasta (deflated 23%)
#   adding: content/uniprot_entries/A0A0A1EQY0.fasta (deflated 29%)
#   adding: content/uniprot_entries/Q9WYT0.fasta (deflated 21%)
#   adding: content/uniprot_entries/G3XD33.fasta (deflated 25%)
#   adding: content/uniprot_entries/G9VYV4.fasta (deflated 28%)
#   adding: content/uniprot_entries/O15530.fasta (deflated 31%)
#   adding: content/uniprot_entries/P02185.fasta (deflated 16%)
#   adding: content/uniprot_entries/P00374.fasta (deflated 19%)
#   adding: content/uniprot_entries/Q8NTB9.fasta (deflated 33%)
#   adding: content/uniprot_entries/Q53W82.fasta (deflated 23%)
#   adding: content/uniprot_entries/Q5AU62.fasta (deflated 27%)
#   adding: content/uniprot_entries/B5II98.fasta (deflated 15%)
#   adding: content/uniprot_entries/P00720.fasta (deflated 18%)
#   adding: content/uniprot_entries/P05091.fasta (deflated 31%)
#   adding: content/uniprot_entries/Q6FNA9.fasta (deflated 26%)
#   adding: content/uniprot_entries/O32553.fasta (deflated 26%)
#   adding: content/uniprot_entries/A0A0H3KNE7.fasta (deflated 22%)
#   adding: content/uniprot_entries/Q93NW7.fasta (deflated 43%)
#   adding: content/uniprot_entries/P56431.fasta (deflated 24%)
#   adding: content/uniprot_entries/K7WDL7.fasta (deflated 28%)
#   adding: content/uniprot_entries/P27616.fasta (deflated 23%)
#   adding: content/uniprot_entries/P9WFG7.fasta (deflated 18%)
#   adding: content/uniprot_entries/P9WP23.fasta (deflated 21%)
#   adding: content/uniprot_entries/P70731.fasta (deflated 14%)
#   adding: content/uniprot_entries/Q12657.fasta (deflated 21%)
#   adding: content/uniprot_entries/Q94734.fasta (deflated 23%)
#   adding: content/uniprot_entries/Q84EX5.fasta (deflated 24%)
#   adding: content/uniprot_entries/P15121.fasta (deflated 25%)
#   adding: content/uniprot_entries/P07900.fasta (deflated 35%)
#   adding: content/uniprot_entries/Q9BQ65.fasta (deflated 25%)
#   adding: content/uniprot_entries/Q9HY79.fasta (deflated 21%)
#   adding: content/uniprot_entries/Q8ZPX9.fasta (deflated 23%)
#   adding: content/uniprot_entries/Q8TX37.fasta (deflated 27%)
#   adding: content/uniprot_entries/P0A9S1.fasta (deflated 28%)
#   adding: content/uniprot_entries/A0QUZ2.fasta (deflated 24%)

# %%
# !pip install biopython
# Out:
# Collecting biopython
#   Downloading biopython-1.85-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (13 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from biopython) (2.0.2)
# Downloading biopython-1.85-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.3/3.3 MB 41.3 MB/s eta 0:00:00
# Installing collected packages: biopython
# Successfully installed biopython-1.85

# %% [markdown]
# # Sugeneruojame JSON darbų failus AlphaFold3 įrankiui

# %%
import os
import json
import pandas as pd
from Bio import SeqIO
import re
# Directory containing Uniprot FASTA files
fasta_dir = "uniprot_entries"

# Function to read the sequence from a Uniprot FASTA file
def get_sequence(uniprot_id):
    fasta_file = os.path.join(fasta_dir, f"{uniprot_id}.fasta")
    if not os.path.exists(fasta_file):
        print(f"FASTA file not found for Uniprot ID: {uniprot_id}")
        return None
    for record in SeqIO.parse(fasta_file, "fasta"):
        return str(record.seq)
    return None

# Function to create AlphaFold job JSON
def create_alphafold_job(job_name, sequence, ligands=None, ions=None):
    sequences = [
        {
            "proteinChain": {
                "sequence": sequence,
                "count": 1
            }
        }
    ]

    if ligands:
        for ligand, count in ligands.items():
            sequences.append({
                "ligand": {
                    "ligand": f"CCD_{ligand}",
                    "count": count
                }
            })

    if ions:
        for ion, count in ions.items():
            sequences.append({
                "ion": {
                    "ion": ion,
                    "count": count
                }
            })

    job_data = {
        "name": job_name,
        "modelSeeds": [],
        "sequences": sequences
    }

    return job_data

# Main script
if __name__ == "__main__":
    # Load data files
    input_tsv = "/content/reviewed_apo_holo_pair_ligand_and_ion_data.tsv"
    uniprot_holo_pdb_df = pd.read_csv("/content/uniprot_holo_pdb_list.tsv", sep='\t')
    ligand_ion_file = "/content/ligand_and_ion_counts.csv"
    output_file = "alphafold_jobs.json"

    # Read the main data file
    data = pd.read_csv(input_tsv, sep='\t')

    # Read ligand and ion counts
    counts_data = pd.read_csv(ligand_ion_file)
    ligand_counts = counts_data.set_index('Holo_id')['Ligand_count'].to_dict()
    ion_counts = counts_data.set_index('Holo_id')['Ions_count'].to_dict()
    all_jobs = []

    for _, row in data.iterrows():
        apo_id = row['Apo_PDB_ID']
        holo_id = row['Holo_PDB_ID']
        ligands = eval(row['Ligands']) if 'Ligands' in row and pd.notna(row['Ligands']) else []
        ions = eval(row['Ions']) if 'Ions' in row and pd.notna(row['Ions']) else []
        # Get Uniprot ID from mapping
        uniprot_id = uniprot_holo_pdb_df.loc[uniprot_holo_pdb_df['Holo_PDB_ID']== holo_id[0:4], 'uniprot_id'].iloc[0]
        print(uniprot_id, holo_id)
        if not uniprot_id:
            print(f"No Uniprot ID found for {holo_id}")
            continue

        # Get sequences for apo and holo structures
        apo_sequence = get_sequence(uniprot_id)
        holo_sequence = get_sequence(uniprot_id)

        if apo_sequence:
            apo_job = create_alphafold_job(job_name=f'{apo_id}_apo', sequence=apo_sequence)
            all_jobs.append(apo_job)
            print(f"Added AlphaFold job for apo: {apo_id}")

        if holo_sequence:
            ligand_dict = {}
            for i, ion in enumerate(ligands):
              counts = list(map(int, re.findall(r"\d+", ligand_counts.get(holo_id[0:4], 1))))
              ligand_dict[ion] = counts[i]

            ion_dict = {}
            for i, ion in enumerate(ions):
              counts = list(map(int, re.findall(r"\d+", ion_counts.get(holo_id[0:4], 1))))
              ion_dict[ion] = counts[i]
            holo_job = create_alphafold_job(job_name=f'{holo_id}_holo', sequence=holo_sequence, ligands=ligand_dict, ions=ion_dict)
            all_jobs.append(holo_job)
            print(f"Added AlphaFold job for holo: {holo_id}")
    print(len(all_jobs))

    def save_jobs_in_parts(all_jobs, output_file_base, max_jobs=100):
        total_jobs = len(all_jobs)
        num_parts = (total_jobs + max_jobs - 1) // max_jobs  # Ceiling division

        for i in range(num_parts):
            start = i * max_jobs
            end = min((i + 1) * max_jobs, total_jobs)
            part_jobs = all_jobs[start:end]

            filename = f"{output_file_base}_part_{i + 1}.json"
            with open(filename, "w") as outfile:
                json.dump(part_jobs, outfile, indent=4)
            print(f"Saved {len(part_jobs)} jobs to {filename}")

    output_file_base = "AlphaFold_jobs"
    save_jobs_in_parts(all_jobs, output_file_base, max_jobs=30)
# Out:
# P68871 2w72
# Added AlphaFold job for apo: 5vmm
# Added AlphaFold job for holo: 2w72
# P07900 6tn5
# Added AlphaFold job for apo: 5j80
# Added AlphaFold job for holo: 6tn5
# Q94734 1x8q
# Added AlphaFold job for apo: 2ofm
# Added AlphaFold job for holo: 1x8q
# P32055 1e7s
# Added AlphaFold job for apo: 1gfs
# Added AlphaFold job for holo: 1e7s
# Q5AU62 1xgk
# Added AlphaFold job for apo: 1k6i
# Added AlphaFold job for holo: 1xgk
# P00374 1kmv
# Added AlphaFold job for apo: 1pdb
# Added AlphaFold job for holo: 1kmv
# Q12657 1m7h
# Added AlphaFold job for apo: 1d6j
# Added AlphaFold job for holo: 1m7h
# P05091 8dr9
# Added AlphaFold job for apo: 3n80
# Added AlphaFold job for holo: 8dr9
# P27616 2cnq
# Added AlphaFold job for apo: 2cnu
# Added AlphaFold job for holo: 2cnq
# P15121 1us0
# Added AlphaFold job for apo: 1xgd
# Added AlphaFold job for holo: 1us0
# P68135 4b1y
# Added AlphaFold job for apo: 7u8k
# Added AlphaFold job for holo: 4b1y
# P02185 5yce
# Added AlphaFold job for apo: 1ufp
# Added AlphaFold job for holo: 5yce
# P01123 2bcg
# Added AlphaFold job for apo: 3cue
# Added AlphaFold job for holo: 2bcg
# Q84EX5 1zk4
# Added AlphaFold job for apo: 7a2b
# Added AlphaFold job for holo: 1zk4
# P0ABE7 6dyf
# Added AlphaFold job for apo: 1apc
# Added AlphaFold job for holo: 6dyf
# O07347 2j46
# Added AlphaFold job for apo: 1ffh
# Added AlphaFold job for holo: 2j46
# O93715 2cdb
# Added AlphaFold job for apo: 2cd9
# Added AlphaFold job for holo: 2cdb
# Q53W82 4jp3
# Added AlphaFold job for apo: 4jp2
# Added AlphaFold job for holo: 4jp3
# Q60381 2j9e
# Added AlphaFold job for apo: 2j9d
# Added AlphaFold job for holo: 2j9e
# P00383 2rk1
# Added AlphaFold job for apo: 2rh2
# Added AlphaFold job for holo: 2rk1
# O28028 7uld
# Added AlphaFold job for apo: 2g9i
# Added AlphaFold job for holo: 7uld
# P56431 2q0k
# Added AlphaFold job for apo: 3ish
# Added AlphaFold job for holo: 2q0k
# Q15GI4 2qw8
# Added AlphaFold job for apo: 2qys
# Added AlphaFold job for holo: 2qw8
# P53355 4pf4
# Added AlphaFold job for apo: 1jks
# Added AlphaFold job for holo: 4pf4
# Q13WK4 2y5d
# Added AlphaFold job for apo: 2y51
# Added AlphaFold job for holo: 2y5d
# P0ABQ4 8uw0
# Added AlphaFold job for apo: 3k74
# Added AlphaFold job for holo: 8uw0
# Q9Y259 3lq3
# Added AlphaFold job for apo: 2ig7
# Added AlphaFold job for holo: 3lq3
# Q6FNA9 3g59
# Added AlphaFold job for apo: 3fwk
# Added AlphaFold job for holo: 3g59
# P62826 7mo5
# Added AlphaFold job for apo: 2n1b
# Added AlphaFold job for holo: 7mo5
# Q8E565 3keq
# Added AlphaFold job for apo: 3keq
# Added AlphaFold job for holo: 3keq
# P70731 4cnz
# Added AlphaFold job for apo: 4co3
# Added AlphaFold job for holo: 4cnz
# Q93NW7 3mjs
# Added AlphaFold job for apo: 3mjc
# Added AlphaFold job for holo: 3mjs
# G3XD33 5iqx
# Added AlphaFold job for apo: 3mok
# Added AlphaFold job for holo: 5iqx
# O28527 3ncr
# Added AlphaFold job for apo: 3ncp
# Added AlphaFold job for holo: 3ncr
# P54616 3oif
# Added AlphaFold job for apo: 3oif
# Added AlphaFold job for holo: 3oif
# D0VWQ0 5b4t
# Added AlphaFold job for apo: 2yz7
# Added AlphaFold job for holo: 5b4t
# O15530 5lvo
# Added AlphaFold job for apo: 8dqt
# Added AlphaFold job for holo: 5lvo
# Q8TX37 4bga
# Added AlphaFold job for apo: 4bg9
# Added AlphaFold job for holo: 4bga
# C4LW95 4up3
# Added AlphaFold job for apo: 4ccr
# Added AlphaFold job for holo: 4up3
# Q9HZN8 3uwk
# Added AlphaFold job for apo: 3uxm
# Added AlphaFold job for holo: 3uwk
# P01116 8onv
# Added AlphaFold job for apo: 6epp
# Added AlphaFold job for holo: 8onv
# Q9WYT0 4gta
# Added AlphaFold job for apo: 5chp
# Added AlphaFold job for holo: 4gta
# A0A0H3KNE7 4gkb
# Added AlphaFold job for apo: 4gkb
# Added AlphaFold job for holo: 4gkb
# O66490 4jl5
# Added AlphaFold job for apo: 2rh5
# Added AlphaFold job for holo: 4jl5
# P37344 4qnr
# Added AlphaFold job for apo: 7qv9
# Added AlphaFold job for holo: 4qnr
# P9WGR1 4ohu
# Added AlphaFold job for apo: 4trm
# Added AlphaFold job for holo: 4ohu
# O68098 5c4n
# Added AlphaFold job for apo: 5c4r
# Added AlphaFold job for holo: 5c4n
# G8NVB5 4xye
# Added AlphaFold job for apo: 4xyg
# Added AlphaFold job for holo: 4xye
# P15452 5aus
# Added AlphaFold job for apo: 4zid
# Added AlphaFold job for holo: 5aus
# P0A9S1 7r3d
# Added AlphaFold job for apo: 7qni
# Added AlphaFold job for holo: 7r3d
# O24146 5bst
# Added AlphaFold job for apo: 5u95
# Added AlphaFold job for holo: 5bst
# P61586 6v6u
# Added AlphaFold job for apo: 7g90
# Added AlphaFold job for holo: 6v6u
# Q92NR7 4pmj
# Added AlphaFold job for apo: 4xap
# Added AlphaFold job for holo: 4pmj
# Q9HY79 6nlg
# Added AlphaFold job for apo: 6nlf
# Added AlphaFold job for holo: 6nlg
# K7WDL7 5dcy
# Added AlphaFold job for apo: 5dcw
# Added AlphaFold job for holo: 5dcy
# A0A0A1EQY0 6d4b
# Added AlphaFold job for apo: 5dna
# Added AlphaFold job for holo: 6d4b
# A0A0H3AER7 5f0z
# Added AlphaFold job for apo: 5ey7
# Added AlphaFold job for holo: 5f0z
# Q97UL5 5gme
# Added AlphaFold job for apo: 4z7y
# Added AlphaFold job for holo: 5gme
# O32553 5iwu
# Added AlphaFold job for apo: 5uxa
# Added AlphaFold job for holo: 5iwu
# G0YYQ5 5jbg
# Added AlphaFold job for apo: 5jbj
# Added AlphaFold job for holo: 5jbg
# G9VYV4 5l3z
# Added AlphaFold job for apo: 5l40
# Added AlphaFold job for holo: 5l3z
# Q8ZPX9 5luh
# Added AlphaFold job for apo: 4cs6
# Added AlphaFold job for holo: 5luh
# P05164 6bmt
# Added AlphaFold job for apo: 6azp
# Added AlphaFold job for holo: 6bmt
# Q9BPX1 6h0m
# Added AlphaFold job for apo: 5ics
# Added AlphaFold job for holo: 6h0m
# P9WP23 5ugv
# Added AlphaFold job for apo: 1yl5
# Added AlphaFold job for holo: 5ugv
# P50743 2hjg
# Added AlphaFold job for apo: 4dcv
# Added AlphaFold job for holo: 2hjg
# A0QUZ2 6m65
# Added AlphaFold job for apo: 5ggb
# Added AlphaFold job for holo: 6m65
# P00099 2exv
# Added AlphaFold job for apo: 3x39
# Added AlphaFold job for holo: 2exv
# D6PBM7 5y1g
# Added AlphaFold job for apo: 5y1d
# Added AlphaFold job for holo: 5y1g
# Q8E3E8 4qx6
# Added AlphaFold job for apo: 6iep
# Added AlphaFold job for holo: 4qx6
# Q9BQ65 5v1m
# Added AlphaFold job for apo: 4h7w
# Added AlphaFold job for holo: 5v1m
# P00720 6qaj
# Added AlphaFold job for apo: 6zx9
# Added AlphaFold job for holo: 6qaj
# Q03555 6fgd
# Added AlphaFold job for apo: 4pd0
# Added AlphaFold job for holo: 6fgd
# Q15286 6ekk
# Added AlphaFold job for apo: 3tw8
# Added AlphaFold job for holo: 6ekk
# Q8NTB9 6jsc
# Added AlphaFold job for apo: 6jsd
# Added AlphaFold job for holo: 6jsc
# B5II98 6ntb
# Added AlphaFold job for apo: 6n4a
# Added AlphaFold job for holo: 6ntb
# P9WFG7 6r3y
# Added AlphaFold job for apo: 2fr2
# Added AlphaFold job for holo: 6r3y
# A0A024B7W1 5y6n
# Added AlphaFold job for apo: 5jmt
# Added AlphaFold job for holo: 5y6n
# P0CE13 6ok4
# Added AlphaFold job for apo: 6x2e
# Added AlphaFold job for holo: 6ok4
# F7X6I3 6x9a
# Added AlphaFold job for apo: 6x99
# Added AlphaFold job for holo: 6x9a
# P49366 8a0f
# Added AlphaFold job for apo: 6xxh
# Added AlphaFold job for holo: 8a0f
# P0DSP4 7d4o
# Added AlphaFold job for apo: 7d48
# Added AlphaFold job for holo: 7d4o
# S9Q235 7qzn
# Added AlphaFold job for apo: 6iau
# Added AlphaFold job for holo: 7qzn
# P0A6Y8 7kru
# Added AlphaFold job for apo: 1dkg
# Added AlphaFold job for holo: 7kru
# Q5SLG6 3apt
# Added AlphaFold job for apo: 8eac
# Added AlphaFold job for holo: 3apt
# A0A0L0P1H8 8crh
# Added AlphaFold job for apo: 7zzx
# Added AlphaFold job for holo: 8crh
# O74036 5j4l
# Added AlphaFold job for apo: 6tuu
# Added AlphaFold job for holo: 5j4l
# Q9Y231 8d0u
# Added AlphaFold job for apo: 8d0p
# Added AlphaFold job for holo: 8d0u
# A0A0H3FR62 8u96
# Added AlphaFold job for apo: 8sbn
# Added AlphaFold job for holo: 8u96
# A0A0H3GVQ7 9b20
# Added AlphaFold job for apo: 9b1z
# Added AlphaFold job for holo: 9b20
# 180
# Saved 30 jobs to AlphaFold_jobs_part_1.json
# Saved 30 jobs to AlphaFold_jobs_part_2.json
# Saved 30 jobs to AlphaFold_jobs_part_3.json
# Saved 30 jobs to AlphaFold_jobs_part_4.json
# Saved 30 jobs to AlphaFold_jobs_part_5.json
# Saved 30 jobs to AlphaFold_jobs_part_6.json

# %% [markdown]
# # Išpakuojame prognozuotas struktūras

# %%
# !mkdir /content/all_folds
# !unzip /content/folds_2025_04_16_12_36_part_1.zip -d /content/all_folds
# !unzip /content/folds_2025_04_16_12_45_part_2.zip -d /content/all_folds
# !unzip /content/folds_2025_04_17_08_00_part_3.zip -d /content/all_folds
#   inflating: /content/all_folds/4b1y_holo/fold_4b1y_holo_summary_confidences_0.json
#   inflating: /content/all_folds/4b1y_holo/fold_4b1y_holo_full_data_0.json
#   inflating: /content/all_folds/4b1y_holo/fold_4b1y_holo_model_1.cif
#   inflating: /content/all_folds/4b1y_holo/fold_4b1y_holo_summary_confidences_1.json
#   inflating: /content/all_folds/4b1y_holo/fold_4b1y_holo_full_data_1.json
#   inflating: /content/all_folds/4b1y_holo/fold_4b1y_holo_model_2.cif
#   inflating: /content/all_folds/4b1y_holo/fold_4b1y_holo_summary_confidences_2.json
#   inflating: /content/all_folds/4b1y_holo/fold_4b1y_holo_full_data_2.json
#   inflating: /content/all_folds/4b1y_holo/fold_4b1y_holo_model_3.cif
#   inflating: /content/all_folds/4b1y_holo/fold_4b1y_holo_summary_confidences_3.json
#   inflating: /content/all_folds/4b1y_holo/fold_4b1y_holo_full_data_3.json
#   inflating: /content/all_folds/4b1y_holo/fold_4b1y_holo_model_4.cif
#   inflating: /content/all_folds/4b1y_holo/fold_4b1y_holo_summary_confidences_4.json
#   inflating: /content/all_folds/4b1y_holo/fold_4b1y_holo_full_data_4.json
#   inflating: /content/all_folds/6dyf_holo/fold_6dyf_holo_job_request.json
#   inflating: /content/all_folds/6dyf_holo/fold_6dyf_holo_model_0.cif
#   inflating: /content/all_folds/6dyf_holo/fold_6dyf_holo_summary_confidences_0.json
#   inflating: /content/all_folds/6dyf_holo/fold_6dyf_holo_full_data_0.json
#   inflating: /content/all_folds/6dyf_holo/fold_6dyf_holo_model_1.cif
#   inflating: /content/all_folds/6dyf_holo/fold_6dyf_holo_summary_confidences_1.json
#   inflating: /content/all_folds/6dyf_holo/fold_6dyf_holo_full_data_1.json
#   inflating: /content/all_folds/6dyf_holo/fold_6dyf_holo_model_2.cif
#   inflating: /content/all_folds/6dyf_holo/fold_6dyf_holo_summary_confidences_2.json
#   inflating: /content/all_folds/6dyf_holo/fold_6dyf_holo_full_data_2.json
#   inflating: /content/all_folds/6dyf_holo/fold_6dyf_holo_model_3.cif
#   inflating: /content/all_folds/6dyf_holo/fold_6dyf_holo_summary_confidences_3.json
#   inflating: /content/all_folds/6dyf_holo/fold_6dyf_holo_full_data_3.json
#   inflating: /content/all_folds/6dyf_holo/fold_6dyf_holo_model_4.cif
#   inflating: /content/all_folds/6dyf_holo/fold_6dyf_holo_summary_confidences_4.json
#   inflating: /content/all_folds/6dyf_holo/fold_6dyf_holo_full_data_4.json
#   inflating: /content/all_folds/2bcg_holo/fold_2bcg_holo_job_request.json
#   inflating: /content/all_folds/2bcg_holo/fold_2bcg_holo_model_0.cif
#   inflating: /content/all_folds/2bcg_holo/fold_2bcg_holo_summary_confidences_0.json
#   inflating: /content/all_folds/2bcg_holo/fold_2bcg_holo_full_data_0.json
#   inflating: /content/all_folds/2bcg_holo/fold_2bcg_holo_model_1.cif
#   inflating: /content/all_folds/2bcg_holo/fold_2bcg_holo_summary_confidences_1.json
#   inflating: /content/all_folds/2bcg_holo/fold_2bcg_holo_full_data_1.json
#   inflating: /content/all_folds/2bcg_holo/fold_2bcg_holo_model_2.cif
#   inflating: /content/all_folds/2bcg_holo/fold_2bcg_holo_summary_confidences_2.json
#   inflating: /content/all_folds/2bcg_holo/fold_2bcg_holo_full_data_2.json
#   inflating: /content/all_folds/2bcg_holo/fold_2bcg_holo_model_3.cif
#   inflating: /content/all_folds/2bcg_holo/fold_2bcg_holo_summary_confidences_3.json
#   inflating: /content/all_folds/2bcg_holo/fold_2bcg_holo_full_data_3.json
#   inflating: /content/all_folds/2bcg_holo/fold_2bcg_holo_model_4.cif
#   inflating: /content/all_folds/2bcg_holo/fold_2bcg_holo_summary_confidences_4.json
#   inflating: /content/all_folds/2bcg_holo/fold_2bcg_holo_full_data_4.json
#   inflating: /content/all_folds/8dr9_holo/fold_8dr9_holo_job_request.json
#   inflating: /content/all_folds/8dr9_holo/fold_8dr9_holo_model_0.cif
#   inflating: /content/all_folds/8dr9_holo/fold_8dr9_holo_summary_confidences_0.json
#   inflating: /content/all_folds/8dr9_holo/fold_8dr9_holo_full_data_0.json
#   inflating: /content/all_folds/8dr9_holo/fold_8dr9_holo_model_1.cif
#   inflating: /content/all_folds/8dr9_holo/fold_8dr9_holo_summary_confidences_1.json
#   inflating: /content/all_folds/8dr9_holo/fold_8dr9_holo_full_data_1.json
#   inflating: /content/all_folds/8dr9_holo/fold_8dr9_holo_model_2.cif
#   inflating: /content/all_folds/8dr9_holo/fold_8dr9_holo_summary_confidences_2.json
#   inflating: /content/all_folds/8dr9_holo/fold_8dr9_holo_full_data_2.json
#   inflating: /content/all_folds/8dr9_holo/fold_8dr9_holo_model_3.cif
#   inflating: /content/all_folds/8dr9_holo/fold_8dr9_holo_summary_confidences_3.json
#   inflating: /content/all_folds/8dr9_holo/fold_8dr9_holo_full_data_3.json
#   inflating: /content/all_folds/8dr9_holo/fold_8dr9_holo_model_4.cif
#   inflating: /content/all_folds/8dr9_holo/fold_8dr9_holo_summary_confidences_4.json
#   inflating: /content/all_folds/8dr9_holo/fold_8dr9_holo_full_data_4.json
#   inflating: /content/all_folds/2cnu_apo/fold_2cnu_apo_job_request.json
#   inflating: /content/all_folds/2cnu_apo/fold_2cnu_apo_model_0.cif
#   inflating: /content/all_folds/2cnu_apo/fold_2cnu_apo_summary_confidences_0.json
#   inflating: /content/all_folds/2cnu_apo/fold_2cnu_apo_full_data_0.json
#   inflating: /content/all_folds/2cnu_apo/fold_2cnu_apo_model_1.cif
#   inflating: /content/all_folds/2cnu_apo/fold_2cnu_apo_summary_confidences_1.json
#   inflating: /content/all_folds/2cnu_apo/fold_2cnu_apo_full_data_1.json
#   inflating: /content/all_folds/2cnu_apo/fold_2cnu_apo_model_2.cif
#   inflating: /content/all_folds/2cnu_apo/fold_2cnu_apo_summary_confidences_2.json
#   inflating: /content/all_folds/2cnu_apo/fold_2cnu_apo_full_data_2.json
#   inflating: /content/all_folds/2cnu_apo/fold_2cnu_apo_model_3.cif
#   inflating: /content/all_folds/2cnu_apo/fold_2cnu_apo_summary_confidences_3.json
#   inflating: /content/all_folds/2cnq_holo/fold_2cnq_holo_full_data_1.json
#   inflating: /content/all_folds/2cnq_holo/fold_2cnq_holo_model_2.cif
#   inflating: /content/all_folds/2cnq_holo/fold_2cnq_holo_summary_confidences_2.json
#   inflating: /content/all_folds/2cnq_holo/fold_2cnq_holo_full_data_2.json
#   inflating: /content/all_folds/2cnq_holo/fold_2cnq_holo_model_3.cif
#   inflating: /content/all_folds/2cnq_holo/fold_2cnq_holo_summary_confidences_3.json
#   inflating: /content/all_folds/2cnq_holo/fold_2cnq_holo_full_data_3.json
#   inflating: /content/all_folds/2cnq_holo/fold_2cnq_holo_model_4.cif
#   inflating: /content/all_folds/2cnq_holo/fold_2cnq_holo_summary_confidences_4.json
#   inflating: /content/all_folds/2cnq_holo/fold_2cnq_holo_full_data_4.json
#   inflating: /content/all_folds/6tn5_holo/fold_6tn5_holo_job_request.json
#   inflating: /content/all_folds/6tn5_holo/fold_6tn5_holo_model_0.cif
#   inflating: /content/all_folds/6tn5_holo/fold_6tn5_holo_summary_confidences_0.json
#   inflating: /content/all_folds/6tn5_holo/fold_6tn5_holo_full_data_0.json
#   inflating: /content/all_folds/6tn5_holo/fold_6tn5_holo_model_1.cif
#   inflating: /content/all_folds/6tn5_holo/fold_6tn5_holo_summary_confidences_1.json
#   inflating: /content/all_folds/6tn5_holo/fold_6tn5_holo_full_data_1.json
#   inflating: /content/all_folds/6tn5_holo/fold_6tn5_holo_model_2.cif
#   inflating: /content/all_folds/6tn5_holo/fold_6tn5_holo_summary_confidences_2.json
#   inflating: /content/all_folds/6tn5_holo/fold_6tn5_holo_full_data_2.json
#   inflating: /content/all_folds/6tn5_holo/fold_6tn5_holo_model_3.cif
#   inflating: /content/all_folds/6tn5_holo/fold_6tn5_holo_summary_confidences_3.json
#   inflating: /content/all_folds/6tn5_holo/fold_6tn5_holo_full_data_3.json
#   inflating: /content/all_folds/6tn5_holo/fold_6tn5_holo_model_4.cif
#   inflating: /content/all_folds/6tn5_holo/fold_6tn5_holo_summary_confidences_4.json
#   inflating: /content/all_folds/6tn5_holo/fold_6tn5_holo_full_data_4.json
#   inflating: /content/all_folds/1kmv_holo/fold_1kmv_holo_job_request.json
#   inflating: /content/all_folds/1kmv_holo/fold_1kmv_holo_model_0.cif
#   inflating: /content/all_folds/1kmv_holo/fold_1kmv_holo_summary_confidences_0.json
#   inflating: /content/all_folds/1kmv_holo/fold_1kmv_holo_full_data_0.json
#   inflating: /content/all_folds/1kmv_holo/fold_1kmv_holo_model_1.cif
#   inflating: /content/all_folds/1kmv_holo/fold_1kmv_holo_summary_confidences_1.json
#   inflating: /content/all_folds/1kmv_holo/fold_1kmv_holo_full_data_1.json
#   inflating: /content/all_folds/1kmv_holo/fold_1kmv_holo_model_2.cif
#   inflating: /content/all_folds/1kmv_holo/fold_1kmv_holo_summary_confidences_2.json
#   inflating: /content/all_folds/1kmv_holo/fold_1kmv_holo_full_data_2.json
#   inflating: /content/all_folds/1kmv_holo/fold_1kmv_holo_model_3.cif
#   inflating: /content/all_folds/1kmv_holo/fold_1kmv_holo_summary_confidences_3.json
#   inflating: /content/all_folds/1kmv_holo/fold_1kmv_holo_full_data_3.json
#   inflating: /content/all_folds/1kmv_holo/fold_1kmv_holo_model_4.cif
#   inflating: /content/all_folds/1kmv_holo/fold_1kmv_holo_summary_confidences_4.json
#   inflating: /content/all_folds/1kmv_holo/fold_1kmv_holo_full_data_4.json
#   inflating: /content/all_folds/2ofm_apo/fold_2ofm_apo_job_request.json
#   inflating: /content/all_folds/2ofm_apo/fold_2ofm_apo_model_0.cif
#   inflating: /content/all_folds/2ofm_apo/fold_2ofm_apo_summary_confidences_0.json
#   inflating: /content/all_folds/2ofm_apo/fold_2ofm_apo_full_data_0.json
#   inflating: /content/all_folds/2ofm_apo/fold_2ofm_apo_model_1.cif
#   inflating: /content/all_folds/2ofm_apo/fold_2ofm_apo_summary_confidences_1.json
#   inflating: /content/all_folds/2ofm_apo/fold_2ofm_apo_full_data_1.json
#   inflating: /content/all_folds/2ofm_apo/fold_2ofm_apo_model_2.cif
#   inflating: /content/all_folds/2ofm_apo/fold_2ofm_apo_summary_confidences_2.json
#   inflating: /content/all_folds/2ofm_apo/fold_2ofm_apo_full_data_2.json
#   inflating: /content/all_folds/2ofm_apo/fold_2ofm_apo_model_3.cif
#   inflating: /content/all_folds/2ofm_apo/fold_2ofm_apo_summary_confidences_3.json
#   inflating: /content/all_folds/2ofm_apo/fold_2ofm_apo_full_data_3.json
#   inflating: /content/all_folds/2ofm_apo/fold_2ofm_apo_model_4.cif
#   inflating: /content/all_folds/2ofm_apo/fold_2ofm_apo_summary_confidences_4.json
#   inflating: /content/all_folds/2ofm_apo/fold_2ofm_apo_full_data_4.json
#   inflating: /content/all_folds/1gfs_apo/fold_1gfs_apo_job_request.json
#   inflating: /content/all_folds/1gfs_apo/fold_1gfs_apo_model_0.cif
#   inflating: /content/all_folds/1gfs_apo/fold_1gfs_apo_summary_confidences_0.json
#   inflating: /content/all_folds/1gfs_apo/fold_1gfs_apo_full_data_0.json
#   inflating: /content/all_folds/1gfs_apo/fold_1gfs_apo_model_1.cif
#   inflating: /content/all_folds/1gfs_apo/fold_1gfs_apo_summary_confidences_1.json
#   inflating: /content/all_folds/1gfs_apo/fold_1gfs_apo_full_data_1.json
#   inflating: /content/all_folds/1gfs_apo/fold_1gfs_apo_model_2.cif
#   inflating: /content/all_folds/1gfs_apo/fold_1gfs_apo_summary_confidences_2.json
#   inflating: /content/all_folds/1gfs_apo/fold_1gfs_apo_full_data_2.json
#   inflating: /content/all_folds/1gfs_apo/fold_1gfs_apo_model_3.cif
#   inflating: /content/all_folds/1gfs_apo/fold_1gfs_apo_summary_confidences_3.json
#   inflating: /content/all_folds/1gfs_apo/fold_1gfs_apo_full_data_3.json
#   inflating: /content/all_folds/1gfs_apo/fold_1gfs_apo_model_4.cif
#   inflating: /content/all_folds/1gfs_apo/fold_1gfs_apo_summary_confidences_4.json
#   inflating: /content/all_folds/1gfs_apo/fold_1gfs_apo_full_data_4.json
#   inflating: /content/all_folds/5vmm_apo/fold_5vmm_apo_job_request.json
#   inflating: /content/all_folds/5vmm_apo/fold_5vmm_apo_model_0.cif
#   inflating: /content/all_folds/5vmm_apo/fold_5vmm_apo_summary_confidences_0.json
#   inflating: /content/all_folds/5vmm_apo/fold_5vmm_apo_full_data_0.json
#   inflating: /content/all_folds/5vmm_apo/fold_5vmm_apo_model_1.cif
#   inflating: /content/all_folds/5vmm_apo/fold_5vmm_apo_summary_confidences_1.json
#   inflating: /content/all_folds/5vmm_apo/fold_5vmm_apo_full_data_1.json
#   inflating: /content/all_folds/5vmm_apo/fold_5vmm_apo_model_2.cif
#   inflating: /content/all_folds/5vmm_apo/fold_5vmm_apo_summary_confidences_2.json
#   inflating: /content/all_folds/5vmm_apo/fold_5vmm_apo_full_data_2.json
#   inflating: /content/all_folds/5vmm_apo/fold_5vmm_apo_model_3.cif
#   inflating: /content/all_folds/5vmm_apo/fold_5vmm_apo_summary_confidences_3.json
#   inflating: /content/all_folds/5vmm_apo/fold_5vmm_apo_full_data_3.json
#   inflating: /content/all_folds/5vmm_apo/fold_5vmm_apo_model_4.cif
#   inflating: /content/all_folds/5vmm_apo/fold_5vmm_apo_summary_confidences_4.json
#   inflating: /content/all_folds/5vmm_apo/fold_5vmm_apo_full_data_4.json
#   inflating: /content/all_folds/1us0_holo/fold_1us0_holo_job_request.json
#   inflating: /content/all_folds/1us0_holo/fold_1us0_holo_model_0.cif
#   inflating: /content/all_folds/1us0_holo/fold_1us0_holo_summary_confidences_0.json
#   inflating: /content/all_folds/1us0_holo/fold_1us0_holo_full_data_0.json
#   inflating: /content/all_folds/1us0_holo/fold_1us0_holo_model_1.cif
#   inflating: /content/all_folds/1us0_holo/fold_1us0_holo_summary_confidences_1.json
#   inflating: /content/all_folds/1us0_holo/fold_1us0_holo_full_data_1.json
#   inflating: /content/all_folds/1us0_holo/fold_1us0_holo_model_2.cif
#   inflating: /content/all_folds/1us0_holo/fold_1us0_holo_summary_confidences_2.json
#   inflating: /content/all_folds/1us0_holo/fold_1us0_holo_full_data_2.json
#   inflating: /content/all_folds/1us0_holo/fold_1us0_holo_model_3.cif
#   inflating: /content/all_folds/1us0_holo/fold_1us0_holo_summary_confidences_3.json
#   inflating: /content/all_folds/1us0_holo/fold_1us0_holo_full_data_3.json
#   inflating: /content/all_folds/1us0_holo/fold_1us0_holo_model_4.cif
#   inflating: /content/all_folds/1us0_holo/fold_1us0_holo_summary_confidences_4.json
#   inflating: /content/all_folds/1us0_holo/fold_1us0_holo_full_data_4.json
#   inflating: /content/all_folds/1xgk_holo/fold_1xgk_holo_job_request.json
#   inflating: /content/all_folds/1xgk_holo/fold_1xgk_holo_model_0.cif
#   inflating: /content/all_folds/1xgk_holo/fold_1xgk_holo_summary_confidences_0.json
#   inflating: /content/all_folds/1xgk_holo/fold_1xgk_holo_full_data_0.json
#   inflating: /content/all_folds/1xgk_holo/fold_1xgk_holo_model_1.cif
#   inflating: /content/all_folds/1xgk_holo/fold_1xgk_holo_summary_confidences_1.json
#   inflating: /content/all_folds/1xgk_holo/fold_1xgk_holo_full_data_1.json
#   inflating: /content/all_folds/1xgk_holo/fold_1xgk_holo_model_2.cif
#   inflating: /content/all_folds/1xgk_holo/fold_1xgk_holo_summary_confidences_2.json
#   inflating: /content/all_folds/1xgk_holo/fold_1xgk_holo_full_data_2.json
#   inflating: /content/all_folds/1xgk_holo/fold_1xgk_holo_model_3.cif
#   inflating: /content/all_folds/1xgk_holo/fold_1xgk_holo_summary_confidences_3.json
#   inflating: /content/all_folds/1xgk_holo/fold_1xgk_holo_full_data_3.json
#   inflating: /content/all_folds/1xgk_holo/fold_1xgk_holo_model_4.cif
#   inflating: /content/all_folds/1xgk_holo/fold_1xgk_holo_summary_confidences_4.json
#   inflating: /content/all_folds/1xgk_holo/fold_1xgk_holo_full_data_4.json
#   inflating: /content/all_folds/7u8k_apo/fold_7u8k_apo_job_request.json
#   inflating: /content/all_folds/7u8k_apo/fold_7u8k_apo_model_0.cif
#   inflating: /content/all_folds/7u8k_apo/fold_7u8k_apo_summary_confidences_0.json
#   inflating: /content/all_folds/7u8k_apo/fold_7u8k_apo_full_data_0.json
#   inflating: /content/all_folds/7u8k_apo/fold_7u8k_apo_model_1.cif
#   inflating: /content/all_folds/7u8k_apo/fold_7u8k_apo_summary_confidences_1.json
#   inflating: /content/all_folds/7u8k_apo/fold_7u8k_apo_full_data_1.json
#   inflating: /content/all_folds/7u8k_apo/fold_7u8k_apo_model_2.cif
#   inflating: /content/all_folds/7u8k_apo/fold_7u8k_apo_summary_confidences_2.json
#   inflating: /content/all_folds/7u8k_apo/fold_7u8k_apo_full_data_2.json
#   inflating: /content/all_folds/7u8k_apo/fold_7u8k_apo_model_3.cif
#   inflating: /content/all_folds/7u8k_apo/fold_7u8k_apo_summary_confidences_3.json
#   inflating: /content/all_folds/7u8k_apo/fold_7u8k_apo_full_data_3.json
#   inflating: /content/all_folds/7u8k_apo/fold_7u8k_apo_model_4.cif
#   inflating: /content/all_folds/7u8k_apo/fold_7u8k_apo_summary_confidences_4.json
#   inflating: /content/all_folds/7u8k_apo/fold_7u8k_apo_full_data_4.json
#   inflating: /content/all_folds/1m7h_holo/fold_1m7h_holo_job_request.json
#   inflating: /content/all_folds/1m7h_holo/fold_1m7h_holo_model_0.cif
#   inflating: /content/all_folds/1m7h_holo/fold_1m7h_holo_summary_confidences_0.json
#   inflating: /content/all_folds/1m7h_holo/fold_1m7h_holo_full_data_0.json
#   inflating: /content/all_folds/1m7h_holo/fold_1m7h_holo_model_1.cif
#   inflating: /content/all_folds/1m7h_holo/fold_1m7h_holo_summary_confidences_1.json
#   inflating: /content/all_folds/1m7h_holo/fold_1m7h_holo_full_data_1.json
#   inflating: /content/all_folds/1m7h_holo/fold_1m7h_holo_model_2.cif
#   inflating: /content/all_folds/1m7h_holo/fold_1m7h_holo_summary_confidences_2.json
#   inflating: /content/all_folds/1m7h_holo/fold_1m7h_holo_full_data_2.json
#   inflating: /content/all_folds/1pdb_apo/fold_1pdb_apo_model_3.cif
#   inflating: /content/all_folds/1pdb_apo/fold_1pdb_apo_summary_confidences_3.json
#   inflating: /content/all_folds/1pdb_apo/fold_1pdb_apo_full_data_3.json
#   inflating: /content/all_folds/1pdb_apo/fold_1pdb_apo_model_4.cif
#   inflating: /content/all_folds/1pdb_apo/fold_1pdb_apo_summary_confidences_4.json
#   inflating: /content/all_folds/1pdb_apo/fold_1pdb_apo_full_data_4.json
#   inflating: /content/all_folds/2w72_holo/fold_2w72_holo_job_request.json
#   inflating: /content/all_folds/2w72_holo/fold_2w72_holo_model_0.cif
#   inflating: /content/all_folds/2w72_holo/fold_2w72_holo_summary_confidences_0.json
#   inflating: /content/all_folds/2w72_holo/fold_2w72_holo_full_data_0.json
#   inflating: /content/all_folds/2w72_holo/fold_2w72_holo_model_1.cif
#   inflating: /content/all_folds/2w72_holo/fold_2w72_holo_summary_confidences_1.json
#   inflating: /content/all_folds/2w72_holo/fold_2w72_holo_full_data_1.json
#   inflating: /content/all_folds/2w72_holo/fold_2w72_holo_model_2.cif
#   inflating: /content/all_folds/2w72_holo/fold_2w72_holo_summary_confidences_2.json
#   inflating: /content/all_folds/2w72_holo/fold_2w72_holo_full_data_2.json
#   inflating: /content/all_folds/2w72_holo/fold_2w72_holo_model_3.cif
#   inflating: /content/all_folds/2w72_holo/fold_2w72_holo_summary_confidences_3.json
#   inflating: /content/all_folds/2w72_holo/fold_2w72_holo_full_data_3.json
#   inflating: /content/all_folds/2w72_holo/fold_2w72_holo_model_4.cif
#   inflating: /content/all_folds/2w72_holo/fold_2w72_holo_summary_confidences_4.json
#   inflating: /content/all_folds/2w72_holo/fold_2w72_holo_full_data_4.json
#   inflating: /content/all_folds/1x8q_holo/fold_1x8q_holo_job_request.json
#   inflating: /content/all_folds/1x8q_holo/fold_1x8q_holo_model_0.cif
#   inflating: /content/all_folds/1x8q_holo/fold_1x8q_holo_summary_confidences_0.json
#   inflating: /content/all_folds/1x8q_holo/fold_1x8q_holo_full_data_0.json
#   inflating: /content/all_folds/1x8q_holo/fold_1x8q_holo_model_1.cif
#   inflating: /content/all_folds/1x8q_holo/fold_1x8q_holo_summary_confidences_1.json
#   inflating: /content/all_folds/1x8q_holo/fold_1x8q_holo_full_data_1.json
#   inflating: /content/all_folds/1x8q_holo/fold_1x8q_holo_model_2.cif
#   inflating: /content/all_folds/1x8q_holo/fold_1x8q_holo_summary_confidences_2.json
#   inflating: /content/all_folds/1x8q_holo/fold_1x8q_holo_full_data_2.json
#   inflating: /content/all_folds/1x8q_holo/fold_1x8q_holo_model_3.cif
#   inflating: /content/all_folds/1x8q_holo/fold_1x8q_holo_summary_confidences_3.json
#   inflating: /content/all_folds/1x8q_holo/fold_1x8q_holo_full_data_3.json
#   inflating: /content/all_folds/1x8q_holo/fold_1x8q_holo_model_4.cif
#   inflating: /content/all_folds/1x8q_holo/fold_1x8q_holo_summary_confidences_4.json
#   inflating: /content/all_folds/1x8q_holo/fold_1x8q_holo_full_data_4.json
# Archive:  /content/folds_2025_04_16_12_45_part_2.zip
# replace /content/all_folds/terms_of_use.md? [y]es, [n]o, [A]ll, [N]one, [r]ename: A
#   inflating
#   inflating: /content/all_folds/1jks_apo/fold_1jks_apo_model_1.cif
#   inflating: /content/all_folds/1jks_apo/fold_1jks_apo_summary_confidences_1.json
#   inflating: /content/all_folds/1jks_apo/fold_1jks_apo_full_data_1.json
#   inflating: /content/all_folds/1jks_apo/fold_1jks_apo_model_2.cif
#   inflating: /content/all_folds/1jks_apo/fold_1jks_apo_summary_confidences_2.json
#   inflating: /content/all_folds/1jks_apo/fold_1jks_apo_full_data_2.json
#   inflating: /content/all_folds/1jks_apo/fold_1jks_apo_model_3.cif
#   inflating: /content/all_folds/1jks_apo/fold_1jks_apo_summary_confidences_3.json
#   inflating: /content/all_folds/1jks_apo/fold_1jks_apo_full_data_3.json
#   inflating: /content/all_folds/1jks_apo/fold_1jks_apo_model_4.cif
#   inflating: /content/all_folds/1jks_apo/fold_1jks_apo_summary_confidences_4.json
#   inflating: /content/all_folds/1jks_apo/fold_1jks_apo_full_data_4.json
#   inflating: /content/all_folds/2cd9_apo/fold_2cd9_apo_job_request.json
#   inflating: /content/all_folds/2cd9_apo/fold_2cd9_apo_model_0.cif
#   inflating: /content/all_folds/2cd9_apo/fold_2cd9_apo_summary_confidences_0.json
#   inflating: /content/all_folds/2cd9_apo/fold_2cd9_apo_full_data_0.json
#   inflating: /content/all_folds/2cd9_apo/fold_2cd9_apo_model_1.cif
#   inflating: /content/all_folds/2cd9_apo/fold_2cd9_apo_summary_confidences_1.json
#   inflating: /content/all_folds/2cd9_apo/fold_2cd9_apo_full_data_1.json
#   inflating: /content/all_folds/2cd9_apo/fold_2cd9_apo_model_2.cif
#   inflating: /content/all_folds/2cd9_apo/fold_2cd9_apo_summary_confidences_2.json
#   inflating: /content/all_folds/2cd9_apo/fold_2cd9_apo_full_data_2.json
#   inflating: /content/all_folds/2cd9_apo/fold_2cd9_apo_model_3.cif
#   inflating: /content/all_folds/2cd9_apo/fold_2cd9_apo_summary_confidences_3.json
#   inflating: /content/all_folds/2cd9_apo/fold_2cd9_apo_full_data_3.json
#   inflating: /content/all_folds/2cd9_apo/fold_2cd9_apo_model_4.cif
#   inflating: /content/all_folds/2cd9_apo/fold_2cd9_apo_summary_confidences_4.json
#   inflating: /content/all_folds/2cd9_apo/fold_2cd9_apo_full_data_4.json
#   inflating: /content/all_folds/2ig7_apo/fold_2ig7_apo_job_request.json
#   inflating: /content/all_folds/2ig7_apo/fold_2ig7_apo_model_0.cif
#   inflating: /content/all_folds/2ig7_apo/fold_2ig7_apo_summary_confidences_0.json
#   inflating: /content/all_folds/2ig7_apo/fold_2ig7_apo_full_data_0.json
#   inflating: /content/all_folds/2ig7_apo/fold_2ig7_apo_model_1.cif
#   inflating: /content/all_folds/2ig7_apo/fold_2ig7_apo_summary_confidences_1.json
#   inflating: /content/all_folds/2ig7_apo/fold_2ig7_apo_full_data_1.json
#   inflating: /content/all_folds/2ig7_apo/fold_2ig7_apo_model_2.cif
#   inflating: /content/all_folds/2ig7_apo/fold_2ig7_apo_summary_confidences_2.json
#   inflating: /content/all_folds/8u96_holo/fold_8u96_holo_summary_confidences_1.json
#   inflating: /content/all_folds/8u96_holo/fold_8u96_holo_full_data_1.json
#   inflating: /content/all_folds/8u96_holo/fold_8u96_holo_model_2.cif
#   inflating: /content/all_folds/8u96_holo/fold_8u96_holo_summary_confidences_2.json
#   inflating: /content/all_folds/8u96_holo/fold_8u96_holo_full_data_2.json
#   inflating: /content/all_folds/8u96_holo/fold_8u96_holo_model_3.cif
#   inflating: /content/all_folds/8u96_holo/fold_8u96_holo_summary_confidences_3.json
#   inflating: /content/all_folds/8u96_holo/fold_8u96_holo_full_data_3.json
#   inflating: /content/all_folds/8u96_holo/fold_8u96_holo_model_4.cif
#   inflating: /content/all_folds/8u96_holo/fold_8u96_holo_summary_confidences_4.json
#   inflating: /content/all_folds/8u96_holo/fold_8u96_holo_full_data_4.json
#   inflating: /content/all_folds/8sbn_apo/fold_8sbn_apo_job_request.json
#   inflating: /content/all_folds/8sbn_apo/fold_8sbn_apo_model_0.cif
#   inflating: /content/all_folds/8sbn_apo/fold_8sbn_apo_summary_confidences_0.json
#   inflating: /content/all_folds/8sbn_apo/fold_8sbn_apo_full_data_0.json
#   inflating: /content/all_folds/8sbn_apo/fold_8sbn_apo_model_1.cif
#   inflating: /content/all_folds/8sbn_apo/fold_8sbn_apo_summary_confidences_1.json
#   inflating: /content/all_folds/8sbn_apo/fold_8sbn_apo_full_data_1.json
#   inflating: /content/all_folds/8sbn_apo/fold_8sbn_apo_model_2.cif
#   inflating: /content/all_folds/8sbn_apo/fold_8sbn_apo_summary_confidences_2.json
#   inflating: /content/all_folds/8sbn_apo/fold_8sbn_apo_full_data_2.json
#   inflating: /content/all_folds/8sbn_apo/fold_8sbn_apo_model_3.cif
#   inflating: /content/all_folds/8sbn_apo/fold_8sbn_apo_summary_confidences_3.json
#   inflating: /content/all_folds/8sbn_apo/fold_8sbn_apo_full_data_3.json
#   inflating: /content/all_folds/8sbn_apo/fold_8sbn_apo_model_4.cif
#   inflating: /content/all_folds/8sbn_apo/fold_8sbn_apo_summary_confidences_4.json
#   inflating: /content/all_folds/8sbn_apo/fold_8sbn_apo_full_data_4.json
#   inflating: /content/all_folds/7d4o_holo/fold_7d4o_holo_job_request.json
#   inflating: /content/all_folds/7d4o_holo/fold_7d4o_holo_model_0.cif
#   inflating: /content/all_folds/7d4o_holo/fold_7d4o_holo_summary_confidences_0.json
#   inflating: /content/all_folds/7d4o_holo/fold_7d4o_holo_full_data_0.json
#   inflating: /content/all_folds/7d4o_holo/fold_7d4o_holo_model_1.cif
#   inflating: /content/all_folds/7d4o_holo/fold_7d4o_holo_summary_confidences_1.json
#   inflating: /content/all_folds/7d4o_holo/fold_7d4o_holo_full_data_1.json
#   inflating: /content/all_folds/7d4o_holo/fold_7d4o_holo_model_2.cif
#   inflating: /content/all_folds/7d4o_holo/fold_7d4o_holo_summary_confidences_2.json
#   inflating: /content/all_folds/7d4o_holo/fold_7d4o_holo_full_data_2.json
#   inflating: /content/all_folds/7d4o_holo/fold_7d4o_holo_model_3.cif
#   inflating: /content/all_folds/9b20_holo/fold_9b20_holo_job_request.json
#   inflating: /content/all_folds/9b20_holo/fold_9b20_holo_model_0.cif
#   inflating: /content/all_folds/9b20_holo/fold_9b20_holo_summary_confidences_0.json
#   inflating: /content/all_folds/9b20_holo/fold_9b20_holo_full_data_0.json
#   inflating: /content/all_folds/9b20_holo/fold_9b20_holo_model_1.cif
#   inflating: /content/all_folds/9b20_holo/fold_9b20_holo_summary_confidences_1.json
#   inflating: /content/all_folds/9b20_holo/fold_9b20_holo_full_data_1.json
#   inflating: /content/all_folds/9b20_holo/fold_9b20_holo_model_2.cif
#   inflating: /content/all_folds/9b20_holo/fold_9b20_holo_summary_confidences_2.json
#   inflating: /content/all_folds/9b20_holo/fold_9b20_holo_full_data_2.json
#   inflating: /content/all_folds/9b20_holo/fold_9b20_holo_model_3.cif
#   inflating: /content/all_folds/9b20_holo/fold_9b20_holo_summary_confidences_3.json
#   inflating: /content/all_folds/9b20_holo/fold_9b20_holo_full_data_3.json
#   inflating: /content/all_folds/9b20_holo/fold_9b20_holo_model_4.cif
#   inflating: /content/all_folds/9b20_holo/fold_9b20_holo_summary_confidences_4.json
#   inflating: /content/all_folds/9b20_holo/fold_9b20_holo_full_data_4.json
#   inflating: /content/all_folds/6x2e_apo/fold_6x2e_apo_job_request.json
#   inflating: /content/all_folds/6x2e_apo/fold_6x2e_apo_model_0.cif
#   inflating: /content/all_folds/6x2e_apo/fold_6x2e_apo_summary_confidences_0.json
#   inflating: /content/all_folds/6x2e_apo/fold_6x2e_apo_full_data_0.json
#   inflating: /content/all_folds/6x2e_apo/fold_6x2e_apo_model_1.cif
#   inflating: /content/all_folds/6x2e_apo/fold_6x2e_apo_summary_confidences_1.json
#   inflating: /content/all_folds/6x2e_apo/fold_6x2e_apo_full_data_1.json
#   inflating: /content/all_folds/6x2e_apo/fold_6x2e_apo_model_2.cif
#   inflating: /content/all_folds/6x2e_apo/fold_6x2e_apo_summary_confidences_2.json
#   inflating: /content/all_folds/6x2e_apo/fold_6x2e_apo_full_data_2.json
#   inflating: /content/all_folds/6x2e_apo/fold_6x2e_apo_model_3.cif
#   inflating: /content/all_folds/6x2e_apo/fold_6x2e_apo_summary_confidences_3.json
#   inflating: /content/all_folds/6x2e_apo/fold_6x2e_apo_full_data_3.json
#   inflating: /content/all_folds/6x2e_apo/fold_6x2e_apo_model_4.cif
#   inflating: /content/all_folds/6x2e_apo/fold_6x2e_apo_summary_confidences_4.json
#   inflating: /content/all_folds/6x2e_apo/fold_6x2e_apo_full_data_4.json
#   inflating: /content/all_folds/7d48_apo/fold_7d48_apo_job_request.json
#   inflating: /content/all_folds/7d48_apo/fold_7d48_apo_model_0.cif
#   inflating: /content/all_folds/7d48_apo/fold_7d48_apo_summary_confidences_0.json
#   inflating: /content/all_folds/7d48_apo/fold_7d48_apo_full_data_0.json
#   inflating: /content/all_folds/7d48_apo/fold_7d48_apo_model_1.cif
#   inflating: /content/all_folds/7d48_apo/fold_7d48_apo_summary_confidences_1.json
#   inflating: /content/all_folds/6tuu_apo/fold_6tuu_apo_job_request.json
#   inflating: /content/all_folds/6tuu_apo/fold_6tuu_apo_model_0.cif
#   inflating: /content/all_folds/6tuu_apo/fold_6tuu_apo_summary_confidences_0.json
#   inflating: /content/all_folds/6tuu_apo/fold_6tuu_apo_full_data_0.json
#   inflating: /content/all_folds/6tuu_apo/fold_6tuu_apo_model_1.cif
#   inflating: /content/all_folds/6tuu_apo/fold_6tuu_apo_summary_confidences_1.json
#   inflating: /content/all_folds/6tuu_apo/fold_6tuu_apo_full_data_1.json
#   inflating: /content/all_folds/6tuu_apo/fold_6tuu_apo_model_2.cif
#   inflating: /content/all_folds/6tuu_apo/fold_6tuu_apo_summary_confidences_2.json
#   inflating: /content/all_folds/6tuu_apo/fold_6tuu_apo_full_data_2.json
#   inflating: /content/all_folds/6tuu_apo/fold_6tuu_apo_model_3.cif
#   inflating: /content/all_folds/6tuu_apo/fold_6tuu_apo_summary_confidences_3.json
#   inflating: /content/all_folds/6tuu_apo/fold_6tuu_apo_full_data_3.json
#   inflating: /content/all_folds/6tuu_apo/fold_6tuu_apo_model_4.cif
#   inflating: /content/all_folds/6tuu_apo/fold_6tuu_apo_summary_confidences_4.json
#   inflating: /content/all_folds/6tuu_apo/fold_6tuu_apo_full_data_4.json

# %% [markdown]
# # Skaičiuojame plDDt įverčius

# %%
import os
import json
import re

# Directory containing your JSON files
data_dir = "all_folds"

# Output TSV file
output_file = "plddt_results.tsv"

# 1. Discover all fold numbers across all folders
fold_numbers = set()
pattern = re.compile(r".*full_data_(\d+)\.json$")
for folder in os.listdir(data_dir):
    folder_path = os.path.join(data_dir, folder)
    if not os.path.isdir(folder_path):
        continue
    for filename in os.listdir(folder_path):
        m = pattern.match(filename)
        print(filename, m)
        if m:
            fold_numbers.add(int(m.group(1)))

# Sort so columns come out in numeric order
fold_numbers = sorted(fold_numbers)

# 2. Write header
with open(output_file, "w") as outfile:
    header = ["PDB_NAME"] + [f"PLDDT_{n}" for n in fold_numbers]
    outfile.write("\t".join(header) + "\n")

    # 3. Process each folder and collect averages
    for folder in os.listdir(data_dir):
        folder_path = os.path.join(data_dir, folder)
        if not os.path.isdir(folder_path):
            continue

        # compute avg pLDDT per fold in this folder
        avg_by_fold = {}
        for filename in os.listdir(folder_path):
            m = pattern.match(filename)
            if not m:
                continue
            fold_idx = int(m.group(1))
            json_path = os.path.join(folder_path, filename)
            with open(json_path, "r") as f:
                data = json.load(f)
            atom_plddts = data.get("atom_plddts", [])
            if atom_plddts:
                avg_plddt = sum(atom_plddts) / len(atom_plddts)
                avg_by_fold[fold_idx] = avg_plddt

        # build row: PDB name (uppercase) + values or blanks
        row = [folder.upper()]
        for n in fold_numbers:
            if n in avg_by_fold:
                row.append(f"{avg_by_fold[n]:.2f}")
            else:
                row.append("")  # or use "NA" if you prefer
        outfile.write("\t".join(row) + "\n")

print(f"pLDDT calculations completed. Results saved in {output_file}.")
# Out:
# fold_5jbj_apo_full_data_0.json <re.Match object; span=(0, 30), match='fold_5jbj_apo_full_data_0.json'>
# fold_5jbj_apo_model_1.cif None
# fold_5jbj_apo_summary_confidences_0.json None
# fold_5jbj_apo_full_data_2.json <re.Match object; span=(0, 30), match='fold_5jbj_apo_full_data_2.json'>
# fold_5jbj_apo_full_data_1.json <re.Match object; span=(0, 30), match='fold_5jbj_apo_full_data_1.json'>
# fold_5jbj_apo_full_data_3.json <re.Match object; span=(0, 30), match='fold_5jbj_apo_full_data_3.json'>
# fold_5jbj_apo_full_data_4.json <re.Match object; span=(0, 30), match='fold_5jbj_apo_full_data_4.json'>
# fold_5jbj_apo_model_4.cif None
# fold_5jbj_apo_model_2.cif None
# fold_5jbj_apo_job_request.json None
# fold_5jbj_apo_model_0.cif None
# fold_5jbj_apo_model_3.cif None
# fold_5jbj_apo_summary_confidences_2.json None
# fold_5jbj_apo_summary_confidences_1.json None
# fold_5jbj_apo_summary_confidences_4.json None
# fold_5jbj_apo_summary_confidences_3.json None
# fold_5iqx_holo_model_4.cif None
# fold_5iqx_holo_model_0.cif None
# fold_5iqx_holo_summary_confidences_0.json None
# fold_5iqx_holo_model_2.cif None
# fold_5iqx_holo_model_1.cif None
# fold_5iqx_holo_summary_confidences_1.json None
# fold_5iqx_holo_full_data_2.json <re.Match object; span=(0, 31), match='fold_5iqx_holo_full_data_2.json'>
# fold_5iqx_holo_full_data_0.json <re.Match object; span=(0, 31), match='fold_5iqx_holo_full_data_0.json'>
# fold_5iqx_holo_summary_confidences_4.json None
# fold_5iqx_holo_job_request.json None
# fold_5iqx_holo_full_data_1.json <re.Match object; span=(0, 31), match='fold_5iqx_holo_full_data_1.json'>
# fold_5iqx_holo_full_data_4.json <re.Match object; span=(0, 31), match='fold_5iqx_holo_full_data_4.json'>
# fold_5iqx_holo_summary_confidences_2.json None
# fold_5iqx_holo_full_data_3.json <re.Match object; span=(0, 31), match='fold_5iqx_holo_full_data_3.json'>
# fold_5iqx_holo_model_3.cif None
# fold_5iqx_holo_summary_confidences_3.json None
# fold_1e7s_holo_job_request.json None
# fold_1e7s_holo_full_data_2.json <re.Match object; span=(0, 31), match='fold_1e7s_holo_full_data_2.json'>
# fold_1e7s_holo_model_4.cif None
# fold_1e7s_holo_summary_confidences_2.json None
# fold_1e7s_holo_full_data_4.json <re.Match object; span=(0, 31), match='fold_1e7s_holo_full_data_4.json'>
# fold_1e7s_holo_summary_confidences_4.json None
# fold_1e7s_holo_summary_confidences_3.json None
# fold_1e7s_holo_full_data_1.json <re.Match object; span=(0, 31), match='fold_1e7s_holo_full_data_1.json'>
# fold_1e7s_holo_full_data_3.json <re.Match object; span=(0, 31), match='fold_1e7s_holo_full_data_3.json'>
# fold_1e7s_holo_model_3.cif None
# fold_1e7s_holo_summary_confidences_0.json None
# fold_1e7s_holo_model_1.cif None
# fold_1e7s_holo_model_2.cif None
# fold_1e7s_holo_summary_confidences_1.json None
# fold_1e7s_holo_full_data_0.json <re.Match object; span=(0, 31), match='fold_1e7s_holo_full_data_0.json'>
# fold_1e7s_holo_model_0.cif None
# fold_5ggb_apo_full_data_0.json <re.Match object; span=(0, 30), match='fold_5ggb_apo_full_data_0.json'>
# fold_5ggb_apo_summary_confidences_1.json None
# fold_5ggb_apo_summary_confidences_0.json None
# fold_5ggb_apo_model_4.cif None
# fold_5ggb_apo_model_0.cif None
# fold_5ggb_apo_summary_confidences_4.json None
# fold_5ggb_apo_model_2.cif None
# fold_5ggb_apo_job_request.json None
# fold_5ggb_apo_full_data_2.json <re.Match object; span=(0, 30), match='fold_5ggb_apo_full_data_2.json'>
# fold_5ggb_apo_full_data_3.json <re.Match object; span=(0, 30), match='fold_5ggb_apo_full_data_3.json'>
# fold_5ggb_apo_summary_confidences_2.json None
# fold_5ggb_apo_full_data_1.json <re.Match object; span=(0, 30), match='fold_5ggb_apo_full_data_1.json'>
# fold_5ggb_apo_model_3.cif None
# fold_5ggb_apo_model_1.cif None
# fold_5ggb_apo_summary_confidences_3.json None
# fold_5ggb_apo_full_data_4.json <re.Match object; span=(0, 30), match='fold_5ggb_apo_full_data_4.json'>
# fold_1ufp_apo_full_data_1.json <re.Match object; span=(0, 30), match='fold_1ufp_apo_full_data_1.json'>
# fold_1ufp_apo_model_3.cif None
# fold_1ufp_apo_summary_confidences_1.json None
# fold_1ufp_apo_model_2.cif None
# fold_1ufp_apo_summary_confidences_2.json None
# fold_1ufp_apo_full_data_0.json <re.Match object; span=(0, 30), match='fold_1ufp_apo_full_data_0.json'>
# fold_1ufp_apo_summary_confidences_3.json None
# fold_1ufp_apo_summary_confidences_4.json None
# fold_1ufp_apo_model_4.cif None
# fold_1ufp_apo_model_1.cif None
# fold_1ufp_apo_job_request.json None
# fold_1ufp_apo_full_data_3.json <re.Match object; span=(0, 30), match='fold_1ufp_apo_full_data_3.json'>
# fold_1ufp_apo_full_data_4.json <re.Match object; span=(0, 30), match='fold_1ufp_apo_full_data_4.json'>
# fold_1ufp_apo_summary_confidences_0.json None
# fold_1ufp_apo_full_data_2.json <re.Match object; span=(0, 30), match='fold_1ufp_apo_full_data_2.json'>
# fold_1ufp_apo_model_0.cif None
# fold_4xyg_apo_full_data_4.json <re.Match object; span=(0, 30), match='fold_4xyg_apo_full_data_4.json'>
# fold_4xyg_apo_model_4.cif None
# fold_4xyg_apo_model_1.cif None
# fold_4xyg_apo_full_data_1.json <re.Match object; span=(0, 30), match='fold_4xyg_apo_full_data_1.json'>
# fold_4xyg_apo_job_request.json None
# fold_4xyg_apo_summary_confidences_1.json None
# fold_4xyg_apo_summary_confidences_3.json None
# fold_4xyg_apo_model_3.cif None
# fold_4xyg_apo_summary_confidences_2.json None
# fold_4xyg_apo_full_data_2.json <re.Match object; span=(0, 30), match='fold_4xyg_apo_full_data_2.json'>
# fold_4xyg_apo_model_2.cif None
# fold_4xyg_apo_summary_confidences_0.json None
# fold_4xyg_apo_full_data_3.json <re.Match object; span=(0, 30), match='fold_4xyg_apo_full_data_3.json'>
# fold_4xyg_apo_model_0.cif None
# fold_4xyg_apo_summary_confidences_4.json None
# fold_4xyg_apo_full_data_0.json <re.Match object; span=(0, 30), match='fold_4xyg_apo_full_data_0.json'>
# fold_8dqt_apo_model_0.cif None
# fold_8dqt_apo_model_4.cif None
# fold_8dqt_apo_job_request.json None
# fold_8dqt_apo_summary_confidences_1.json None
# fold_8dqt_apo_model_2.cif None
# fold_8dqt_apo_summary_confidences_4.json None
# fold_8dqt_apo_full_data_4.json <re.Match object; span=(0, 30), match='fold_8dqt_apo_full_data_4.json'>
# fold_8dqt_apo_full_data_3.json <re.Match object; span=(0, 30), match='fold_8dqt_apo_full_data_3.json'>
# fold_8dqt_apo_model_1.cif None
# fold_8dqt_apo_summary_confidences_2.json None
# fold_8dqt_apo_summary_confidences_3.json None
# fold_8dqt_apo_full_data_0.json <re.Match object; span=(0, 30), match='fold_8dqt_apo_full_data_0.json'>
# fold_8dqt_apo_full_data_1.json <re.Match object; span=(0, 30), match='fold_8dqt_apo_full_data_1.json'>
# fold_8dqt_apo_model_3.cif None
# fold_8dqt_apo_full_data_2.json <re.Match object; span=(0, 30), match='fold_8dqt_apo_full_data_2.json'>
# fold_8dqt_apo_summary_confidences_0.json None
# fold_2g9i_apo_model_1.cif None
# fold_2g9i_apo_summary_confidences_1.json None
# fold_2g9i_apo_summary_confidences_0.json None
# fold_2g9i_apo_job_request.json None
# fold_2g9i_apo_summary_confidences_3.json None
# fold_2g9i_apo_model_2.cif None
# fold_2g9i_apo_summary_confidences_4.json None
# fold_2g9i_apo_model_3.cif None
# fold_2g9i_apo_full_data_0.json <re.Match object; span=(0, 30), match='fold_2g9i_apo_full_data_0.json'>
# fold_2g9i_apo_full_data_2.json <re.Match object; span=(0, 30), match='fold_2g9i_apo_full_data_2.json'>
# fold_2g9i_apo_model_4.cif None
# fold_2g9i_apo_full_data_3.json <re.Match object; span=(0, 30), match='fold_2g9i_apo_full_data_3.json'>
# fold_2g9i_apo_model_0.cif None
# fold_2g9i_apo_full_data_1.json <re.Match object; span=(0, 30), match='fold_2g9i_apo_full_data_1.json'>
# fold_2g9i_apo_summary_confidences_2.json None
# fold_2g9i_apo_full_data_4.json <re.Match object; span=(0, 30), match='fold_2g9i_apo_full_data_4.json'>
# fold_2j46_holo_model_4.cif None
# fold_2j46_holo_model_3.cif None
# fold_2j46_holo_full_data_1.json <re.Match object; span=(0, 31), match='fold_2j46_holo_full_data_1.json'>
# fold_2j46_holo_job_request.json None
# fold_2j46_holo_summary_confidences_2.json None
# fold_2j46_holo_full_data_4.json <re.Match object; span=(0, 31), match='fold_2j46_holo_full_data_4.json'>
# fold_2j46_holo_model_2.cif None
# fold_2j46_holo_summary_confidences_4.json None
# fold_2j46_holo_model_1.cif None
# fold_2j46_holo_model_0.cif None
# fold_2j46_holo_full_data_0.json <re.Match object; span=(0, 31), match='fold_2j46_holo_full_data_0.json'>
# fold_2j46_holo_summary_confidences_1.json None
# fold_2j46_holo_full_data_2.json <re.Match object; span=(0, 31), match='fold_2j46_holo_full_data_2.json'>
# fold_2j46_holo_summary_confidences_3.json None
# fold_2j46_holo_summary_confidences_0.json None
# fold_2j46_holo_full_data_3.json <re.Match object; span=(0, 31), match='fold_2j46_holo_full_data_3.json'>
# fold_1jks_apo_summary_confidences_4.json None
# fold_1jks_apo_full_data_4.json <re.Match object; span=(0, 30), match='fold_1jks_apo_full_data_4.json'>
# fold_1jks_apo_full_data_2.json <re.Match object; span=(0, 30), match='fold_1jks_apo_full_data_2.json'>
# fold_1jks_apo_model_2.cif None
# fold_1jks_apo_full_data_1.json <re.Match object; span=(0, 30), match='fold_1jks_apo_full_data_1.json'>
# fold_1jks_apo_full_data_0.json <re.Match object; span=(0, 30), match='fold_1jks_apo_full_data_0.json'>
# fold_1jks_apo_summary_confidences_0.json None
# fold_1jks_apo_summary_confidences_2.json None
# fold_1jks_apo_summary_confidences_1.json None
# fold_1jks_apo_full_data_3.json <re.Match object; span=(0, 30), match='fold_1jks_apo_full_data_3.json'>
# fold_1jks_apo_job_request.json None
# fold_1jks_apo_model_4.cif None
# fold_1jks_apo_model_0.cif None
# fold_1jks_apo_model_1.cif None
# fold_1jks_apo_model_3.cif None
# fold_1jks_apo_summary_confidences_3.json None
# fold_2yz7_apo_summary_confidences_4.json None
# fold_2yz7_apo_full_data_2.json <re.Match object; span=(0, 30), match='fold_2yz7_apo_full_data_2.json'>
# fold_2yz7_apo_summary_confidences_1.json None
# fold_2yz7_apo_model_2.cif None
# fold_2yz7_apo_job_request.json None
# fold_2yz7_apo_model_1.cif None
# fold_2yz7_apo_model_0.cif None
# fold_2yz7_apo_full_data_0.json <re.Match object; span=(0, 30), match='fold_2yz7_apo_full_data_0.json'>
# fold_2yz7_apo_summary_confidences_0.json None
# fold_2yz7_apo_summary_confidences_3.json None
# fold_2yz7_apo_full_data_3.json <re.Match object; span=(0, 30), match='fold_2yz7_apo_full_data_3.json'>
# fold_2yz7_apo_summary_confidences_2.json None
# fold_2yz7_apo_model_3.cif None
# fold_2yz7_apo_model_4.cif None
# fold_2yz7_apo_full_data_4.json <re.Match object; span=(0, 30), match='fold_2yz7_apo_full_data_4.json'>
# fold_2yz7_apo_full_data_1.json <re.Match object; span=(0, 30), match='fold_2yz7_apo_full_data_1.json'>
# fold_2rk1_holo_model_4.cif None
# fold_2rk1_holo_job_request.json None
# fold_2rk1_holo_full_data_0.json <re.Match object; span=(0, 31), match='fold_2rk1_holo_full_data_0.json'>
# fold_2rk1_holo_full_data_4.json <re.Match object; span=(0, 31), match='fold_2rk1_holo_full_data_4.json'>
# fold_2rk1_holo_model_2.cif None
# fold_2rk1_holo_summary_confidences_0.json None
# fold_2rk1_holo_model_0.cif None
# fold_2rk1_holo_full_data_2.json <re.Match object; span=(0, 31), match='fold_2rk1_holo_full_data_2.json'>
# fold_2rk1_holo_summary_confidences_3.json None
# fold_2rk1_holo_model_1.cif None
# fold_2rk1_holo_summary_confidences_4.json None
# fold_2rk1_holo_full_data_3.json <re.Match object; span=(0, 31), match='fold_2rk1_holo_full_data_3.json'>
# fold_2rk1_holo_summary_confidences_1.json None
# fold_2rk1_holo_summary_confidences_2.json None
# fold_2rk1_holo_model_3.cif None
# fold_2rk1_holo_full_data_1.json <re.Match object; span=(0, 31), match='fold_2rk1_holo_full_data_1.json'>
# fold_5ics_apo_summary_confidences_1.json None
# fold_5ics_apo_summary_confidences_2.json None
# fold_5ics_apo_model_0.cif None
# fold_5ics_apo_full_data_1.json <re.Match object; span=(0, 30), match='fold_5ics_apo_full_data_1.json'>
# fold_5ics_apo_model_4.cif None
# fold_5ics_apo_model_2.cif None
# fold_5ics_apo_summary_confidences_3.json None
# fold_5ics_apo_summary_confidences_0.json None
# fold_5ics_apo_model_3.cif None
# fold_5ics_apo_model_1.cif None
# fold_5ics_apo_full_data_2.json <re.Match object; span=(0, 30), match='fold_5ics_apo_full_data_2.json'>
# fold_5ics_apo_job_request.json None
# fold_5ics_apo_full_data_4.json <re.Match object; span=(0, 30), match='fold_5ics_apo_full_data_4.json'>
# fold_5ics_apo_full_data_0.json <re.Match object; span=(0, 30), match='fold_5ics_apo_full_data_0.json'>
# fold_5ics_apo_full_data_3.json <re.Match object; span=(0, 30), match='fold_5ics_apo_full_data_3.json'>
# fold_5ics_apo_summary_confidences_4.json None
# fold_5dcw_apo_summary_confidences_3.json None
# fold_5dcw_apo_model_1.cif None
# fold_5dcw_apo_full_data_3.json <re.Match object; span=(0, 30), match='fold_5dcw_apo_full_data_3.json'>
# fold_5dcw_apo_summary_confidences_2.json None
# fold_5dcw_apo_model_4.cif None
# fold_5dcw_apo_full_data_0.json <re.Match object; span=(0, 30), match='fold_5dcw_apo_full_data_0.json'>
# fold_5dcw_apo_model_3.cif None
# fold_5dcw_apo_summary_confidences_4.json None
# fold_5dcw_apo_summary_confidences_1.json None
# fold_5dcw_apo_model_0.cif None
# fold_5dcw_apo_summary_confidences_0.json None
# fold_5dcw_apo_job_request.json None
# fold_5dcw_apo_full_data_4.json <re.Match object; span=(0, 30), match='fold_5dcw_apo_full_data_4.json'>
# fold_5dcw_apo_full_data_1.json <re.Match object; span=(0, 30), match='fold_5dcw_apo_full_data_1.json'>
# fold_5dcw_apo_model_2.cif None
# fold_5dcw_apo_full_data_2.json <re.Match object; span=(0, 30), match='fold_5dcw_apo_full_data_2.json'>
# fold_2w72_holo_summary_confidences_1.json None
# fold_2w72_holo_job_request.json None
# fold_2w72_holo_full_data_2.json <re.Match object; span=(0, 31), match='fold_2w72_holo_full_data_2.json'>
# fold_2w72_holo_full_data_4.json <re.Match object; span=(0, 31), match='fold_2w72_holo_full_data_4.json'>
# fold_2w72_holo_full_data_0.json <re.Match object; span=(0, 31), match='fold_2w72_holo_full_data_0.json'>
# fold_2w72_holo_summary_confidences_3.json None
# fold_2w72_holo_full_data_1.json <re.Match object; span=(0, 31), match='fold_2w72_holo_full_data_1.json'>
# fold_2w72_holo_model_0.cif None
# fold_2w72_holo_full_data_3.json <re.Match object; span=(0, 31), match='fold_2w72_holo_full_data_3.json'>
# fold_2w72_holo_summary_confidences_0.json None
# fold_2w72_holo_model_3.cif None
# fold_2w72_holo_model_2.cif None
# fold_2w72_holo_model_4.cif None
# fold_2w72_holo_summary_confidences_4.json None
# fold_2w72_holo_model_1.cif None
# fold_2w72_holo_summary_confidences_2.json None
# fold_5iwu_holo_full_data_2.json <re.Match object; span=(0, 31), match='fold_5iwu_holo_full_data_2.json'>
# fold_5iwu_holo_summary_confidences_3.json None
# fold_5iwu_holo_model_0.cif None
# fold_5iwu_holo_summary_confidences_0.json None
# fold_5iwu_holo_full_data_0.json <re.Match object; span=(0, 31), match='fold_5iwu_holo_full_data_0.json'>
# fold_5iwu_holo_summary_confidences_4.json None
# fold_5iwu_holo_model_4.cif None
# fold_5iwu_holo_model_3.cif None
# fold_5iwu_holo_model_2.cif None
# fold_5iwu_holo_full_data_4.json <re.Match object; span=(0, 31), match='fold_5iwu_holo_full_data_4.json'>
# fold_5iwu_holo_model_1.cif None
# fold_5iwu_holo_summary_confidences_2.json None
# fold_5iwu_holo_full_data_3.json <re.Match object; span=(0, 31), match='fold_5iwu_holo_full_data_3.json'>
# fold_5iwu_holo_job_request.json None
# fold_5iwu_holo_summary_confidences_1.json None
# fold_5iwu_holo_full_data_1.json <re.Match object; span=(0, 31), match='fold_5iwu_holo_full_data_1.json'>
# fold_1pdb_apo_full_data_3.json <re.Match object; span=(0, 30), match='fold_1pdb_apo_full_data_3.json'>
# fold_1pdb_apo_full_data_0.json <re.Match object; span=(0, 30), match='fold_1pdb_apo_full_data_0.json'>
# fold_1pdb_apo_full_data_4.json <re.Match object; span=(0, 30), match='fold_1pdb_apo_full_data_4.json'>
# fold_1pdb_apo_job_request.json None
# fold_1pdb_apo_full_data_1.json <re.Match object; span=(0, 30), match='fold_1pdb_apo_full_data_1.json'>
# fold_1pdb_apo_model_1.cif None
# fold_1pdb_apo_summary_confidences_4.json None
# fold_1pdb_apo_model_0.cif None
# fold_1pdb_apo_summary_confidences_3.json None
# fold_1pdb_apo_summary_confidences_0.json None
# fold_1pdb_apo_summary_confidences_1.json None
# fold_1pdb_apo_model_4.cif None
# fold_1pdb_apo_model_2.cif None
# fold_1pdb_apo_model_3.cif None
# fold_1pdb_apo_summary_confidences_2.json None
# fold_1pdb_apo_full_data_2.json <re.Match object; span=(0, 30), match='fold_1pdb_apo_full_data_2.json'>
# fold_6azp_apo_model_4.cif None
# fold_6azp_apo_summary_confidences_0.json None
# fold_6azp_apo_model_1.cif None
# fold_6azp_apo_full_data_3.json <re.Match object; span=(0, 30), match='fold_6azp_apo_full_data_3.json'>
# fold_6azp_apo_model_2.cif None
# fold_6azp_apo_summary_confidences_2.json None
# fold_6azp_apo_full_data_2.json <re.Match object; span=(0, 30), match='fold_6azp_apo_full_data_2.json'>
# fold_6azp_apo_job_request.json None
# fold_6azp_apo_full_data_0.json <re.Match object; span=(0, 30), match='fold_6azp_apo_full_data_0.json'>
# fold_6azp_apo_summary_confidences_1.json None
# fold_6azp_apo_full_data_4.json <re.Match object; span=(0, 30), match='fold_6azp_apo_full_data_4.json'>
# fold_6azp_apo_summary_confidences_4.json None
# fold_6azp_apo_model_3.cif None
# fold_6azp_apo_summary_confidences_3.json None
# fold_6azp_apo_full_data_1.json <re.Match object; span=(0, 30), match='fold_6azp_apo_full_data_1.json'>
# fold_6azp_apo_model_0.cif None
# fold_3k74_apo_summary_confidences_2.json None
# fold_3k74_apo_model_3.cif None
# fold_3k74_apo_summary_confidences_3.json None
# fold_3k74_apo_job_request.json None
# fold_3k74_apo_model_0.cif None
# fold_3k74_apo_model_2.cif None
# fold_3k74_apo_full_data_0.json <re.Match object; span=(0, 30), match='fold_3k74_apo_full_data_0.json'>
# fold_3k74_apo_summary_confidences_4.json None
# fold_3k74_apo_full_data_3.json <re.Match object; span=(0, 30), match='fold_3k74_apo_full_data_3.json'>
# fold_3k74_apo_summary_confidences_0.json None
# fold_3k74_apo_full_data_2.json <re.Match object; span=(0, 30), match='fold_3k74_apo_full_data_2.json'>
# fold_3k74_apo_model_4.cif None
# fold_3k74_apo_summary_confidences_1.json None
# fold_3k74_apo_full_data_4.json <re.Match object; span=(0, 30), match='fold_3k74_apo_full_data_4.json'>
# fold_3k74_apo_full_data_1.json <re.Match object; span=(0, 30), match='fold_3k74_apo_full_data_1.json'>
# fold_3k74_apo_model_1.cif None
# fold_4up3_holo_model_1.cif None
# fold_4up3_holo_model_2.cif None
# fold_4up3_holo_summary_confidences_3.json None
# fold_4up3_holo_full_data_4.json <re.Match object; span=(0, 31), match='fold_4up3_holo_full_data_4.json'>
# fold_4up3_holo_summary_confidences_0.json None
# fold_4up3_holo_summary_confidences_1.json None
# fold_4up3_holo_model_4.cif None
# fold_4up3_holo_job_request.json None
# fold_4up3_holo_model_0.cif None
# fold_4up3_holo_summary_confidences_4.json None
# fold_4up3_holo_model_3.cif None
# fold_4up3_holo_full_data_2.json <re.Match object; span=(0, 31), match='fold_4up3_holo_full_data_2.json'>
# fold_4up3_holo_full_data_1.json <re.Match object; span=(0, 31), match='fold_4up3_holo_full_data_1.json'>
# fold_4up3_holo_full_data_0.json <re.Match object; span=(0, 31), match='fold_4up3_holo_full_data_0.json'>
# fold_4up3_holo_full_data_3.json <re.Match object; span=(0, 31), match='fold_4up3_holo_full_data_3.json'>
# fold_4up3_holo_summary_confidences_2.json None
# fold_8dr9_holo_summary_confidences_4.json None
# fold_8dr9_holo_model_1.cif None
# fold_8dr9_holo_full_data_4.json <re.Match object; span=(0, 31), match='fold_8dr9_holo_full_data_4.json'>
# fold_8dr9_holo_full_data_3.json <re.Match object; span=(0, 31), match='fold_8dr9_holo_full_data_3.json'>
# fold_8dr9_holo_model_4.cif None
# fold_8dr9_holo_summary_confidences_0.json None
# fold_8dr9_holo_job_request.json None
# fold_8dr9_holo_model_3.cif None
# fold_8dr9_holo_model_2.cif None
# fold_8dr9_holo_summary_confidences_2.json None
# fold_8dr9_holo_model_0.cif None
# fold_8dr9_holo_full_data_2.json <re.Match object; span=(0, 31), match='fold_8dr9_holo_full_data_2.json'>
# fold_8dr9_holo_summary_confidences_3.json None
# fold_8dr9_holo_summary_confidences_1.json None
# fold_8dr9_holo_full_data_0.json <re.Match object; span=(0, 31), match='fold_8dr9_holo_full_data_0.json'>
# fold_8dr9_holo_full_data_1.json <re.Match object; span=(0, 31), match='fold_8dr9_holo_full_data_1.json'>
# fold_2cnu_apo_full_data_2.json <re.Match object; span=(0, 30), match='fold_2cnu_apo_full_data_2.json'>
# fold_2cnu_apo_job_request.json None
# fold_2cnu_apo_full_data_3.json <re.Match object; span=(0, 30), match='fold_2cnu_apo_full_data_3.json'>
# fold_2cnu_apo_model_3.cif None
# fold_2cnu_apo_model_2.cif None
# fold_2cnu_apo_summary_confidences_3.json None
# fold_2cnu_apo_summary_confidences_0.json None
# fold_2cnu_apo_summary_confidences_2.json None
# fold_2cnu_apo_full_data_0.json <re.Match object; span=(0, 30), match='fold_2cnu_apo_full_data_0.json'>
# fold_2cnu_apo_model_0.cif None
# fold_2cnu_apo_model_1.cif None
# fold_2cnu_apo_summary_confidences_4.json None
# fold_2cnu_apo_summary_confidences_1.json None
# fold_2cnu_apo_full_data_4.json <re.Match object; span=(0, 30), match='fold_2cnu_apo_full_data_4.json'>
# fold_2cnu_apo_model_4.cif None
# fold_2cnu_apo_full_data_1.json <re.Match object; span=(0, 30), match='fold_2cnu_apo_full_data_1.json'>
# fold_7g90_apo_summary_confidences_0.json None
# fold_7g90_apo_model_0.cif None
# fold_7g90_apo_full_data_2.json <re.Match object; span=(0, 30), match='fold_7g90_apo_full_data_2.json'>
# fold_7g90_apo_summary_confidences_3.json None
# fold_7g90_apo_summary_confidences_4.json None
# fold_7g90_apo_summary_confidences_1.json None
# fold_7g90_apo_full_data_0.json <re.Match object; span=(0, 30), match='fold_7g90_apo_full_data_0.json'>
# fold_7g90_apo_full_data_3.json <re.Match object; span=(0, 30), match='fold_7g90_apo_full_data_3.json'>
# fold_7g90_apo_job_request.json None
# fold_7g90_apo_full_data_1.json <re.Match object; span=(0, 30), match='fold_7g90_apo_full_data_1.json'>
# fold_7g90_apo_summary_confidences_2.json None
# fold_7g90_apo_model_4.cif None
# fold_7g90_apo_full_data_4.json <re.Match object; span=(0, 30), match='fold_7g90_apo_full_data_4.json'>
# fold_7g90_apo_model_2.cif None
# fold_7g90_apo_model_3.cif None
# fold_7g90_apo_model_1.cif None
# fold_6m65_holo_full_data_2.json <re.Match object; span=(0, 31), match='fold_6m65_holo_full_data_2.json'>
# fold_6m65_holo_full_data_4.json <re.Match object; span=(0, 31), match='fold_6m65_holo_full_data_4.json'>
# fold_6m65_holo_model_4.cif None
# fold_6m65_holo_full_data_1.json <re.Match object; span=(0, 31), match='fold_6m65_holo_full_data_1.json'>
# fold_6m65_holo_full_data_0.json <re.Match object; span=(0, 31), match='fold_6m65_holo_full_data_0.json'>
# fold_6m65_holo_summary_confidences_3.json None
# fold_6m65_holo_model_0.cif None
# fold_6m65_holo_model_3.cif None
# fold_6m65_holo_job_request.json None
# fold_6m65_holo_model_1.cif None
# fold_6m65_holo_model_2.cif None
# fold_6m65_holo_summary_confidences_4.json None
# fold_6m65_holo_summary_confidences_1.json None
# fold_6m65_holo_full_data_3.json <re.Match object; span=(0, 31), match='fold_6m65_holo_full_data_3.json'>
# fold_6m65_holo_summary_confidences_0.json None
# fold_6m65_holo_summary_confidences_2.json None
# fold_6r3y_holo_summary_confidences_2.json None
# fold_6r3y_holo_full_data_2.json <re.Match object; span=(0, 31), match='fold_6r3y_holo_full_data_2.json'>
# fold_6r3y_holo_summary_confidences_3.json None
# fold_6r3y_holo_job_request.json None
# fold_6r3y_holo_full_data_1.json <re.Match object; span=(0, 31), match='fold_6r3y_holo_full_data_1.json'>
# fold_6r3y_holo_model_0.cif None
# fold_6r3y_holo_full_data_4.json <re.Match object; span=(0, 31), match='fold_6r3y_holo_full_data_4.json'>
# fold_6r3y_holo_summary_confidences_0.json None
# fold_6r3y_holo_model_2.cif None
# fold_6r3y_holo_model_3.cif None
# fold_6r3y_holo_model_4.cif None
# fold_6r3y_holo_summary_confidences_1.json None
# fold_6r3y_holo_summary_confidences_4.json None
# fold_6r3y_holo_full_data_0.json <re.Match object; span=(0, 31), match='fold_6r3y_holo_full_data_0.json'>
# fold_6r3y_holo_model_1.cif None
# fold_6r3y_holo_full_data_3.json <re.Match object; span=(0, 31), match='fold_6r3y_holo_full_data_3.json'>
# fold_3keq_holo_summary_confidences_3.json None
# fold_3keq_holo_full_data_2.json <re.Match object; span=(0, 31), match='fold_3keq_holo_full_data_2.json'>
# fold_3keq_holo_summary_confidences_2.json None
# fold_3keq_holo_summary_confidences_0.json None
# fold_3keq_holo_full_data_0.json <re.Match object; span=(0, 31), match='fold_3keq_holo_full_data_0.json'>
# fold_3keq_holo_full_data_4.json <re.Match object; span=(0, 31), match='fold_3keq_holo_full_data_4.json'>
# fold_3keq_holo_model_2.cif None
# fold_3keq_holo_full_data_3.json <re.Match object; span=(0, 31), match='fold_3keq_holo_full_data_3.json'>
# fold_3keq_holo_model_3.cif None
# fold_3keq_holo_summary_confidences_4.json None
# fold_3keq_holo_job_request.json None
# fold_3keq_holo_model_4.cif None
# fold_3keq_holo_model_0.cif None
# fold_3keq_holo_summary_confidences_1.json None
# fold_3keq_holo_full_data_1.json <re.Match object; span=(0, 31), match='fold_3keq_holo_full_data_1.json'>
# fold_3keq_holo_model_1.cif None
# fold_4xap_apo_full_data_4.json <re.Match object; span=(0, 30), match='fold_4xap_apo_full_data_4.json'>
# fold_4xap_apo_model_4.cif None
# fold_4xap_apo_full_data_3.json <re.Match object; span=(0, 30), match='fold_4xap_apo_full_data_3.json'>
# fold_4xap_apo_model_2.cif None
# fold_4xap_apo_model_0.cif None
# fold_4xap_apo_summary_confidences_0.json None
# fold_4xap_apo_full_data_2.json <re.Match object; span=(0, 30), match='fold_4xap_apo_full_data_2.json'>
# fold_4xap_apo_summary_confidences_1.json None
# fold_4xap_apo_summary_confidences_4.json None
# fold_4xap_apo_full_data_1.json <re.Match object; span=(0, 30), match='fold_4xap_apo_full_data_1.json'>
# fold_4xap_apo_summary_confidences_3.json None
# fold_4xap_apo_full_data_0.json <re.Match object; span=(0, 30), match='fold_4xap_apo_full_data_0.json'>
# fold_4xap_apo_model_3.cif None
# fold_4xap_apo_model_1.cif None
# fold_4xap_apo_job_request.json None
# fold_4xap_apo_summary_confidences_2.json None
# fold_8a0f_holo_full_data_3.json <re.Match object; span=(0, 31), match='fold_8a0f_holo_full_data_3.json'>
# fold_8a0f_holo_summary_confidences_4.json None
# fold_8a0f_holo_model_1.cif None
# fold_8a0f_holo_job_request.json None
# fold_8a0f_holo_full_data_1.json <re.Match object; span=(0, 31), match='fold_8a0f_holo_full_data_1.json'>
# fold_8a0f_holo_full_data_4.json <re.Match object; span=(0, 31), match='fold_8a0f_holo_full_data_4.json'>
# fold_8a0f_holo_model_3.cif None
# fold_8a0f_holo_model_0.cif None
# fold_8a0f_holo_summary_confidences_1.json None
# fold_8a0f_holo_summary_confidences_3.json None
# fold_8a0f_holo_summary_confidences_2.json None
# fold_8a0f_holo_model_4.cif None
# fold_8a0f_holo_full_data_0.json <re.Match object; span=(0, 31), match='fold_8a0f_holo_full_data_0.json'>
# fold_8a0f_holo_summary_confidences_0.json None
# fold_8a0f_holo_model_2.cif None
# fold_8a0f_holo_full_data_2.json <re.Match object; span=(0, 31), match='fold_8a0f_holo_full_data_2.json'>
# fold_6zx9_apo_summary_confidences_4.json None
# fold_6zx9_apo_model_1.cif None
# fold_6zx9_apo_full_data_0.json <re.Match object; span=(0, 30), match='fold_6zx9_apo_full_data_0.json'>
# fold_6zx9_apo_model_4.cif None
# fold_6zx9_apo_summary_confidences_1.json None
# fold_6zx9_apo_job_request.json None
# fold_6zx9_apo_full_data_4.json <re.Match object; span=(0, 30), match='fold_6zx9_apo_full_data_4.json'>
# fold_6zx9_apo_summary_confidences_3.json None
# fold_6zx9_apo_full_data_3.json <re.Match object; span=(0, 30), match='fold_6zx9_apo_full_data_3.json'>
# fold_6zx9_apo_full_data_2.json <re.Match object; span=(0, 30), match='fold_6zx9_apo_full_data_2.json'>
# fold_6zx9_apo_summary_confidences_2.json None
# fold_6zx9_apo_model_0.cif None
# fold_6zx9_apo_full_data_1.json <re.Match object; span=(0, 30), match='fold_6zx9_apo_full_data_1.json'>
# fold_6zx9_apo_model_3.cif None
# fold_6zx9_apo_summary_confidences_0.json None
# fold_6zx9_apo_model_2.cif None
# fold_4zid_apo_summary_confidences_3.json None
# fold_4zid_apo_full_data_0.json <re.Match object; span=(0, 30), match='fold_4zid_apo_full_data_0.json'>
# fold_4zid_apo_summary_confidences_1.json None
# fold_4zid_apo_full_data_2.json <re.Match object; span=(0, 30), match='fold_4zid_apo_full_data_2.json'>
# fold_4zid_apo_summary_confidences_0.json None
# fold_4zid_apo_full_data_4.json <re.Match object; span=(0, 30), match='fold_4zid_apo_full_data_4.json'>
# fold_4zid_apo_model_4.cif None
# fold_4zid_apo_model_2.cif None
# fold_4zid_apo_summary_confidences_4.json None
# fold_4zid_apo_model_0.cif None
# fold_4zid_apo_model_3.cif None
# fold_4zid_apo_summary_confidences_2.json None
# fold_4zid_apo_full_data_1.json <re.Match object; span=(0, 30), match='fold_4zid_apo_full_data_1.json'>
# fold_4zid_apo_model_1.cif None
# fold_4zid_apo_full_data_3.json <re.Match object; span=(0, 30), match='fold_4zid_apo_full_data_3.json'>
# fold_4zid_apo_job_request.json None
# fold_5vmm_apo_summary_confidences_3.json None
# fold_5vmm_apo_model_0.cif None
# fold_5vmm_apo_model_4.cif None
# fold_5vmm_apo_model_1.cif None
# fold_5vmm_apo_model_2.cif None
# fold_5vmm_apo_job_request.json None
# fold_5vmm_apo_summary_confidences_4.json None
# fold_5vmm_apo_summary_confidences_1.json None
# fold_5vmm_apo_full_data_4.json <re.Match object; span=(0, 30), match='fold_5vmm_apo_full_data_4.json'>
# fold_5vmm_apo_full_data_1.json <re.Match object; span=(0, 30), match='fold_5vmm_apo_full_data_1.json'>
# fold_5vmm_apo_full_data_3.json <re.Match object; span=(0, 30), match='fold_5vmm_apo_full_data_3.json'>
# fold_5vmm_apo_summary_confidences_0.json None
# fold_5vmm_apo_full_data_2.json <re.Match object; span=(0, 30), match='fold_5vmm_apo_full_data_2.json'>
# fold_5vmm_apo_summary_confidences_2.json None
# fold_5vmm_apo_model_3.cif None
# fold_5vmm_apo_full_data_0.json <re.Match object; span=(0, 30), match='fold_5vmm_apo_full_data_0.json'>
# fold_5jmt_apo_job_request.json None
# fold_5jmt_apo_full_data_1.json <re.Match object; span=(0, 30), match='fold_5jmt_apo_full_data_1.json'>
# fold_5jmt_apo_summary_confidences_1.json None
# fold_5jmt_apo_model_2.cif None
# fold_5jmt_apo_summary_confidences_3.json None
# fold_5jmt_apo_model_3.cif None
# fold_5jmt_apo_model_4.cif None
# fold_5jmt_apo_model_0.cif None
# fold_5jmt_apo_full_data_3.json <re.Match object; span=(0, 30), match='fold_5jmt_apo_full_data_3.json'>
# fold_5jmt_apo_summary_confidences_4.json None
# fold_5jmt_apo_full_data_4.json <re.Match object; span=(0, 30), match='fold_5jmt_apo_full_data_4.json'>
# fold_5jmt_apo_full_data_2.json <re.Match object; span=(0, 30), match='fold_5jmt_apo_full_data_2.json'>
# fold_5jmt_apo_full_data_0.json <re.Match object; span=(0, 30), match='fold_5jmt_apo_full_data_0.json'>
# fold_5jmt_apo_summary_confidences_2.json None
# fold_5jmt_apo_summary_confidences_0.json None
# fold_5jmt_apo_model_1.cif None
# fold_1d6j_apo_summary_confidences_3.json None
# fold_1d6j_apo_full_data_4.json <re.Match object; span=(0, 30), match='fold_1d6j_apo_full_data_4.json'>
# fold_1d6j_apo_full_data_2.json <re.Match object; span=(0, 30), match='fold_1d6j_apo_full_data_2.json'>
# fold_1d6j_apo_summary_confidences_4.json None
# fold_1d6j_apo_model_4.cif None
# fold_1d6j_apo_job_request.json None
# fold_1d6j_apo_summary_confidences_1.json None
# fold_1d6j_apo_full_data_3.json <re.Match object; span=(0, 30), match='fold_1d6j_apo_full_data_3.json'>
# fold_1d6j_apo_summary_confidences_2.json None
# fold_1d6j_apo_model_3.cif None
# fold_1d6j_apo_full_data_1.json <re.Match object; span=(0, 30), match='fold_1d6j_apo_full_data_1.json'>
# fold_1d6j_apo_model_0.cif None
# fold_1d6j_apo_model_2.cif None
# fold_1d6j_apo_full_data_0.json <re.Match object; span=(0, 30), match='fold_1d6j_apo_full_data_0.json'>
# fold_1d6j_apo_model_1.cif None
# fold_1d6j_apo_summary_confidences_0.json None
# fold_1us0_holo_full_data_4.json <re.Match object; span=(0, 31), match='fold_1us0_holo_full_data_4.json'>
# fold_1us0_holo_model_1.cif None
# fold_1us0_holo_job_request.json None
# fold_1us0_holo_full_data_2.json <re.Match object; span=(0, 31), match='fold_1us0_holo_full_data_2.json'>
# fold_1us0_holo_model_0.cif None
# fold_1us0_holo_model_4.cif None
# fold_1us0_holo_full_data_1.json <re.Match object; span=(0, 31), match='fold_1us0_holo_full_data_1.json'>
# fold_1us0_holo_summary_confidences_4.json None
# fold_1us0_holo_summary_confidences_0.json None
# fold_1us0_holo_full_data_0.json <re.Match object; span=(0, 31), match='fold_1us0_holo_full_data_0.json'>
# fold_1us0_holo_full_data_3.json <re.Match object; span=(0, 31), match='fold_1us0_holo_full_data_3.json'>
# fold_1us0_holo_summary_confidences_3.json None
# fold_1us0_holo_summary_confidences_2.json None
# fold_1us0_holo_summary_confidences_1.json None
# fold_1us0_holo_model_2.cif None
# fold_1us0_holo_model_3.cif None
# fold_8u96_holo_job_request.json None
# fold_8u96_holo_full_data_4.json <re.Match object; span=(0, 31), match='fold_8u96_holo_full_data_4.json'>
# fold_8u96_holo_full_data_3.json <re.Match object; span=(0, 31), match='fold_8u96_holo_full_data_3.json'>
# fold_8u96_holo_model_1.cif None
# fold_8u96_holo_model_3.cif None
# fold_8u96_holo_summary_confidences_4.json None
# fold_8u96_holo_summary_confidences_3.json None
# fold_8u96_holo_model_2.cif None
# fold_8u96_holo_model_0.cif None
# fold_8u96_holo_summary_confidences_0.json None
# fold_8u96_holo_full_data_0.json <re.Match object; span=(0, 31), match='fold_8u96_holo_full_data_0.json'>
# fold_8u96_holo_full_data_2.json <re.Match object; span=(0, 31), match='fold_8u96_holo_full_data_2.json'>
# fold_8u96_holo_summary_confidences_2.json None
# fold_8u96_holo_summary_confidences_1.json None
# fold_8u96_holo_model_4.cif None
# fold_8u96_holo_full_data_1.json <re.Match object; span=(0, 31), match='fold_8u96_holo_full_data_1.json'>
# fold_6x2e_apo_summary_confidences_0.json None
# fold_6x2e_apo_model_0.cif None
# fold_6x2e_apo_full_data_2.json <re.Match object; span=(0, 30), match='fold_6x2e_apo_full_data_2.json'>
# fold_6x2e_apo_full_data_4.json <re.Match object; span=(0, 30), match='fold_6x2e_apo_full_data_4.json'>
# fold_6x2e_apo_full_data_1.json <re.Match object; span=(0, 30), match='fold_6x2e_apo_full_data_1.json'>
# fold_6x2e_apo_model_1.cif None
# fold_6x2e_apo_full_data_0.json <re.Match object; span=(0, 30), match='fold_6x2e_apo_full_data_0.json'>
# fold_6x2e_apo_summary_confidences_3.json None
# fold_6x2e_apo_model_3.cif None
# fold_6x2e_apo_summary_confidences_4.json None
# fold_6x2e_apo_summary_confidences_1.json None
# fold_6x2e_apo_job_request.json None
# fold_6x2e_apo_model_4.cif None
# fold_6x2e_apo_model_2.cif None
# fold_6x2e_apo_full_data_3.json <re.Match object; span=(0, 30), match='fold_6x2e_apo_full_data_3.json'>
# fold_6x2e_apo_summary_confidences_2.json None
# fold_1k6i_apo_model_0.cif None
# fold_1k6i_apo_summary_confidences_0.json None
# fold_1k6i_apo_full_data_1.json <re.Match object; span=(0, 30), match='fold_1k6i_apo_full_data_1.json'>
# fold_1k6i_apo_full_data_3.json <re.Match object; span=(0, 30), match='fold_1k6i_apo_full_data_3.json'>
# fold_1k6i_apo_summary_confidences_2.json None
# fold_1k6i_apo_summary_confidences_1.json None
# fold_1k6i_apo_summary_confidences_4.json None
# fold_1k6i_apo_model_4.cif None
# fold_1k6i_apo_job_request.json None
# fold_1k6i_apo_full_data_2.json <re.Match object; span=(0, 30), match='fold_1k6i_apo_full_data_2.json'>
# fold_1k6i_apo_model_3.cif None
# fold_1k6i_apo_full_data_4.json <re.Match object; span=(0, 30), match='fold_1k6i_apo_full_data_4.json'>
# fold_1k6i_apo_full_data_0.json <re.Match object; span=(0, 30), match='fold_1k6i_apo_full_data_0.json'>
# fold_1k6i_apo_summary_confidences_3.json None
# fold_1k6i_apo_model_1.cif None
# fold_1k6i_apo_model_2.cif None
# fold_3oif_apo_model_0.cif None
# fold_3oif_apo_job_request.json None
# fold_3oif_apo_full_data_2.json <re.Match object; span=(0, 30), match='fold_3oif_apo_full_data_2.json'>
# fold_3oif_apo_summary_confidences_4.json None
# fold_3oif_apo_summary_confidences_1.json None
# fold_3oif_apo_full_data_1.json <re.Match object; span=(0, 30), match='fold_3oif_apo_full_data_1.json'>
# fold_3oif_apo_full_data_3.json <re.Match object; span=(0, 30), match='fold_3oif_apo_full_data_3.json'>
# fold_3oif_apo_summary_confidences_2.json None
# fold_3oif_apo_summary_confidences_0.json None
# fold_3oif_apo_full_data_4.json <re.Match object; span=(0, 30), match='fold_3oif_apo_full_data_4.json'>
# fold_3oif_apo_full_data_0.json <re.Match object; span=(0, 30), match='fold_3oif_apo_full_data_0.json'>
# fold_3oif_apo_model_1.cif None
# fold_3oif_apo_model_3.cif None
# fold_3oif_apo_model_2.cif None
# fold_3oif_apo_model_4.cif None
# fold_3oif_apo_summary_confidences_3.json None
# fold_8d0u_holo_full_data_3.json <re.Match object; span=(0, 31), match='fold_8d0u_holo_full_data_3.json'>
# fold_8d0u_holo_model_0.cif None
# fold_8d0u_holo_full_data_1.json <re.Match object; span=(0, 31), match='fold_8d0u_holo_full_data_1.json'>
# fold_8d0u_holo_summary_confidences_1.json None
# fold_8d0u_holo_summary_confidences_4.json None
# fold_8d0u_holo_job_request.json None
# fold_8d0u_holo_model_2.cif None
# fold_8d0u_holo_model_3.cif None
# fold_8d0u_holo_model_1.cif None
# fold_8d0u_holo_summary_confidences_2.json None
# fold_8d0u_holo_model_4.cif None
# fold_8d0u_holo_full_data_2.json <re.Match object; span=(0, 31), match='fold_8d0u_holo_full_data_2.json'>
# fold_8d0u_holo_summary_confidences_3.json None
# fold_8d0u_holo_full_data_0.json <re.Match object; span=(0, 31), match='fold_8d0u_holo_full_data_0.json'>
# fold_8d0u_holo_summary_confidences_0.json None
# fold_8d0u_holo_full_data_4.json <re.Match object; span=(0, 31), match='fold_8d0u_holo_full_data_4.json'>
# fold_3mjc_apo_full_data_0.json <re.Match object; span=(0, 30), match='fold_3mjc_apo_full_data_0.json'>
# fold_3mjc_apo_summary_confidences_4.json None
# fold_3mjc_apo_full_data_2.json <re.Match object; span=(0, 30), match='fold_3mjc_apo_full_data_2.json'>
# fold_3mjc_apo_summary_confidences_2.json None
# fold_3mjc_apo_full_data_3.json <re.Match object; span=(0, 30), match='fold_3mjc_apo_full_data_3.json'>
# fold_3mjc_apo_summary_confidences_1.json None
# fold_3mjc_apo_summary_confidences_3.json None
# fold_3mjc_apo_model_4.cif None
# fold_3mjc_apo_full_data_4.json <re.Match object; span=(0, 30), match='fold_3mjc_apo_full_data_4.json'>
# fold_3mjc_apo_model_2.cif None
# fold_3mjc_apo_model_0.cif None
# fold_3mjc_apo_model_3.cif None
# fold_3mjc_apo_full_data_1.json <re.Match object; span=(0, 30), match='fold_3mjc_apo_full_data_1.json'>
# fold_3mjc_apo_job_request.json None
# fold_3mjc_apo_model_1.cif None
# fold_3mjc_apo_summary_confidences_0.json None
# fold_6dyf_holo_model_3.cif None
# fold_6dyf_holo_model_4.cif None
# fold_6dyf_holo_full_data_0.json <re.Match object; span=(0, 31), match='fold_6dyf_holo_full_data_0.json'>
# fold_6dyf_holo_summary_confidences_2.json None
# fold_6dyf_holo_full_data_2.json <re.Match object; span=(0, 31), match='fold_6dyf_holo_full_data_2.json'>
# fold_6dyf_holo_full_data_3.json <re.Match object; span=(0, 31), match='fold_6dyf_holo_full_data_3.json'>
# fold_6dyf_holo_summary_confidences_3.json None
# fold_6dyf_holo_summary_confidences_1.json None
# fold_6dyf_holo_job_request.json None
# fold_6dyf_holo_summary_confidences_0.json None
# fold_6dyf_holo_full_data_4.json <re.Match object; span=(0, 31), match='fold_6dyf_holo_full_data_4.json'>
# fold_6dyf_holo_summary_confidences_4.json None
# fold_6dyf_holo_model_1.cif None
# fold_6dyf_holo_model_2.cif None
# fold_6dyf_holo_model_0.cif None
# fold_6dyf_holo_full_data_1.json <re.Match object; span=(0, 31), match='fold_6dyf_holo_full_data_1.json'>
# fold_4jp2_apo_summary_confidences_4.json None
# fold_4jp2_apo_model_4.cif None
# fold_4jp2_apo_job_request.json None
# fold_4jp2_apo_summary_confidences_1.json None
# fold_4jp2_apo_model_0.cif None
# fold_4jp2_apo_full_data_2.json <re.Match object; span=(0, 30), match='fold_4jp2_apo_full_data_2.json'>
# fold_4jp2_apo_full_data_1.json <re.Match object; span=(0, 30), match='fold_4jp2_apo_full_data_1.json'>
# fold_4jp2_apo_full_data_0.json <re.Match object; span=(0, 30), match='fold_4jp2_apo_full_data_0.json'>
# fold_4jp2_apo_summary_confidences_0.json None
# fold_4jp2_apo_model_2.cif None
# fold_4jp2_apo_summary_confidences_2.json None
# fold_4jp2_apo_full_data_3.json <re.Match object; span=(0, 30), match='fold_4jp2_apo_full_data_3.json'>
# fold_4jp2_apo_model_3.cif None
# fold_4jp2_apo_summary_confidences_3.json None
# fold_4jp2_apo_model_1.cif None
# fold_4jp2_apo_full_data_4.json <re.Match object; span=(0, 30), match='fold_4jp2_apo_full_data_4.json'>
# fold_6n4a_apo_summary_confidences_0.json None
# fold_6n4a_apo_model_1.cif None
# fold_6n4a_apo_full_data_2.json <re.Match object; span=(0, 30), match='fold_6n4a_apo_full_data_2.json'>
# fold_6n4a_apo_job_request.json None
# fold_6n4a_apo_summary_confidences_2.json None
# fold_6n4a_apo_full_data_4.json <re.Match object; span=(0, 30), match='fold_6n4a_apo_full_data_4.json'>
# fold_6n4a_apo_full_data_0.json <re.Match object; span=(0, 30), match='fold_6n4a_apo_full_data_0.json'>
# fold_6n4a_apo_full_data_3.json <re.Match object; span=(0, 30), match='fold_6n4a_apo_full_data_3.json'>
# fold_6n4a_apo_summary_confidences_1.json None
# fold_6n4a_apo_model_0.cif None
# fold_6n4a_apo_model_4.cif None
# fold_6n4a_apo_summary_confidences_3.json None
# fold_6n4a_apo_summary_confidences_4.json None
# fold_6n4a_apo_full_data_1.json <re.Match object; span=(0, 30), match='fold_6n4a_apo_full_data_1.json'>
# fold_6n4a_apo_model_3.cif None
# fold_6n4a_apo_model_2.cif None
# fold_6iep_apo_full_data_2.json <re.Match object; span=(0, 30), match='fold_6iep_apo_full_data_2.json'>
# fold_6iep_apo_summary_confidences_4.json None
# fold_6iep_apo_model_1.cif None
# fold_6iep_apo_full_data_0.json <re.Match object; span=(0, 30), match='fold_6iep_apo_full_data_0.json'>
# fold_6iep_apo_full_data_3.json <re.Match object; span=(0, 30), match='fold_6iep_apo_full_data_3.json'>
# fold_6iep_apo_model_4.cif None
# fold_6iep_apo_model_0.cif None
# fold_6iep_apo_summary_confidences_2.json None
# fold_6iep_apo_model_3.cif None
# fold_6iep_apo_summary_confidences_3.json None
# fold_6iep_apo_full_data_1.json <re.Match object; span=(0, 30), match='fold_6iep_apo_full_data_1.json'>
# fold_6iep_apo_full_data_4.json <re.Match object; span=(0, 30), match='fold_6iep_apo_full_data_4.json'>
# fold_6iep_apo_summary_confidences_1.json None
# fold_6iep_apo_summary_confidences_0.json None
# fold_6iep_apo_model_2.cif None
# fold_6iep_apo_job_request.json None
# fold_1apc_apo_model_0.cif None
# fold_1apc_apo_summary_confidences_1.json None
# fold_1apc_apo_model_4.cif None
# fold_1apc_apo_model_3.cif None
# fold_1apc_apo_model_1.cif None
# fold_1apc_apo_summary_confidences_2.json None
# fold_1apc_apo_full_data_3.json <re.Match object; span=(0, 30), match='fold_1apc_apo_full_data_3.json'>
# fold_1apc_apo_full_data_1.json <re.Match object; span=(0, 30), match='fold_1apc_apo_full_data_1.json'>
# fold_1apc_apo_full_data_2.json <re.Match object; span=(0, 30), match='fold_1apc_apo_full_data_2.json'>
# fold_1apc_apo_summary_confidences_3.json None
# fold_1apc_apo_job_request.json None
# fold_1apc_apo_summary_confidences_0.json None
# fold_1apc_apo_summary_confidences_4.json None
# fold_1apc_apo_model_2.cif None
# fold_1apc_apo_full_data_4.json <re.Match object; span=(0, 30), match='fold_1apc_apo_full_data_4.json'>
# fold_1apc_apo_full_data_0.json <re.Match object; span=(0, 30), match='fold_1apc_apo_full_data_0.json'>
# fold_6d4b_holo_summary_confidences_2.json None
# fold_6d4b_holo_full_data_4.json <re.Match object; span=(0, 31), match='fold_6d4b_holo_full_data_4.json'>
# fold_6d4b_holo_full_data_3.json <re.Match object; span=(0, 31), match='fold_6d4b_holo_full_data_3.json'>
# fold_6d4b_holo_summary_confidences_3.json None
# fold_6d4b_holo_model_4.cif None
# fold_6d4b_holo_model_3.cif None
# fold_6d4b_holo_model_1.cif None
# fold_6d4b_holo_full_data_2.json <re.Match object; span=(0, 31), match='fold_6d4b_holo_full_data_2.json'>
# fold_6d4b_holo_model_2.cif None
# fold_6d4b_holo_summary_confidences_4.json None
# fold_6d4b_holo_full_data_0.json <re.Match object; span=(0, 31), match='fold_6d4b_holo_full_data_0.json'>
# fold_6d4b_holo_model_0.cif None
# fold_6d4b_holo_summary_confidences_1.json None
# fold_6d4b_holo_summary_confidences_0.json None
# fold_6d4b_holo_job_request.json None
# fold_6d4b_holo_full_data_1.json <re.Match object; span=(0, 31), match='fold_6d4b_holo_full_data_1.json'>
# fold_7zzx_apo_summary_confidences_0.json None
# fold_7zzx_apo_full_data_0.json <re.Match object; span=(0, 30), match='fold_7zzx_apo_full_data_0.json'>
# fold_7zzx_apo_full_data_3.json <re.Match object; span=(0, 30), match='fold_7zzx_apo_full_data_3.json'>
# fold_7zzx_apo_model_3.cif None
# fold_7zzx_apo_job_request.json None
# fold_7zzx_apo_summary_confidences_2.json None
# fold_7zzx_apo_full_data_4.json <re.Match object; span=(0, 30), match='fold_7zzx_apo_full_data_4.json'>
# fold_7zzx_apo_summary_confidences_4.json None
# fold_7zzx_apo_summary_confidences_3.json None
# fold_7zzx_apo_model_4.cif None
# fold_7zzx_apo_model_0.cif None
# fold_7zzx_apo_full_data_1.json <re.Match object; span=(0, 30), match='fold_7zzx_apo_full_data_1.json'>
# fold_7zzx_apo_full_data_2.json <re.Match object; span=(0, 30), match='fold_7zzx_apo_full_data_2.json'>
# fold_7zzx_apo_summary_confidences_1.json None
# fold_7zzx_apo_model_1.cif None
# fold_7zzx_apo_model_2.cif None
# fold_2q0k_holo_summary_confidences_3.json None
# fold_2q0k_holo_summary_confidences_0.json None
# fold_2q0k_holo_model_3.cif None
# fold_2q0k_holo_model_2.cif None
# fold_2q0k_holo_model_1.cif None
# fold_2q0k_holo_full_data_4.json <re.Match object; span=(0, 31), match='fold_2q0k_holo_full_data_4.json'>
# fold_2q0k_holo_model_4.cif None
# fold_2q0k_holo_full_data_3.json <re.Match object; span=(0, 31), match='fold_2q0k_holo_full_data_3.json'>
# fold_2q0k_holo_model_0.cif None
# fold_2q0k_holo_full_data_1.json <re.Match object; span=(0, 31), match='fold_2q0k_holo_full_data_1.json'>
# fold_2q0k_holo_full_data_2.json <re.Match object; span=(0, 31), match='fold_2q0k_holo_full_data_2.json'>
# fold_2q0k_holo_full_data_0.json <re.Match object; span=(0, 31), match='fold_2q0k_holo_full_data_0.json'>
# fold_2q0k_holo_summary_confidences_2.json None
# fold_2q0k_holo_summary_confidences_1.json None
# fold_2q0k_holo_summary_confidences_4.json None
# fold_2q0k_holo_job_request.json None
# fold_6nlg_holo_model_4.cif None
# fold_6nlg_holo_model_2.cif None
# fold_6nlg_holo_summary_confidences_2.json None
# fold_6nlg_holo_summary_confidences_0.json None
# fold_6nlg_holo_job_request.json None
# fold_6nlg_holo_full_data_4.json <re.Match object; span=(0, 31), match='fold_6nlg_holo_full_data_4.json'>
# fold_6nlg_holo_model_1.cif None
# fold_6nlg_holo_summary_confidences_4.json None
# fold_6nlg_holo_full_data_2.json <re.Match object; span=(0, 31), match='fold_6nlg_holo_full_data_2.json'>
# fold_6nlg_holo_summary_confidences_1.json None
# fold_6nlg_holo_summary_confidences_3.json None
# fold_6nlg_holo_full_data_1.json <re.Match object; span=(0, 31), match='fold_6nlg_holo_full_data_1.json'>
# fold_6nlg_holo_model_3.cif None
# fold_6nlg_holo_full_data_0.json <re.Match object; span=(0, 31), match='fold_6nlg_holo_full_data_0.json'>
# fold_6nlg_holo_model_0.cif None
# fold_6nlg_holo_full_data_3.json <re.Match object; span=(0, 31), match='fold_6nlg_holo_full_data_3.json'>
# fold_9b20_holo_model_3.cif None
# fold_9b20_holo_summary_confidences_2.json None
# fold_9b20_holo_model_4.cif None
# fold_9b20_holo_job_request.json None
# fold_9b20_holo_full_data_4.json <re.Match object; span=(0, 31), match='fold_9b20_holo_full_data_4.json'>
# fold_9b20_holo_summary_confidences_1.json None
# fold_9b20_holo_full_data_1.json <re.Match object; span=(0, 31), match='fold_9b20_holo_full_data_1.json'>
# fold_9b20_holo_summary_confidences_4.json None
# fold_9b20_holo_summary_confidences_0.json None
# fold_9b20_holo_model_2.cif None
# fold_9b20_holo_full_data_3.json <re.Match object; span=(0, 31), match='fold_9b20_holo_full_data_3.json'>
# fold_9b20_holo_model_1.cif None
# fold_9b20_holo_full_data_2.json <re.Match object; span=(0, 31), match='fold_9b20_holo_full_data_2.json'>
# fold_9b20_holo_model_0.cif None
# fold_9b20_holo_full_data_0.json <re.Match object; span=(0, 31), match='fold_9b20_holo_full_data_0.json'>
# fold_9b20_holo_summary_confidences_3.json None
# fold_2j9e_holo_full_data_1.json <re.Match object; span=(0, 31), match='fold_2j9e_holo_full_data_1.json'>
# fold_2j9e_holo_full_data_4.json <re.Match object; span=(0, 31), match='fold_2j9e_holo_full_data_4.json'>
# fold_2j9e_holo_full_data_3.json <re.Match object; span=(0, 31), match='fold_2j9e_holo_full_data_3.json'>
# fold_2j9e_holo_summary_confidences_2.json None
# fold_2j9e_holo_model_1.cif None
# fold_2j9e_holo_model_4.cif None
# fold_2j9e_holo_model_3.cif None
# fold_2j9e_holo_full_data_0.json <re.Match object; span=(0, 31), match='fold_2j9e_holo_full_data_0.json'>
# fold_2j9e_holo_summary_confidences_4.json None
# fold_2j9e_holo_summary_confidences_3.json None
# fold_2j9e_holo_model_2.cif None
# ...
# fold_3uxm_apo_summary_confidences_1.json None
# fold_3uxm_apo_job_request.json None
# fold_3uxm_apo_summary_confidences_2.json None
# fold_3uxm_apo_full_data_1.json <re.Match object; span=(0, 30), match='fold_3uxm_apo_full_data_1.json'>
# fold_3uxm_apo_summary_confidences_3.json None
# fold_3uxm_apo_model_1.cif None
# fold_3uxm_apo_model_2.cif None
# fold_3uxm_apo_full_data_4.json <re.Match object; span=(0, 30), match='fold_3uxm_apo_full_data_4.json'>
# fold_3uxm_apo_full_data_0.json <re.Match object; span=(0, 30), match='fold_3uxm_apo_full_data_0.json'>
# fold_3uxm_apo_full_data_3.json <re.Match object; span=(0, 30), match='fold_3uxm_apo_full_data_3.json'>
# fold_3uxm_apo_model_0.cif None
# fold_1kmv_holo_full_data_1.json <re.Match object; span=(0, 31), match='fold_1kmv_holo_full_data_1.json'>
# fold_1kmv_holo_full_data_4.json <re.Match object; span=(0, 31), match='fold_1kmv_holo_full_data_4.json'>
# fold_1kmv_holo_summary_confidences_2.json None
# fold_1kmv_holo_job_request.json None
# fold_1kmv_holo_model_2.cif None
# fold_1kmv_holo_full_data_0.json <re.Match object; span=(0, 31), match='fold_1kmv_holo_full_data_0.json'>
# fold_1kmv_holo_summary_confidences_4.json None
# fold_1kmv_holo_summary_confidences_0.json None
# fold_1kmv_holo_model_0.cif None
# fold_1kmv_holo_model_4.cif None
# fold_1kmv_holo_model_1.cif None
# fold_1kmv_holo_full_data_3.json <re.Match object; span=(0, 31), match='fold_1kmv_holo_full_data_3.json'>
# fold_1kmv_holo_summary_confidences_1.json None
# fold_1kmv_holo_summary_confidences_3.json None
# fold_1kmv_holo_full_data_2.json <re.Match object; span=(0, 31), match='fold_1kmv_holo_full_data_2.json'>
# fold_1kmv_holo_model_3.cif None
# fold_5y1g_holo_model_1.cif None
# fold_5y1g_holo_full_data_0.json <re.Match object; span=(0, 31), match='fold_5y1g_holo_full_data_0.json'>
# fold_5y1g_holo_model_0.cif None
# fold_5y1g_holo_full_data_1.json <re.Match object; span=(0, 31), match='fold_5y1g_holo_full_data_1.json'>
# fold_5y1g_holo_summary_confidences_1.json None
# fold_5y1g_holo_model_2.cif None
# fold_5y1g_holo_full_data_3.json <re.Match object; span=(0, 31), match='fold_5y1g_holo_full_data_3.json'>
# fold_5y1g_holo_model_4.cif None
# fold_5y1g_holo_summary_confidences_3.json None
# fold_5y1g_holo_full_data_4.json <re.Match object; span=(0, 31), match='fold_5y1g_holo_full_data_4.json'>
# fold_5y1g_holo_summary_confidences_2.json None
# fold_5y1g_holo_job_request.json None
# fold_5y1g_holo_summary_confidences_0.json None
# fold_5y1g_holo_summary_confidences_4.json None
# fold_5y1g_holo_full_data_2.json <re.Match object; span=(0, 31), match='fold_5y1g_holo_full_data_2.json'>
# fold_5y1g_holo_model_3.cif None
# fold_5v1m_holo_full_data_2.json <re.Match object; span=(0, 31), match='fold_5v1m_holo_full_data_2.json'>
# fold_5v1m_holo_full_data_4.json <re.Match object; span=(0, 31), match='fold_5v1m_holo_full_data_4.json'>
# fold_5v1m_holo_full_data_3.json <re.Match object; span=(0, 31), match='fold_5v1m_holo_full_data_3.json'>
# fold_5v1m_holo_job_request.json None
# fold_5v1m_holo_summary_confidences_3.json None
# fold_5v1m_holo_full_data_1.json <re.Match object; span=(0, 31), match='fold_5v1m_holo_full_data_1.json'>
# fold_5v1m_holo_summary_confidences_4.json None
# fold_5v1m_holo_model_3.cif None
# fold_5v1m_holo_model_0.cif None
# fold_5v1m_holo_full_data_0.json <re.Match object; span=(0, 31), match='fold_5v1m_holo_full_data_0.json'>
# fold_5v1m_holo_summary_confidences_2.json None
# fold_5v1m_holo_model_2.cif None
# fold_5v1m_holo_summary_confidences_0.json None
# fold_5v1m_holo_model_4.cif None
# fold_5v1m_holo_model_1.cif None
# fold_5v1m_holo_summary_confidences_1.json None
# fold_2cdb_holo_model_1.cif None
# fold_2cdb_holo_full_data_0.json <re.Match object; span=(0, 31), match='fold_2cdb_holo_full_data_0.json'>
# fold_2cdb_holo_full_data_1.json <re.Match object; span=(0, 31), match='fold_2cdb_holo_full_data_1.json'>
# fold_2cdb_holo_full_data_2.json <re.Match object; span=(0, 31), match='fold_2cdb_holo_full_data_2.json'>
# fold_2cdb_holo_model_0.cif None
# fold_2cdb_holo_summary_confidences_3.json None
# fold_2cdb_holo_summary_confidences_0.json None
# fold_2cdb_holo_summary_confidences_1.json None
# fold_2cdb_holo_summary_confidences_4.json None
# fold_2cdb_holo_model_2.cif None
# fold_2cdb_holo_summary_confidences_2.json None
# fold_2cdb_holo_model_3.cif None
# fold_2cdb_holo_full_data_4.json <re.Match object; span=(0, 31), match='fold_2cdb_holo_full_data_4.json'>
# fold_2cdb_holo_job_request.json None
# fold_2cdb_holo_full_data_3.json <re.Match object; span=(0, 31), match='fold_2cdb_holo_full_data_3.json'>
# fold_2cdb_holo_model_4.cif None
# fold_4gkb_apo_full_data_3.json <re.Match object; span=(0, 30), match='fold_4gkb_apo_full_data_3.json'>
# fold_4gkb_apo_model_0.cif None
# fold_4gkb_apo_full_data_0.json <re.Match object; span=(0, 30), match='fold_4gkb_apo_full_data_0.json'>
# fold_4gkb_apo_summary_confidences_0.json None
# fold_4gkb_apo_model_4.cif None
# fold_4gkb_apo_summary_confidences_2.json None
# fold_4gkb_apo_summary_confidences_3.json None
# fold_4gkb_apo_model_3.cif None
# fold_4gkb_apo_full_data_4.json <re.Match object; span=(0, 30), match='fold_4gkb_apo_full_data_4.json'>
# fold_4gkb_apo_model_1.cif None
# fold_4gkb_apo_summary_confidences_4.json None
# fold_4gkb_apo_job_request.json None
# fold_4gkb_apo_full_data_2.json <re.Match object; span=(0, 30), match='fold_4gkb_apo_full_data_2.json'>
# fold_4gkb_apo_model_2.cif None
# fold_4gkb_apo_summary_confidences_1.json None
# fold_4gkb_apo_full_data_1.json <re.Match object; span=(0, 30), match='fold_4gkb_apo_full_data_1.json'>
# fold_5ugv_holo_model_4.cif None
# fold_5ugv_holo_summary_confidences_3.json None
# fold_5ugv_holo_summary_confidences_0.json None
# fold_5ugv_holo_full_data_2.json <re.Match object; span=(0, 31), match='fold_5ugv_holo_full_data_2.json'>
# fold_5ugv_holo_model_1.cif None
# fold_5ugv_holo_full_data_0.json <re.Match object; span=(0, 31), match='fold_5ugv_holo_full_data_0.json'>
# fold_5ugv_holo_full_data_3.json <re.Match object; span=(0, 31), match='fold_5ugv_holo_full_data_3.json'>
# fold_5ugv_holo_full_data_1.json <re.Match object; span=(0, 31), match='fold_5ugv_holo_full_data_1.json'>
# fold_5ugv_holo_full_data_4.json <re.Match object; span=(0, 31), match='fold_5ugv_holo_full_data_4.json'>
# fold_5ugv_holo_model_0.cif None
# fold_5ugv_holo_job_request.json None
# fold_5ugv_holo_model_3.cif None
# fold_5ugv_holo_model_2.cif None
# fold_5ugv_holo_summary_confidences_4.json None
# fold_5ugv_holo_summary_confidences_1.json None
# fold_5ugv_holo_summary_confidences_2.json None
# fold_7qv9_apo_full_data_1.json <re.Match object; span=(0, 30), match='fold_7qv9_apo_full_data_1.json'>
# fold_7qv9_apo_summary_confidences_0.json None
# fold_7qv9_apo_full_data_2.json <re.Match object; span=(0, 30), match='fold_7qv9_apo_full_data_2.json'>
# fold_7qv9_apo_model_2.cif None
# fold_7qv9_apo_full_data_0.json <re.Match object; span=(0, 30), match='fold_7qv9_apo_full_data_0.json'>
# fold_7qv9_apo_summary_confidences_1.json None
# fold_7qv9_apo_job_request.json None
# fold_7qv9_apo_summary_confidences_4.json None
# fold_7qv9_apo_model_4.cif None
# fold_7qv9_apo_full_data_4.json <re.Match object; span=(0, 30), match='fold_7qv9_apo_full_data_4.json'>
# fold_7qv9_apo_full_data_3.json <re.Match object; span=(0, 30), match='fold_7qv9_apo_full_data_3.json'>
# fold_7qv9_apo_summary_confidences_3.json None
# fold_7qv9_apo_model_1.cif None
# fold_7qv9_apo_model_3.cif None
# fold_7qv9_apo_model_0.cif None
# fold_7qv9_apo_summary_confidences_2.json None
# fold_2j9d_apo_model_4.cif None
# fold_2j9d_apo_full_data_1.json <re.Match object; span=(0, 30), match='fold_2j9d_apo_full_data_1.json'>
# fold_2j9d_apo_full_data_2.json <re.Match object; span=(0, 30), match='fold_2j9d_apo_full_data_2.json'>
# fold_2j9d_apo_full_data_3.json <re.Match object; span=(0, 30), match='fold_2j9d_apo_full_data_3.json'>
# fold_2j9d_apo_summary_confidences_2.json None
# fold_2j9d_apo_full_data_0.json <re.Match object; span=(0, 30), match='fold_2j9d_apo_full_data_0.json'>
# fold_2j9d_apo_summary_confidences_0.json None
# fold_2j9d_apo_full_data_4.json <re.Match object; span=(0, 30), match='fold_2j9d_apo_full_data_4.json'>
# fold_2j9d_apo_summary_confidences_4.json None
# fold_2j9d_apo_model_1.cif None
# fold_2j9d_apo_model_0.cif None
# fold_2j9d_apo_model_2.cif None
# fold_2j9d_apo_model_3.cif None
# fold_2j9d_apo_job_request.json None
# fold_2j9d_apo_summary_confidences_3.json None
# fold_2j9d_apo_summary_confidences_1.json None
# fold_5j80_apo_model_0.cif None
# fold_5j80_apo_job_request.json None
# fold_5j80_apo_summary_confidences_0.json None
# fold_5j80_apo_summary_confidences_4.json None
# fold_5j80_apo_model_2.cif None
# fold_5j80_apo_full_data_4.json <re.Match object; span=(0, 30), match='fold_5j80_apo_full_data_4.json'>
# fold_5j80_apo_full_data_0.json <re.Match object; span=(0, 30), match='fold_5j80_apo_full_data_0.json'>
# fold_5j80_apo_summary_confidences_2.json None
# fold_5j80_apo_summary_confidences_3.json None
# fold_5j80_apo_full_data_3.json <re.Match object; span=(0, 30), match='fold_5j80_apo_full_data_3.json'>
# fold_5j80_apo_summary_confidences_1.json None
# fold_5j80_apo_full_data_2.json <re.Match object; span=(0, 30), match='fold_5j80_apo_full_data_2.json'>
# fold_5j80_apo_model_4.cif None
# fold_5j80_apo_model_1.cif None
# fold_5j80_apo_full_data_1.json <re.Match object; span=(0, 30), match='fold_5j80_apo_full_data_1.json'>
# fold_5j80_apo_model_3.cif None
# fold_3mjs_holo_job_request.json None
# fold_3mjs_holo_model_4.cif None
# fold_3mjs_holo_summary_confidences_0.json None
# fold_3mjs_holo_summary_confidences_4.json None
# fold_3mjs_holo_summary_confidences_2.json None
# fold_3mjs_holo_summary_confidences_3.json None
# fold_3mjs_holo_full_data_0.json <re.Match object; span=(0, 31), match='fold_3mjs_holo_full_data_0.json'>
# fold_3mjs_holo_full_data_2.json <re.Match object; span=(0, 31), match='fold_3mjs_holo_full_data_2.json'>
# fold_3mjs_holo_summary_confidences_1.json None
# fold_3mjs_holo_model_2.cif None
# fold_3mjs_holo_full_data_4.json <re.Match object; span=(0, 31), match='fold_3mjs_holo_full_data_4.json'>
# fold_3mjs_holo_model_0.cif None
# fold_3mjs_holo_full_data_1.json <re.Match object; span=(0, 31), match='fold_3mjs_holo_full_data_1.json'>
# fold_3mjs_holo_model_1.cif None
# fold_3mjs_holo_model_3.cif None
# fold_3mjs_holo_full_data_3.json <re.Match object; span=(0, 31), match='fold_3mjs_holo_full_data_3.json'>
# fold_5f0z_holo_model_3.cif None
# fold_5f0z_holo_summary_confidences_0.json None
# fold_5f0z_holo_full_data_2.json <re.Match object; span=(0, 31), match='fold_5f0z_holo_full_data_2.json'>
# fold_5f0z_holo_full_data_1.json <re.Match object; span=(0, 31), match='fold_5f0z_holo_full_data_1.json'>
# fold_5f0z_holo_summary_confidences_1.json None
# fold_5f0z_holo_summary_confidences_3.json None
# fold_5f0z_holo_model_0.cif None
# fold_5f0z_holo_full_data_4.json <re.Match object; span=(0, 31), match='fold_5f0z_holo_full_data_4.json'>
# fold_5f0z_holo_job_request.json None
# fold_5f0z_holo_summary_confidences_2.json None
# fold_5f0z_holo_summary_confidences_4.json None
# fold_5f0z_holo_model_2.cif None
# fold_5f0z_holo_full_data_0.json <re.Match object; span=(0, 31), match='fold_5f0z_holo_full_data_0.json'>
# fold_5f0z_holo_model_1.cif None
# fold_5f0z_holo_full_data_3.json <re.Match object; span=(0, 31), match='fold_5f0z_holo_full_data_3.json'>
# fold_5f0z_holo_model_4.cif None
# fold_5dcy_holo_model_0.cif None
# fold_5dcy_holo_model_2.cif None
# fold_5dcy_holo_full_data_1.json <re.Match object; span=(0, 31), match='fold_5dcy_holo_full_data_1.json'>
# fold_5dcy_holo_full_data_3.json <re.Match object; span=(0, 31), match='fold_5dcy_holo_full_data_3.json'>
# fold_5dcy_holo_summary_confidences_1.json None
# fold_5dcy_holo_full_data_0.json <re.Match object; span=(0, 31), match='fold_5dcy_holo_full_data_0.json'>
# fold_5dcy_holo_model_3.cif None
# fold_5dcy_holo_full_data_2.json <re.Match object; span=(0, 31), match='fold_5dcy_holo_full_data_2.json'>
# fold_5dcy_holo_model_4.cif None
# fold_5dcy_holo_summary_confidences_4.json None
# fold_5dcy_holo_summary_confidences_2.json None
# fold_5dcy_holo_summary_confidences_0.json None
# fold_5dcy_holo_model_1.cif None
# fold_5dcy_holo_full_data_4.json <re.Match object; span=(0, 31), match='fold_5dcy_holo_full_data_4.json'>
# fold_5dcy_holo_summary_confidences_3.json None
# fold_5dcy_holo_job_request.json None
# fold_5uxa_apo_model_1.cif None
# fold_5uxa_apo_full_data_2.json <re.Match object; span=(0, 30), match='fold_5uxa_apo_full_data_2.json'>
# fold_5uxa_apo_full_data_4.json <re.Match object; span=(0, 30), match='fold_5uxa_apo_full_data_4.json'>
# fold_5uxa_apo_full_data_1.json <re.Match object; span=(0, 30), match='fold_5uxa_apo_full_data_1.json'>
# fold_5uxa_apo_model_2.cif None
# fold_5uxa_apo_full_data_3.json <re.Match object; span=(0, 30), match='fold_5uxa_apo_full_data_3.json'>
# fold_5uxa_apo_summary_confidences_1.json None
# fold_5uxa_apo_job_request.json None
# fold_5uxa_apo_summary_confidences_3.json None
# fold_5uxa_apo_model_0.cif None
# fold_5uxa_apo_model_4.cif None
# fold_5uxa_apo_summary_confidences_4.json None
# fold_5uxa_apo_summary_confidences_2.json None
# fold_5uxa_apo_summary_confidences_0.json None
# fold_5uxa_apo_full_data_0.json <re.Match object; span=(0, 30), match='fold_5uxa_apo_full_data_0.json'>
# fold_5uxa_apo_model_3.cif None
# fold_5aus_holo_model_0.cif None
# fold_5aus_holo_summary_confidences_0.json None
# fold_5aus_holo_full_data_4.json <re.Match object; span=(0, 31), match='fold_5aus_holo_full_data_4.json'>
# fold_5aus_holo_full_data_1.json <re.Match object; span=(0, 31), match='fold_5aus_holo_full_data_1.json'>
# fold_5aus_holo_summary_confidences_2.json None
# fold_5aus_holo_model_1.cif None
# fold_5aus_holo_full_data_2.json <re.Match object; span=(0, 31), match='fold_5aus_holo_full_data_2.json'>
# fold_5aus_holo_summary_confidences_1.json None
# fold_5aus_holo_model_2.cif None
# fold_5aus_holo_full_data_0.json <re.Match object; span=(0, 31), match='fold_5aus_holo_full_data_0.json'>
# fold_5aus_holo_summary_confidences_4.json None
# fold_5aus_holo_model_3.cif None
# fold_5aus_holo_job_request.json None
# fold_5aus_holo_full_data_3.json <re.Match object; span=(0, 31), match='fold_5aus_holo_full_data_3.json'>
# fold_5aus_holo_summary_confidences_3.json None
# fold_5aus_holo_model_4.cif None
# fold_6x9a_holo_summary_confidences_2.json None
# fold_6x9a_holo_summary_confidences_1.json None
# fold_6x9a_holo_full_data_1.json <re.Match object; span=(0, 31), match='fold_6x9a_holo_full_data_1.json'>
# fold_6x9a_holo_model_2.cif None
# fold_6x9a_holo_model_4.cif None
# fold_6x9a_holo_full_data_0.json <re.Match object; span=(0, 31), match='fold_6x9a_holo_full_data_0.json'>
# fold_6x9a_holo_full_data_3.json <re.Match object; span=(0, 31), match='fold_6x9a_holo_full_data_3.json'>
# fold_6x9a_holo_summary_confidences_3.json None
# fold_6x9a_holo_summary_confidences_4.json None
# fold_6x9a_holo_model_0.cif None
# fold_6x9a_holo_full_data_2.json <re.Match object; span=(0, 31), match='fold_6x9a_holo_full_data_2.json'>
# fold_6x9a_holo_job_request.json None
# fold_6x9a_holo_summary_confidences_0.json None
# fold_6x9a_holo_full_data_4.json <re.Match object; span=(0, 31), match='fold_6x9a_holo_full_data_4.json'>
# fold_6x9a_holo_model_1.cif None
# fold_6x9a_holo_model_3.cif None
# fold_5u95_apo_summary_confidences_4.json None
# fold_5u95_apo_full_data_2.json <re.Match object; span=(0, 30), match='fold_5u95_apo_full_data_2.json'>
# fold_5u95_apo_full_data_3.json <re.Match object; span=(0, 30), match='fold_5u95_apo_full_data_3.json'>
# fold_5u95_apo_model_3.cif None
# fold_5u95_apo_summary_confidences_3.json None
# fold_5u95_apo_job_request.json None
# fold_5u95_apo_model_4.cif None
# fold_5u95_apo_model_0.cif None
# fold_5u95_apo_full_data_4.json <re.Match object; span=(0, 30), match='fold_5u95_apo_full_data_4.json'>
# fold_5u95_apo_model_1.cif None
# fold_5u95_apo_full_data_1.json <re.Match object; span=(0, 30), match='fold_5u95_apo_full_data_1.json'>
# fold_5u95_apo_summary_confidences_1.json None
# fold_5u95_apo_summary_confidences_2.json None
# fold_5u95_apo_model_2.cif None
# fold_5u95_apo_summary_confidences_0.json None
# fold_5u95_apo_full_data_0.json <re.Match object; span=(0, 30), match='fold_5u95_apo_full_data_0.json'>
# pLDDT calculations completed. Results saved in plddt_results.tsv.

# %% [markdown]
# # Skaičiuojame RMSD įverčius

# %%
from IPython.utils import io
import tqdm.notebook
import os
"""The PyMOL installation is done inside two nested context managers. This approach
was inspired by Dr. Christopher Schlick's (of the Phenix group at
Lawrence Berkeley National Laboratory) method for installing cctbx
in a Colab Notebook. He presented his work on September 1, 2021 at the IUCr
Crystallographic Computing School. I adapted Chris's approach here. It replaces my first approach
that requires seven steps. My approach was presentated at the SciPy2021 conference
in July 2021 and published in the
[proceedings](http://conference.scipy.org/proceedings/scipy2021/blaine_mooers.html).
The new approach is easier for beginners to use. The old approach is easier to debug
and could be used as a back-up approach.

Thank you to Professor David Oppenheimer of the University of Florida for suggesting the use mamba and of Open Source PyMOL.
"""
total = 100
with tqdm.notebook.tqdm(total=total) as pbar:
    with io.capture_output() as captured:

        # !pip install -q condacolab
        import condacolab
        condacolab.install()
        pbar.update(10)

        import sys
        sys.path.append('/usr/local/lib/python3.10/site-packages/')
        pbar.update(20)

        # Install PyMOL
        # %shell mamba install pymol-open-source --yes

        pbar.update(100)
# Out:
#   0%|          | 0/100 [00:00<?, ?it/s]

# %%
# !unzip /content/structures_from_pdb.zip -d /content/cif_files
# Out:
# Archive:  /content/structures_from_pdb.zip
#    creating: /content/cif_files/content/cif_files/
#   inflating: /content/cif_files/content/cif_files/8uw0.cif
#   inflating: /content/cif_files/content/cif_files/6ekk.cif
#   inflating: /content/cif_files/content/cif_files/6qaj.cif
#   inflating: /content/cif_files/content/cif_files/6nlf.cif
#   inflating: /content/cif_files/content/cif_files/4qnr.cif
#   inflating: /content/cif_files/content/cif_files/3keq.cif
#   inflating: /content/cif_files/content/cif_files/3g59.cif
#   inflating: /content/cif_files/content/cif_files/2cd9.cif
#   inflating: /content/cif_files/content/cif_files/8onv.cif
#   inflating: /content/cif_files/content/cif_files/6zx9.cif
#   inflating: /content/cif_files/content/cif_files/6m65.cif
#   inflating: /content/cif_files/content/cif_files/2qw8.cif
#   inflating: /content/cif_files/content/cif_files/4bga.cif
#   inflating: /content/cif_files/content/cif_files/6jsd.cif
#   inflating: /content/cif_files/content/cif_files/5j4l.cif
#   inflating: /content/cif_files/content/cif_files/2ig7.cif
#   inflating: /content/cif_files/content/cif_files/6epp.cif
#   inflating: /content/cif_files/content/cif_files/6fgd.cif
#   inflating: /content/cif_files/content/cif_files/3cue.cif
#   inflating: /content/cif_files/content/cif_files/5y1d.cif
#   inflating: /content/cif_files/content/cif_files/2w72.cif
#   inflating: /content/cif_files/content/cif_files/7zzx.cif
#   inflating: /content/cif_files/content/cif_files/6x9a.cif
#   inflating: /content/cif_files/content/cif_files/2bcg.cif
#   inflating: /content/cif_files/content/cif_files/3uxm.cif
#   inflating: /content/cif_files/content/cif_files/5l3z.cif
#   inflating: /content/cif_files/content/cif_files/6n4a.cif
#   inflating: /content/cif_files/content/cif_files/4up3.cif
#   inflating: /content/cif_files/content/cif_files/4cnz.cif
#   inflating: /content/cif_files/content/cif_files/6r3y.cif
#   inflating: /content/cif_files/content/cif_files/2q0k.cif
#   inflating: /content/cif_files/content/cif_files/1jks.cif
#   inflating: /content/cif_files/content/cif_files/4gta.cif
#   inflating: /content/cif_files/content/cif_files/3lq3.cif
#   inflating: /content/cif_files/content/cif_files/7r3d.cif
#   inflating: /content/cif_files/content/cif_files/3tw8.cif
#   inflating: /content/cif_files/content/cif_files/6nlg.cif
#   inflating: /content/cif_files/content/cif_files/4xyg.cif
#   inflating: /content/cif_files/content/cif_files/5ey7.cif
#   inflating: /content/cif_files/content/cif_files/5b4t.cif
#   inflating: /content/cif_files/content/cif_files/6bmt.cif
#   inflating: /content/cif_files/content/cif_files/5lvo.cif
#   inflating: /content/cif_files/content/cif_files/8dqt.cif
#   inflating: /content/cif_files/content/cif_files/8eac.cif
#   inflating: /content/cif_files/content/cif_files/1us0.cif
#   inflating: /content/cif_files/content/cif_files/4jl5.cif
#   inflating: /content/cif_files/content/cif_files/7uld.cif
#   inflating: /content/cif_files/content/cif_files/7qv9.cif
#   inflating: /content/cif_files/content/cif_files/4pmj.cif
#   inflating: /content/cif_files/content/cif_files/1kmv.cif
#   inflating: /content/cif_files/content/cif_files/5yce.cif
#   inflating: /content/cif_files/content/cif_files/3ish.cif
#   inflating: /content/cif_files/content/cif_files/5u95.cif
#   inflating: /content/cif_files/content/cif_files/5ics.cif
#   inflating: /content/cif_files/content/cif_files/9b1z.cif
#   inflating: /content/cif_files/content/cif_files/3oif.cif
#   inflating: /content/cif_files/content/cif_files/2j9e.cif
#   inflating: /content/cif_files/content/cif_files/1gfs.cif
#   inflating: /content/cif_files/content/cif_files/5jmt.cif
#   inflating: /content/cif_files/content/cif_files/4ohu.cif
#   inflating: /content/cif_files/content/cif_files/8sbn.cif
#   inflating: /content/cif_files/content/cif_files/1dkg.cif
#   inflating: /content/cif_files/content/cif_files/1zk4.cif
#   inflating: /content/cif_files/content/cif_files/6v6u.cif
#   inflating: /content/cif_files/content/cif_files/2yz7.cif
#   inflating: /content/cif_files/content/cif_files/3x39.cif
#   inflating: /content/cif_files/content/cif_files/1ufp.cif
#   inflating: /content/cif_files/content/cif_files/1apc.cif
#   inflating: /content/cif_files/content/cif_files/5luh.cif
#   inflating: /content/cif_files/content/cif_files/4zid.cif

# %%
from pymol import cmd
# from IPython.display import Image
import pandas as pd
df = pd.read_csv("/content/reviewed_apo_holo_pair_ligand_and_ion_data.tsv", sep='\t')
pairs = []
for index, row in df.iterrows():
        apo = row['Apo_PDB_ID']
        holo = row['Holo_PDB_ID']
        pairs.append([apo, holo])
RMSD_map = dict()
for pair in pairs:
  cmd.reinitialize()
  cmd.load(f"/content/cif_files/content/cif_files/{pair[0][0:4]}.cif", "str1")
  cmd.load(f"/content/cif_files/content/cif_files/{pair[1][0:4]}.cif", "str2")
  RMSD = cmd.align("str2", "str1")[0]  # Align structure2 to structure1
  RMSD_map[f'{pair[0][0:4]}_{pair[1][0:4]}'] = RMSD
  print(f"RMSD between {pair[0]} and {pair[1]}: {RMSD}")
# Out:
#  Downloading https://files.rcsb.org/ligands/download/XE.cif
#   ->./XE.cif
# RMSD between 5vmm and 2w72: 3.785067081451416
# RMSD between 5j80 and 6tn5: 0.2576241195201874
# RMSD between 2ofm and 1x8q: 0.2636294662952423
# RMSD between 1gfs and 1e7s: 0.2641831338405609
# RMSD between 1k6i and 1xgk: 0.1773521453142166
# RMSD between 1pdb and 1kmv: 0.6890032887458801
# RMSD between 1d6j and 1m7h: 0.8921723961830139
# RMSD between 3n80 and 8dr9: 51.66289138793945
# RMSD between 2cnu and 2cnq: 0.9901812672615051
# RMSD between 1xgd and 1us0: 0.5888625979423523
# RMSD between 7u8k and 4b1y: 1.5697057247161865
# RMSD between 1ufp and 5yce: 0.6060529351234436
# RMSD between 3cue and 2bcg: 31.333511352539062
# RMSD between 7a2b and 1zk4: 0.1095983237028122
# RMSD between 1apc and 6dyf: 3.8038365840911865
# RMSD between 1ffh and 2j46: 0.45971956849098206
#  Downloading https://files.rcsb.org/ligands/download/ZN.cif
#   ->./ZN.cif
# RMSD between 2cd9 and 2cdb: 0.29073020815849304
# RMSD between 4jp2 and 4jp3: 0.1582803726196289
# RMSD between 2j9d and 2j9e: 0.25424060225486755
# RMSD between 2rh2 and 2rk1: 0.08633699268102646
# RMSD between 2g9i and 7uld: 0.4485000967979431
# RMSD between 3ish and 2q0k: 26.249900817871094
# RMSD between 2qys and 2qw8: 0.26023924350738525
# RMSD between 1jks and 4pf4: 0.21571025252342224
# RMSD between 2y51 and 2y5d: 0.1997029185295105
# RMSD between 3k74 and 8uw0: 0.4371735155582428
# RMSD between 2ig7 and 3lq3: 0.9705550074577332
# RMSD between 3fwk and 3g59: 0.15714724361896515
# RMSD between 2n1b and 7mo5: 1.0818605422973633
# RMSD between 3keq and 3keq: 0.0
# RMSD between 4co3 and 4cnz: 15.663869857788086
# RMSD between 3mjc and 3mjs: 0.2110450118780136
# RMSD between 3mok and 5iqx: 0.39491140842437744
# RMSD between 3ncp and 3ncr: 27.87533187866211
# RMSD between 3oif and 3oif: 0.0
# RMSD between 2yz7 and 5b4t: 0.42495426535606384
# RMSD between 8dqt and 5lvo: 0.2339114546775818
# RMSD between 4bg9 and 4bga: 0.4901587963104248
# RMSD between 4ccr and 4up3: 18.771133422851562
# RMSD between 3uxm and 3uwk: 18.82759666442871
# RMSD between 6epp and 8onv: 0.5418289303779602
# RMSD between 5chp and 4gta: 0.18435083329677582
# RMSD between 4gkb and 4gkb: 0.0
# RMSD between 2rh5 and 4jl5: 19.729856491088867
# RMSD between 7qv9 and 4qnr: 1.850993275642395
# RMSD between 4trm and 4ohu: 40.44003677368164
# RMSD between 5c4r and 5c4n: 1.4846054315567017
# RMSD between 4xyg and 4xye: 0.9755018949508667
# RMSD between 4zid and 5aus: 17.69405746459961
# RMSD between 7qni and 7r3d: 3.141176700592041
# RMSD between 5u95 and 5bst: 0.3686332106590271
# RMSD between 7g90 and 6v6u: 0.48299139738082886
# RMSD between 4xap and 4pmj: 0.2888466715812683
# RMSD between 6nlf and 6nlg: 25.714847564697266
# RMSD between 5dcw and 5dcy: 0.5791751146316528
# RMSD between 5dna and 6d4b: 2.023646354675293
# RMSD between 5ey7 and 5f0z: 0.5295052528381348
# RMSD between 4z7y and 5gme: 0.42188510298728943
# RMSD between 5uxa and 5iwu: 0.8656777143478394
# RMSD between 5jbj and 5jbg: 2.495638132095337
# RMSD between 5l40 and 5l3z: 0.11310898512601852
# RMSD between 4cs6 and 5luh: 0.8816986083984375
# RMSD between 6azp and 6bmt: 0.29143714904785156
# RMSD between 5ics and 6h0m: 0.45074141025543213
# RMSD between 1yl5 and 5ugv: 0.5546565055847168
# RMSD between 4dcv and 2hjg: 0.32250848412513733
# RMSD between 5ggb and 6m65: 0.20955762267112732
# RMSD between 3x39 and 2exv: 8.626736640930176
# RMSD between 5y1d and 5y1g: 0.23000411689281464
# RMSD between 6iep and 4qx6: 21.60313606262207
# RMSD between 4h7w and 5v1m: 0.6232722997665405
# RMSD between 6zx9 and 6qaj: 3.3635330200195312
# RMSD between 4pd0 and 6fgd: 0.29894521832466125
# RMSD between 3tw8 and 6ekk: 27.750003814697266
# RMSD between 6jsd and 6jsc: 21.7098388671875
# RMSD between 6n4a and 6ntb: 0.5477407574653625
# RMSD between 2fr2 and 6r3y: 0.13098374009132385
# RMSD between 5jmt and 5y6n: 0.6677738428115845
# RMSD between 6x2e and 6ok4: 0.31860631704330444
# RMSD between 6x99 and 6x9a: 0.15397337079048157
# RMSD between 6xxh and 8a0f: 0.2513948380947113
# RMSD between 7d48 and 7d4o: 0.7363448143005371
# RMSD between 6iau and 7qzn: 0.43204426765441895
# RMSD between 1dkg and 7kru: 3.013298749923706
# RMSD between 8eac and 3apt: 0.3008122444152832
# RMSD between 7zzx and 8crh: 0.7152985334396362
# RMSD between 6tuu and 5j4l: 0.4821301996707916
# RMSD between 8d0p and 8d0u: 0.07017603516578674
# RMSD between 8sbn and 8u96: 0.38312381505966187
# RMSD between 9b1z and 9b20: 0.3579128086566925

# %%
df['APO_vs_HOLO'] = RMSD_map.values()
print(df)
# Out:
#    PDB_ID   Status  Conformers  Ligands    Ions Apo_PDB_ID Holo_PDB_ID  \
# 0    2w72  Success           3  ['HEM']   ['K']       5vmm        2w72
# 1    6tn5  Success           1       []  ['CL']       5j80        6tn5
# 2    1x8q  Success           1  ['HEM']      []       2ofm        1x8q
# 3    1e7s  Success           1  ['NAP']      []       1gfs        1e7s
# 4    1xgk  Success           1       []   ['K']       1k6i        1xgk
# ..    ...      ...         ...      ...     ...        ...         ...
# 85   8crh  Success           1  ['NDP']      []       7zzx        8crh
# 86   5j4l  Success           1       []  ['CL']       6tuu        5j4l
# 87   8d0u  Success           1  ['GDP']      []       8d0p        8d0u
# 88   8u96  Success           1  ['ATP']  ['CL']       8sbn        8u96
# 89   9b20  Success           1       []  ['MG']       9b1z        9b20
#
#     APO_vs_HOLO
# 0      3.785067
# 1      0.257624
# 2      0.263629
# 3      0.264183
# 4      0.177352
# ..          ...
# 85     0.715299
# 86     0.482130
# 87     0.070176
# 88     0.383124
# 89     0.357913
#
# [90 rows x 8 columns]

# %%
# APO X HOLO_ALPHA
new_pairs = []
for pair in pairs:
  alpha_model = pair[1] + '_holo'
  # print(alpha_model)
  new_pairs.append([pair[0], alpha_model])
RMSD_map = dict()
pairs_w_model = dict()
model_w_pdb_ids = pd.DataFrame(columns=['apo_pdb_id', 'holo_pdb_id', 'alphafold_model_id'])
model = 0
for pair in new_pairs:
  RMSD = 0
  for i in range(0, 5):
    cmd.reinitialize()
    cmd.load(f"/content/cif_files/content/cif_files/{pair[0][0:4]}.cif", "str1")
    cmd.load(f"/content/all_folds/{pair[1]}/fold_{pair[1]}_model_{i}.cif", "str2")
    RMSD_new = cmd.align("str2", "str1")[0]  # Align structure2 to structure1
    if RMSD < RMSD_new:
      RMSD = RMSD_new
      model = i
  RMSD_map[f'{pair[0][0:4]}_{pair[1][0:4]}'] = RMSD
  new_row = {
    'apo_pdb_id':          pair[0],
    'holo_pdb_id':         pair[1][:4],
    'alphafold_model_id':  model
  }
  model_w_pdb_ids.loc[len(model_w_pdb_ids)] = new_row
#   model_w_pdb_ids.append({'apo_pdb_id': pair[0], 'holo_pdb_id': pair[1][:4], 'alphafold_model_id': model}, ignore_index=True)
  pairs_w_model[pair[0]] = model
  print(f"RMSD between {pair[0]} and {pair[1][0:4]}_alpha: {RMSD}")
# Out:
# RMSD between 5vmm and 2w72_alpha: 0.7270038723945618
# RMSD between 5j80 and 6tn5_alpha: 0.27227675914764404
# RMSD between 2ofm and 1x8q_alpha: 0.3280476927757263
# RMSD between 1gfs and 1e7s_alpha: 0.28335633873939514
# RMSD between 1k6i and 1xgk_alpha: 0.24348580837249756
# RMSD between 1pdb and 1kmv_alpha: 0.6770316362380981
# RMSD between 1d6j and 1m7h_alpha: 1.0385462045669556
# RMSD between 3n80 and 8dr9_alpha: 0.17998363077640533
# RMSD between 2cnu and 2cnq_alpha: 0.5191517472267151
# RMSD between 1xgd and 1us0_alpha: 0.5088538527488708
# RMSD between 7u8k and 4b1y_alpha: 1.3108265399932861
# RMSD between 1ufp and 5yce_alpha: 0.4627609848976135
# RMSD between 3cue and 2bcg_alpha: 1.9346128702163696
# RMSD between 7a2b and 1zk4_alpha: 0.171620175242424
# RMSD between 1apc and 6dyf_alpha: 3.3999927043914795
# RMSD between 1ffh and 2j46_alpha: 0.6109067797660828
# RMSD between 2cd9 and 2cdb_alpha: 0.4408150315284729
# RMSD between 4jp2 and 4jp3_alpha: 0.31142765283584595
# RMSD between 2j9d and 2j9e_alpha: 0.3030886948108673
# RMSD between 2rh2 and 2rk1_alpha: 0.23209688067436218
# RMSD between 2g9i and 7uld_alpha: 0.5434080958366394
# RMSD between 3ish and 2q0k_alpha: 7.033581256866455
# RMSD between 2qys and 2qw8_alpha: 0.20632721483707428
# RMSD between 1jks and 4pf4_alpha: 0.524073600769043
# RMSD between 2y51 and 2y5d_alpha: 0.18366964161396027
# RMSD between 3k74 and 8uw0_alpha: 0.38532379269599915
# RMSD between 2ig7 and 3lq3_alpha: 1.4091200828552246
# RMSD between 3fwk and 3g59_alpha: 0.34199896454811096
# RMSD between 2n1b and 7mo5_alpha: 0.9816966652870178
# RMSD between 3keq and 3keq_alpha: 2.684586763381958
# RMSD between 4co3 and 4cnz_alpha: 0.5581235885620117
# RMSD between 3mjc and 3mjs_alpha: 23.95506477355957
# RMSD between 3mok and 5iqx_alpha: 0.4578571617603302
# RMSD between 3ncp and 3ncr_alpha: 0.5201537609100342
# RMSD between 3oif and 3oif_alpha: 0.38939279317855835
# RMSD between 2yz7 and 5b4t_alpha: 0.3818337023258209
# RMSD between 8dqt and 5lvo_alpha: 0.43847155570983887
# RMSD between 4bg9 and 4bga_alpha: 2.020570993423462
# RMSD between 4ccr and 4up3_alpha: 0.3045310974121094
# RMSD between 3uxm and 3uwk_alpha: 0.803967297077179
# RMSD between 6epp and 8onv_alpha: 0.5699484944343567
# RMSD between 5chp and 4gta_alpha: 0.323607474565506
# RMSD between 4gkb and 4gkb_alpha: 0.31438350677490234
# RMSD between 2rh5 and 4jl5_alpha: 1.8308041095733643
# RMSD between 7qv9 and 4qnr_alpha: 1.6261790990829468
# RMSD between 4trm and 4ohu_alpha: 0.3397597372531891
# RMSD between 5c4r and 5c4n_alpha: 0.6747656464576721
# RMSD between 4xyg and 4xye_alpha: 1.0272974967956543
# RMSD between 4zid and 5aus_alpha: 0.7632180452346802
# RMSD between 7qni and 7r3d_alpha: 2.8766050338745117
# RMSD between 5u95 and 5bst_alpha: 0.3468707203865051
# RMSD between 7g90 and 6v6u_alpha: 0.4875072240829468
# RMSD between 4xap and 4pmj_alpha: 0.368613600730896
# RMSD between 6nlf and 6nlg_alpha: 0.25822365283966064
# RMSD between 5dcw and 5dcy_alpha: 0.5756739377975464
# RMSD between 5dna and 6d4b_alpha: 1.9282374382019043
# RMSD between 5ey7 and 5f0z_alpha: 0.5449815392494202
# RMSD between 4z7y and 5gme_alpha: 0.4910885989665985
# RMSD between 5uxa and 5iwu_alpha: 0.7835074663162231
# RMSD between 5jbj and 5jbg_alpha: 2.266606092453003
# RMSD between 5l40 and 5l3z_alpha: 0.39524510502815247
# RMSD between 4cs6 and 5luh_alpha: 1.137139081954956
# RMSD between 6azp and 6bmt_alpha: 0.2863810956478119
# RMSD between 5ics and 6h0m_alpha: 0.3667784035205841
# RMSD between 1yl5 and 5ugv_alpha: 3.1522014141082764
# RMSD between 4dcv and 2hjg_alpha: 4.491910934448242
# RMSD between 5ggb and 6m65_alpha: 0.3600287139415741
# RMSD between 3x39 and 2exv_alpha: 1.185036301612854
# RMSD between 5y1d and 5y1g_alpha: 0.3845703601837158
# RMSD between 6iep and 4qx6_alpha: 0.9599030017852783
# RMSD between 4h7w and 5v1m_alpha: 0.6521063446998596
# RMSD between 6zx9 and 6qaj_alpha: 3.235690116882324
# RMSD between 4pd0 and 6fgd_alpha: 0.6165950894355774
# RMSD between 3tw8 and 6ekk_alpha: 1.238305687904358
# RMSD between 6jsd and 6jsc_alpha: 8.23708438873291
# RMSD between 6n4a and 6ntb_alpha: 0.3811836540699005
# RMSD between 2fr2 and 6r3y_alpha: 0.38505977392196655
# RMSD between 5jmt and 5y6n_alpha: 0.8171886801719666
# RMSD between 6x2e and 6ok4_alpha: 0.385018914937973
# RMSD between 6x99 and 6x9a_alpha: 0.5724193453788757
# RMSD between 6xxh and 8a0f_alpha: 0.32740843296051025
# RMSD between 7d48 and 7d4o_alpha: 0.6853423714637756
# RMSD between 6iau and 7qzn_alpha: 0.4850509464740753
# RMSD between 1dkg and 7kru_alpha: 3.1863510608673096
# RMSD between 8eac and 3apt_alpha: 0.6330840587615967
# RMSD between 7zzx and 8crh_alpha: 0.8068785071372986
# RMSD between 6tuu and 5j4l_alpha: 0.3674909770488739
# RMSD between 8d0p and 8d0u_alpha: 0.6716925501823425
# RMSD between 8sbn and 8u96_alpha: 3.387932062149048
# RMSD between 9b1z and 9b20_alpha: 0.4107288122177124

# %%
df['APO_vs_HOLO_ALPHA'] = RMSD_map.values()
print(df)
print(model_w_pdb_ids)
model_w_pdb_ids.to_csv('model_w_pdb_ids.csv', index=False)
# Out:
#    PDB_ID   Status  Conformers  Ligands    Ions Apo_PDB_ID Holo_PDB_ID  \
# 0    2w72  Success           3  ['HEM']   ['K']       5vmm        2w72
# 1    6tn5  Success           1       []  ['CL']       5j80        6tn5
# 2    1x8q  Success           1  ['HEM']      []       2ofm        1x8q
# 3    1e7s  Success           1  ['NAP']      []       1gfs        1e7s
# 4    1xgk  Success           1       []   ['K']       1k6i        1xgk
# ..    ...      ...         ...      ...     ...        ...         ...
# 85   8crh  Success           1  ['NDP']      []       7zzx        8crh
# 86   5j4l  Success           1       []  ['CL']       6tuu        5j4l
# 87   8d0u  Success           1  ['GDP']      []       8d0p        8d0u
# 88   8u96  Success           1  ['ATP']  ['CL']       8sbn        8u96
# 89   9b20  Success           1       []  ['MG']       9b1z        9b20
#
#     APO_vs_HOLO  APO_vs_HOLO_ALPHA
# 0      3.785067           0.727004
# 1      0.257624           0.272277
# 2      0.263629           0.328048
# 3      0.264183           0.283356
# 4      0.177352           0.243486
# ..          ...                ...
# 85     0.715299           0.806879
# 86     0.482130           0.367491
# 87     0.070176           0.671693
# 88     0.383124           3.387932
# 89     0.357913           0.410729
#
# [90 rows x 9 columns]
#    apo_pdb_id holo_pdb_id  alphafold_model_id
# 0        5vmm        2w72                   3
# 1        5j80        6tn5                   2
# 2        2ofm        1x8q                   2
# 3        1gfs        1e7s                   0
# 4        1k6i        1xgk                   1
# ..        ...         ...                 ...
# 85       7zzx        8crh                   4
# 86       6tuu        5j4l                   3
# 87       8d0p        8d0u                   3
# 88       8sbn        8u96                   3
# 89       9b1z        9b20                   0
#
# [90 rows x 3 columns]

# %%
# HOLO X APO_ALPHA
new_pairs = []
for pair in pairs:
  alpha_model = pair[0] + '_apo'
  # print(alpha_model)
  new_pairs.append([pair[1], alpha_model, pairs_w_model[pair[0]]])
RMSD_map = dict()
for pair in new_pairs:
  # RMSD = 100
  cmd.reinitialize()
  cmd.load(f"/content/cif_files/content/cif_files/{pair[0]}.cif", "str1")
  cmd.load(f"/content/all_folds/{pair[1]}/fold_{pair[1]}_model_{pair[2]}.cif", "str2")
  RMSD = cmd.align("str2", "str1")[0]  # Align structure2 to structure1

      # print(f"Model: {i}")
  RMSD_map[f'{pair[0]}_{pair[1][0:4]}'] = RMSD
  print(f"RMSD between {pair[0]} and {pair[1][0:4]}_alpha: {RMSD}")
# Out:
# RMSD between 2w72 and 5vmm_alpha: 0.6015127301216125
# RMSD between 6tn5 and 5j80_alpha: 0.44321155548095703
# RMSD between 1x8q and 2ofm_alpha: 0.2589937150478363
# RMSD between 1e7s and 1gfs_alpha: 0.25430214405059814
# RMSD between 1xgk and 1k6i_alpha: 0.17159682512283325
# RMSD between 1kmv and 1pdb_alpha: 0.5687075853347778
# RMSD between 1m7h and 1d6j_alpha: 0.564735472202301
# RMSD between 8dr9 and 3n80_alpha: 0.22595389187335968
# RMSD between 2cnq and 2cnu_alpha: 0.7983500957489014
# RMSD between 1us0 and 1xgd_alpha: 0.2003105729818344
# RMSD between 4b1y and 7u8k_alpha: 1.455474853515625
# RMSD between 5yce and 1ufp_alpha: 0.4989243149757385
# RMSD between 2bcg and 3cue_alpha: 0.526677131652832
# RMSD between 1zk4 and 7a2b_alpha: 0.17777231335639954
# RMSD between 6dyf and 1apc_alpha: 0.3659241795539856
# RMSD between 2j46 and 1ffh_alpha: 1.510663628578186
# RMSD between 2cdb and 2cd9_alpha: 0.17002923786640167
# RMSD between 4jp3 and 4jp2_alpha: 0.3752644956111908
# RMSD between 2j9e and 2j9d_alpha: 0.3669544458389282
# RMSD between 2rk1 and 2rh2_alpha: 0.1840261071920395
# RMSD between 7uld and 2g9i_alpha: 0.7230846285820007
# RMSD between 2q0k and 3ish_alpha: 0.9123369455337524
# RMSD between 2qw8 and 2qys_alpha: 0.22050902247428894
# RMSD between 4pf4 and 1jks_alpha: 0.6042061448097229
# RMSD between 2y5d and 2y51_alpha: 0.17253050208091736
# RMSD between 8uw0 and 3k74_alpha: 0.2873942255973816
# RMSD between 3lq3 and 2ig7_alpha: 0.9681889414787292
# RMSD between 3g59 and 3fwk_alpha: 0.31256961822509766
# RMSD between 7mo5 and 2n1b_alpha: 0.3775080144405365
# RMSD between 3keq and 3keq_alpha: 1.4505285024642944
# RMSD between 4cnz and 4co3_alpha: 0.2991771399974823
# RMSD between 3mjs and 3mjc_alpha: 28.027591705322266
# RMSD between 5iqx and 3mok_alpha: 0.19946111738681793
# RMSD between 3ncr and 3ncp_alpha: 0.38894739747047424
# RMSD between 3oif and 3oif_alpha: 0.43023601174354553
# RMSD between 5b4t and 2yz7_alpha: 0.29504427313804626
# RMSD between 5lvo and 8dqt_alpha: 0.3937385380268097
# RMSD between 4bga and 4bg9_alpha: 0.26517921686172485
# RMSD between 4up3 and 4ccr_alpha: 6.888120651245117
# RMSD between 3uwk and 3uxm_alpha: 0.42945995926856995
# RMSD between 8onv and 6epp_alpha: 0.40331584215164185
# RMSD between 4gta and 5chp_alpha: 0.243117094039917
# RMSD between 4gkb and 4gkb_alpha: 0.2802165746688843
# RMSD between 4jl5 and 2rh5_alpha: 0.3977731168270111
# RMSD between 4qnr and 7qv9_alpha: 0.9624791145324707
# RMSD between 4ohu and 4trm_alpha: 0.3610428273677826
# RMSD between 5c4n and 5c4r_alpha: 0.8158247470855713
# RMSD between 4xye and 4xyg_alpha: 0.45546093583106995
# RMSD between 5aus and 4zid_alpha: 17.976648330688477
# RMSD between 7r3d and 7qni_alpha: 0.4421589970588684
# RMSD between 5bst and 5u95_alpha: 0.3443607687950134
# RMSD between 6v6u and 7g90_alpha: 0.34695345163345337
# RMSD between 4pmj and 4xap_alpha: 0.3272952735424042
# RMSD between 6nlg and 6nlf_alpha: 0.2285134643316269
# RMSD between 5dcy and 5dcw_alpha: 0.40174439549446106
# RMSD between 6d4b and 5dna_alpha: 0.2548750936985016
# RMSD between 5f0z and 5ey7_alpha: 0.2846842110157013
# RMSD between 5gme and 4z7y_alpha: 0.4750146269798279
# RMSD between 5iwu and 5uxa_alpha: 0.44846677780151367
# RMSD between 5jbg and 5jbj_alpha: 1.5061355829238892
# RMSD between 5l3z and 5l40_alpha: 0.3945815861225128
# RMSD between 5luh and 4cs6_alpha: 0.24878500401973724
# RMSD between 6bmt and 6azp_alpha: 0.23306870460510254
# RMSD between 6h0m and 5ics_alpha: 0.24635130167007446
# RMSD between 5ugv and 1yl5_alpha: 1.29329252243042
# RMSD between 2hjg and 4dcv_alpha: 5.099315643310547
# RMSD between 6m65 and 5ggb_alpha: 0.4396089017391205
# RMSD between 2exv and 3x39_alpha: 0.2731013298034668
# RMSD between 5y1g and 5y1d_alpha: 0.4827093183994293
# RMSD between 4qx6 and 6iep_alpha: 0.39262494444847107
# RMSD between 5v1m and 4h7w_alpha: 0.31905239820480347
# RMSD between 6qaj and 6zx9_alpha: 0.6599358320236206
# RMSD between 6fgd and 4pd0_alpha: 0.6588549613952637
# RMSD between 6ekk and 3tw8_alpha: 0.8756058216094971
# RMSD between 6jsc and 6jsd_alpha: 21.560190200805664
# RMSD between 6ntb and 6n4a_alpha: 0.41239920258522034
# RMSD between 6r3y and 2fr2_alpha: 0.414692759513855
# RMSD between 5y6n and 5jmt_alpha: 0.7532232403755188
# RMSD between 6ok4 and 6x2e_alpha: 0.5108839869499207
# RMSD between 6x9a and 6x99_alpha: 0.5901363492012024
# RMSD between 8a0f and 6xxh_alpha: 0.3463682532310486
# RMSD between 7d4o and 7d48_alpha: 0.3717252016067505
# RMSD between 7qzn and 6iau_alpha: 0.47340157628059387
# RMSD between 7kru and 1dkg_alpha: 1.356552004814148
# RMSD between 3apt and 8eac_alpha: 0.7802404165267944
# RMSD between 8crh and 7zzx_alpha: 0.46164393424987793
# RMSD between 5j4l and 6tuu_alpha: 0.5501558780670166
# RMSD between 8d0u and 8d0p_alpha: 0.5278201103210449
# RMSD between 8u96 and 8sbn_alpha: 2.0933330059051514
# RMSD between 9b20 and 9b1z_alpha: 0.45620962977409363

# %%
df = pd.read_csv("/content/RMSD_results.csv", sep=',')
df['HOLO_vs_APO_ALPHA'] = RMSD_map.values()
print(df)
df.to_csv('RMSD_results.csv', index=False)
# Out:
#    PDB_ID   Status  Conformers  Ligands    Ions Apo_PDB_ID Holo_PDB_ID  \
# 0    2w72  Success           3  ['HEM']   ['K']       5vmm        2w72
# 1    6tn5  Success           1       []  ['CL']       5j80        6tn5
# 2    1x8q  Success           1  ['HEM']      []       2ofm        1x8q
# 3    1e7s  Success           1  ['NAP']      []       1gfs        1e7s
# 4    1xgk  Success           1       []   ['K']       1k6i        1xgk
# ..    ...      ...         ...      ...     ...        ...         ...
# 85   8crh  Success           1  ['NDP']      []       7zzx        8crh
# 86   5j4l  Success           1       []  ['CL']       6tuu        5j4l
# 87   8d0u  Success           1  ['GDP']      []       8d0p        8d0u
# 88   8u96  Success           1  ['ATP']  ['CL']       8sbn        8u96
# 89   9b20  Success           1       []  ['MG']       9b1z        9b20
#
#     APO_vs_HOLO  APO_vs_HOLO_ALPHA  APO_vs_APO_ALPHA  HOLO_vs_HOLO_ALPHA  \
# 0      3.785067           0.727004          0.635192            0.712308
# 1      0.257624           0.272277          0.421065            0.267859
# 2      0.263629           0.328048          0.352440            0.231631
# 3      0.264183           0.283356          0.247993            0.202855
# 4      0.177352           0.243486          0.229911            0.194335
# ..          ...                ...               ...                 ...
# 85     0.715299           0.806879          0.911738            0.376641
# 86     0.482130           0.367491          0.427612            0.467868
# 87     0.070176           0.671693          0.520820            0.626351
# 88     0.383124           3.387932          2.237975            3.308408
# 89     0.357913           0.410729          0.463587            0.317411
#
#     APO_ALPHA_vs_HOLO_ALPHA  HOLO_vs_APO_ALPHA
# 0                  0.356937           0.601513
# 1                  4.640476           0.443212
# 2                  0.183481           0.258994
# 3                  0.144231           0.254302
# 4                  0.152927           0.171597
# ..                      ...                ...
# 85                 0.316142           0.461644
# 86                 0.541948           0.550156
# 87                 0.632332           0.527820
# 88                 1.287520           2.093333
# 89                 0.284479           0.456210
#
# [90 rows x 13 columns]

# %%
# APO X APO_ALPHA
new_pairs = []
for pair in pairs:
  alpha_model = pair[0] + '_apo'
  # print(alpha_model)
  new_pairs.append([pair[0], alpha_model, pairs_w_model[pair[0]]])
RMSD_map = dict()
for pair in new_pairs:
  # RMSD = 100
  cmd.reinitialize()
  cmd.load(f"/content/cif_files/content/cif_files/{pair[0]}.cif", "str1")
  cmd.load(f"/content/all_folds/{pair[1]}/fold_{pair[1]}_model_{pair[2]}.cif", "str2")
  RMSD = cmd.align("str2", "str1")[0]  # Align structure2 to structure1

      # print(f"Model: {i}")
  RMSD_map[f'{pair[0]}_{pair[1][0:4]}'] = RMSD
  print(f"RMSD between {pair[0]} and {pair[1][0:4]}_alpha: {RMSD}")
# Out:
# RMSD between 5vmm and 5vmm_alpha: 0.6351919174194336
# RMSD between 5j80 and 5j80_alpha: 0.4210648238658905
# RMSD between 2ofm and 2ofm_alpha: 0.3524399995803833
# RMSD between 1gfs and 1gfs_alpha: 0.24799276888370514
# RMSD between 1k6i and 1k6i_alpha: 0.22991079092025757
# RMSD between 1pdb and 1pdb_alpha: 0.6412376165390015
# RMSD between 1d6j and 1d6j_alpha: 0.8791496753692627
# RMSD between 3n80 and 3n80_alpha: 0.17029742896556854
# RMSD between 2cnu and 2cnu_alpha: 0.8026918768882751
# RMSD between 1xgd and 1xgd_alpha: 0.46913692355155945
# RMSD between 7u8k and 7u8k_alpha: 2.1467695236206055
# RMSD between 1ufp and 1ufp_alpha: 0.31079816818237305
# RMSD between 3cue and 3cue_alpha: 1.8968489170074463
# RMSD between 7a2b and 7a2b_alpha: 0.16601382195949554
# RMSD between 1apc and 1apc_alpha: 3.3575353622436523
# RMSD between 1ffh and 1ffh_alpha: 1.095964789390564
# RMSD between 2cd9 and 2cd9_alpha: 0.3199032247066498
# RMSD between 4jp2 and 4jp2_alpha: 0.3846393823623657
# RMSD between 2j9d and 2j9d_alpha: 0.3449200689792633
# RMSD between 2rh2 and 2rh2_alpha: 0.18281593918800354
# RMSD between 2g9i and 2g9i_alpha: 0.5360087752342224
# RMSD between 3ish and 3ish_alpha: 0.8201736211776733
# RMSD between 2qys and 2qys_alpha: 0.22592194378376007
# RMSD between 1jks and 1jks_alpha: 0.6085956692695618
# RMSD between 2y51 and 2y51_alpha: 0.20723262429237366
# RMSD between 3k74 and 3k74_alpha: 0.416413813829422
# RMSD between 2ig7 and 2ig7_alpha: 0.43393710255622864
# RMSD between 3fwk and 3fwk_alpha: 0.2727331817150116
# RMSD between 2n1b and 2n1b_alpha: 0.9731104373931885
# RMSD between 3keq and 3keq_alpha: 1.4505285024642944
# RMSD between 4co3 and 4co3_alpha: 0.43197041749954224
# RMSD between 3mjc and 3mjc_alpha: 28.01658821105957
# RMSD between 3mok and 3mok_alpha: 0.401804119348526
# RMSD between 3ncp and 3ncp_alpha: 0.39323312044143677
# RMSD between 3oif and 3oif_alpha: 0.43023601174354553
# RMSD between 2yz7 and 2yz7_alpha: 0.37934258580207825
# RMSD between 8dqt and 8dqt_alpha: 0.3776305913925171
# RMSD between 4bg9 and 4bg9_alpha: 0.45246589183807373
# RMSD between 4ccr and 4ccr_alpha: 0.7134628295898438
# RMSD between 3uxm and 3uxm_alpha: 0.3703473210334778
# RMSD between 6epp and 6epp_alpha: 0.5201638340950012
# RMSD between 5chp and 5chp_alpha: 0.2974645793437958
# RMSD between 4gkb and 4gkb_alpha: 0.2802165746688843
# RMSD between 2rh5 and 2rh5_alpha: 1.7369585037231445
# RMSD between 7qv9 and 7qv9_alpha: 1.7879194021224976
# RMSD between 4trm and 4trm_alpha: 0.375598281621933
# RMSD between 5c4r and 5c4r_alpha: 0.826767086982727
# RMSD between 4xyg and 4xyg_alpha: 0.9506362080574036
# RMSD between 4zid and 4zid_alpha: 0.5332422256469727
# RMSD between 7qni and 7qni_alpha: 2.8749468326568604
# RMSD between 5u95 and 5u95_alpha: 0.33077144622802734
# RMSD between 7g90 and 7g90_alpha: 0.4981069266796112
# RMSD between 4xap and 4xap_alpha: 0.32587531208992004
# RMSD between 6nlf and 6nlf_alpha: 0.2648634612560272
# RMSD between 5dcw and 5dcw_alpha: 0.4068513512611389
# RMSD between 5dna and 5dna_alpha: 1.72794771194458
# RMSD between 5ey7 and 5ey7_alpha: 0.5054273009300232
# RMSD between 4z7y and 4z7y_alpha: 0.5177642703056335
# RMSD between 5uxa and 5uxa_alpha: 0.617515504360199
# RMSD between 5jbj and 5jbj_alpha: 1.9254270792007446
# RMSD between 5l40 and 5l40_alpha: 0.4018702208995819
# RMSD between 4cs6 and 4cs6_alpha: 0.8575073480606079
# RMSD between 6azp and 6azp_alpha: 0.2919104993343353
# RMSD between 5ics and 5ics_alpha: 0.3911684453487396
# RMSD between 1yl5 and 1yl5_alpha: 1.0474718809127808
# RMSD between 4dcv and 4dcv_alpha: 4.061496734619141
# RMSD between 5ggb and 5ggb_alpha: 0.4685195982456207
# RMSD between 3x39 and 3x39_alpha: 0.7092245817184448
# RMSD between 5y1d and 5y1d_alpha: 0.5786807537078857
# RMSD between 6iep and 6iep_alpha: 0.8348897695541382
# RMSD between 4h7w and 4h7w_alpha: 0.6013668179512024
# RMSD between 6zx9 and 6zx9_alpha: 2.871716260910034
# RMSD between 4pd0 and 4pd0_alpha: 0.5330135226249695
# RMSD between 3tw8 and 3tw8_alpha: 1.0133122205734253
# RMSD between 6jsd and 6jsd_alpha: 10.939123153686523
# RMSD between 6n4a and 6n4a_alpha: 0.3707561194896698
# RMSD between 2fr2 and 2fr2_alpha: 0.42403578758239746
# RMSD between 5jmt and 5jmt_alpha: 0.6816704273223877
# RMSD between 6x2e and 6x2e_alpha: 0.3870968520641327
# RMSD between 6x99 and 6x99_alpha: 0.6291521191596985
# RMSD between 6xxh and 6xxh_alpha: 0.31870192289352417
# RMSD between 7d48 and 7d48_alpha: 0.7234522700309753
# RMSD between 6iau and 6iau_alpha: 0.38153132796287537
# RMSD between 1dkg and 1dkg_alpha: 3.1295013427734375
# RMSD between 8eac and 8eac_alpha: 0.725593090057373
# RMSD between 7zzx and 7zzx_alpha: 0.9117382764816284
# RMSD between 6tuu and 6tuu_alpha: 0.4276123642921448
# RMSD between 8d0p and 8d0p_alpha: 0.5208195447921753
# RMSD between 8sbn and 8sbn_alpha: 2.2379751205444336
# RMSD between 9b1z and 9b1z_alpha: 0.4635870158672333

# %%
df['APO_vs_APO_ALPHA'] = RMSD_map.values()
print(df)
# Out:
#    PDB_ID   Status  Conformers  Ligands    Ions Apo_PDB_ID Holo_PDB_ID  \
# 0    2w72  Success           3  ['HEM']   ['K']       5vmm        2w72
# 1    6tn5  Success           1       []  ['CL']       5j80        6tn5
# 2    1x8q  Success           1  ['HEM']      []       2ofm        1x8q
# 3    1e7s  Success           1  ['NAP']      []       1gfs        1e7s
# 4    1xgk  Success           1       []   ['K']       1k6i        1xgk
# ..    ...      ...         ...      ...     ...        ...         ...
# 85   8crh  Success           1  ['NDP']      []       7zzx        8crh
# 86   5j4l  Success           1       []  ['CL']       6tuu        5j4l
# 87   8d0u  Success           1  ['GDP']      []       8d0p        8d0u
# 88   8u96  Success           1  ['ATP']  ['CL']       8sbn        8u96
# 89   9b20  Success           1       []  ['MG']       9b1z        9b20
#
#     APO_vs_HOLO  APO_vs_HOLO_ALPHA  APO_vs_APO_ALPHA
# 0      3.785067           0.727004          0.635192
# 1      0.257624           0.272277          0.421065
# 2      0.263629           0.328048          0.352440
# 3      0.264183           0.283356          0.247993
# 4      0.177352           0.243486          0.229911
# ..          ...                ...               ...
# 85     0.715299           0.806879          0.911738
# 86     0.482130           0.367491          0.427612
# 87     0.070176           0.671693          0.520820
# 88     0.383124           3.387932          2.237975
# 89     0.357913           0.410729          0.463587
#
# [90 rows x 10 columns]

# %%
# HOLO X HOLO_ALPHA
new_pairs = []
for pair in pairs:
  alpha_model = pair[1] + '_holo'
  # print(alpha_model)
  new_pairs.append([pair[1], alpha_model, pairs_w_model[pair[0]]])
RMSD_map = dict()
for pair in new_pairs:
  # RMSD = 100
  cmd.reinitialize()
  cmd.load(f"/content/cif_files/content/cif_files/{pair[0]}.cif", "str1")
  cmd.load(f"/content/all_folds/{pair[1]}/fold_{pair[1]}_model_{pair[2]}.cif", "str2")
  RMSD = cmd.align("str2", "str1")[0]  # Align structure2 to structure1

      # print(f"Model: {i}")
  RMSD_map[f'{pair[0]}_{pair[1][0:4]}'] = RMSD
  print(f"RMSD between {pair[0]} and {pair[1][0:4]}_alpha: {RMSD}")
# Out:
# RMSD between 2w72 and 2w72_alpha: 0.7123081684112549
# RMSD between 6tn5 and 6tn5_alpha: 0.26785922050476074
# RMSD between 1x8q and 1x8q_alpha: 0.2316313534975052
# RMSD between 1e7s and 1e7s_alpha: 0.20285482704639435
# RMSD between 1xgk and 1xgk_alpha: 0.19433462619781494
# RMSD between 1kmv and 1kmv_alpha: 0.5250555872917175
# RMSD between 1m7h and 1m7h_alpha: 0.5978659987449646
# RMSD between 8dr9 and 8dr9_alpha: 0.20531490445137024
# RMSD between 2cnq and 2cnq_alpha: 1.078899621963501
# RMSD between 1us0 and 1us0_alpha: 0.13766351342201233
# RMSD between 4b1y and 4b1y_alpha: 0.4797632694244385
# RMSD between 5yce and 5yce_alpha: 0.3338206708431244
# RMSD between 2bcg and 2bcg_alpha: 0.255928635597229
# RMSD between 1zk4 and 1zk4_alpha: 0.12602490186691284
# RMSD between 6dyf and 6dyf_alpha: 0.3284011483192444
# RMSD between 2j46 and 2j46_alpha: 0.7227142453193665
# RMSD between 2cdb and 2cdb_alpha: 0.27384236454963684
# RMSD between 4jp3 and 4jp3_alpha: 0.32368558645248413
# RMSD between 2j9e and 2j9e_alpha: 0.24829402565956116
# RMSD between 2rk1 and 2rk1_alpha: 0.21465231478214264
# RMSD between 7uld and 7uld_alpha: 0.4034412205219269
# RMSD between 2q0k and 2q0k_alpha: 7.269191741943359
# RMSD between 2qw8 and 2qw8_alpha: 0.161299929022789
# RMSD between 4pf4 and 4pf4_alpha: 0.48469534516334534
# RMSD between 2y5d and 2y5d_alpha: 0.14825592935085297
# RMSD between 8uw0 and 8uw0_alpha: 0.3438285291194916
# RMSD between 3lq3 and 3lq3_alpha: 0.3020549714565277
# RMSD between 3g59 and 3g59_alpha: 0.36019623279571533
# RMSD between 7mo5 and 7mo5_alpha: 0.28352662920951843
# RMSD between 3keq and 3keq_alpha: 2.684586763381958
# RMSD between 4cnz and 4cnz_alpha: 0.5390061736106873
# RMSD between 3mjs and 3mjs_alpha: 23.994731903076172
# RMSD between 5iqx and 5iqx_alpha: 0.17482364177703857
# RMSD between 3ncr and 3ncr_alpha: 0.44991403818130493
# RMSD between 3oif and 3oif_alpha: 0.38939279317855835
# RMSD between 5b4t and 5b4t_alpha: 0.2949239909648895
# RMSD between 5lvo and 5lvo_alpha: 0.33274972438812256
# RMSD between 4bga and 4bga_alpha: 2.4205167293548584
# RMSD between 4up3 and 4up3_alpha: 2.7305877208709717
# RMSD between 3uwk and 3uwk_alpha: 0.6386426091194153
# RMSD between 8onv and 8onv_alpha: 0.39735063910484314
# RMSD between 4gta and 4gta_alpha: 0.2735661566257477
# RMSD between 4gkb and 4gkb_alpha: 0.31438350677490234
# RMSD between 4jl5 and 4jl5_alpha: 0.5019348859786987
# RMSD between 4qnr and 4qnr_alpha: 0.9361377358436584
# RMSD between 4ohu and 4ohu_alpha: 0.2872784733772278
# RMSD between 5c4n and 5c4n_alpha: 1.157700777053833
# RMSD between 4xye and 4xye_alpha: 0.3013678789138794
# RMSD between 5aus and 5aus_alpha: 17.42333221435547
# RMSD between 7r3d and 7r3d_alpha: 0.40918686985969543
# RMSD between 5bst and 5bst_alpha: 0.3224278390407562
# RMSD between 6v6u and 6v6u_alpha: 0.33750486373901367
# RMSD between 4pmj and 4pmj_alpha: 0.30202314257621765
# RMSD between 6nlg and 6nlg_alpha: 0.2041473239660263
# RMSD between 5dcy and 5dcy_alpha: 0.2591545879840851
# RMSD between 6d4b and 6d4b_alpha: 0.22453336417675018
# RMSD between 5f0z and 5f0z_alpha: 0.32672119140625
# RMSD between 5gme and 5gme_alpha: 0.43717318773269653
# RMSD between 5iwu and 5iwu_alpha: 0.3592277467250824
# RMSD between 5jbg and 5jbg_alpha: 1.5272821187973022
# RMSD between 5l3z and 5l3z_alpha: 0.3558690547943115
# RMSD between 5luh and 5luh_alpha: 0.4427299201488495
# RMSD between 6bmt and 6bmt_alpha: 0.24084581434726715
# RMSD between 6h0m and 6h0m_alpha: 0.21772506833076477
# RMSD between 5ugv and 5ugv_alpha: 3.364368200302124
# RMSD between 2hjg and 2hjg_alpha: 5.513218402862549
# RMSD between 6m65 and 6m65_alpha: 0.3162766098976135
# RMSD between 2exv and 2exv_alpha: 0.3222389817237854
# RMSD between 5y1g and 5y1g_alpha: 0.2875303328037262
# RMSD between 4qx6 and 4qx6_alpha: 0.3058760464191437
# RMSD between 5v1m and 5v1m_alpha: 0.36452165246009827
# RMSD between 6qaj and 6qaj_alpha: 0.573261559009552
# RMSD between 6fgd and 6fgd_alpha: 0.5073622465133667
# RMSD between 6ekk and 6ekk_alpha: 1.0778887271881104
# RMSD between 6jsc and 6jsc_alpha: 22.356327056884766
# RMSD between 6ntb and 6ntb_alpha: 0.5919507145881653
# RMSD between 6r3y and 6r3y_alpha: 0.3377856910228729
# RMSD between 5y6n and 5y6n_alpha: 0.4503832459449768
# RMSD between 6ok4 and 6ok4_alpha: 0.38492026925086975
# RMSD between 6x9a and 6x9a_alpha: 0.6008031368255615
# RMSD between 8a0f and 8a0f_alpha: 0.28249144554138184
# RMSD between 7d4o and 7d4o_alpha: 0.31236517429351807
# RMSD between 7qzn and 7qzn_alpha: 0.5352081060409546
# RMSD between 7kru and 7kru_alpha: 1.5799211263656616
# RMSD between 3apt and 3apt_alpha: 0.7584636211395264
# RMSD between 8crh and 8crh_alpha: 0.37664103507995605
# RMSD between 5j4l and 5j4l_alpha: 0.46786829829216003
# RMSD between 8d0u and 8d0u_alpha: 0.6263511776924133
# RMSD between 8u96 and 8u96_alpha: 3.308408260345459
# RMSD between 9b20 and 9b20_alpha: 0.31741079688072205

# %%
df['HOLO_vs_HOLO_ALPHA'] = RMSD_map.values()
print(df)
# Out:
#    PDB_ID   Status  Conformers  Ligands    Ions Apo_PDB_ID Holo_PDB_ID  \
# 0    2w72  Success           3  ['HEM']   ['K']       5vmm        2w72
# 1    6tn5  Success           1       []  ['CL']       5j80        6tn5
# 2    1x8q  Success           1  ['HEM']      []       2ofm        1x8q
# 3    1e7s  Success           1  ['NAP']      []       1gfs        1e7s
# 4    1xgk  Success           1       []   ['K']       1k6i        1xgk
# ..    ...      ...         ...      ...     ...        ...         ...
# 85   8crh  Success           1  ['NDP']      []       7zzx        8crh
# 86   5j4l  Success           1       []  ['CL']       6tuu        5j4l
# 87   8d0u  Success           1  ['GDP']      []       8d0p        8d0u
# 88   8u96  Success           1  ['ATP']  ['CL']       8sbn        8u96
# 89   9b20  Success           1       []  ['MG']       9b1z        9b20
#
#     APO_vs_HOLO  APO_vs_HOLO_ALPHA  APO_vs_APO_ALPHA  HOLO_vs_HOLO_ALPHA
# 0      3.785067           0.727004          0.635192            0.712308
# 1      0.257624           0.272277          0.421065            0.267859
# 2      0.263629           0.328048          0.352440            0.231631
# 3      0.264183           0.283356          0.247993            0.202855
# 4      0.177352           0.243486          0.229911            0.194335
# ..          ...                ...               ...                 ...
# 85     0.715299           0.806879          0.911738            0.376641
# 86     0.482130           0.367491          0.427612            0.467868
# 87     0.070176           0.671693          0.520820            0.626351
# 88     0.383124           3.387932          2.237975            3.308408
# 89     0.357913           0.410729          0.463587            0.317411
#
# [90 rows x 11 columns]

# %%
# APO_ALPHA X HOLO_ALPHA
new_pairs = []
for pair in pairs:
  alpha_model_apo = pair[0] + '_apo'
  alpha_model_holo = pair[1] + '_holo'
  # print(alpha_model)
  new_pairs.append([alpha_model_apo, alpha_model_holo, pairs_w_model[pair[0]]])
RMSD_map = dict()
for pair in new_pairs:
  # RMSD = 100
  cmd.reinitialize()
  cmd.load(f"/content/all_folds/{pair[0]}/fold_{pair[0]}_model_{pair[2]}.cif", "str1")
  cmd.load(f"/content/all_folds/{pair[1]}/fold_{pair[1]}_model_{pair[2]}.cif", "str2")
  RMSD = cmd.align("str2", "str1")[0]  # Align structure2 to structure1

      # print(f"Model: {i}")
  RMSD_map[f'{pair[0][0:4]}_{pair[1][0:4]}'] = RMSD
  print(f"RMSD between {pair[0][0:4]}_apo_alpha and {pair[1][0:4]}_holo_alpha: {RMSD}")
# Out:
# RMSD between 5vmm_apo_alpha and 2w72_holo_alpha: 0.3569370210170746
# RMSD between 5j80_apo_alpha and 6tn5_holo_alpha: 4.640476226806641
# RMSD between 2ofm_apo_alpha and 1x8q_holo_alpha: 0.1834811568260193
# RMSD between 1gfs_apo_alpha and 1e7s_holo_alpha: 0.14423111081123352
# RMSD between 1k6i_apo_alpha and 1xgk_holo_alpha: 0.15292668342590332
# RMSD between 1pdb_apo_alpha and 1kmv_holo_alpha: 0.1663416177034378
# RMSD between 1d6j_apo_alpha and 1m7h_holo_alpha: 0.341519832611084
# RMSD between 3n80_apo_alpha and 8dr9_holo_alpha: 0.137351393699646
# RMSD between 2cnu_apo_alpha and 2cnq_holo_alpha: 0.7092178463935852
# RMSD between 1xgd_apo_alpha and 1us0_holo_alpha: 0.1540887951850891
# RMSD between 7u8k_apo_alpha and 4b1y_holo_alpha: 1.2708673477172852
# RMSD between 1ufp_apo_alpha and 5yce_holo_alpha: 0.32955530285835266
# RMSD between 3cue_apo_alpha and 2bcg_holo_alpha: 0.3593992590904236
# RMSD between 7a2b_apo_alpha and 1zk4_holo_alpha: 0.15144166350364685
# RMSD between 1apc_apo_alpha and 6dyf_holo_alpha: 0.2733457386493683
# RMSD between 1ffh_apo_alpha and 2j46_holo_alpha: 1.58279550075531
# RMSD between 2cd9_apo_alpha and 2cdb_holo_alpha: 0.12559331953525543
# RMSD between 4jp2_apo_alpha and 4jp3_holo_alpha: 0.24801640212535858
# RMSD between 2j9d_apo_alpha and 2j9e_holo_alpha: 0.5623148083686829
# RMSD between 2rh2_apo_alpha and 2rk1_holo_alpha: 0.26890072226524353
# RMSD between 2g9i_apo_alpha and 7uld_holo_alpha: 0.4897708296775818
# RMSD between 3ish_apo_alpha and 2q0k_holo_alpha: 6.5776448249816895
# RMSD between 2qys_apo_alpha and 2qw8_holo_alpha: 0.17507058382034302
# RMSD between 1jks_apo_alpha and 4pf4_holo_alpha: 2.6070337295532227
# RMSD between 2y51_apo_alpha and 2y5d_holo_alpha: 0.07984507828950882
# RMSD between 3k74_apo_alpha and 8uw0_holo_alpha: 0.23320400714874268
# RMSD between 2ig7_apo_alpha and 3lq3_holo_alpha: 1.5274062156677246
# RMSD between 3fwk_apo_alpha and 3g59_holo_alpha: 0.16767588257789612
# RMSD between 2n1b_apo_alpha and 7mo5_holo_alpha: 0.19415445625782013
# RMSD between 3keq_apo_alpha and 3keq_holo_alpha: 0.6807478666305542
# RMSD between 4co3_apo_alpha and 4cnz_holo_alpha: 0.2795552909374237
# RMSD between 3mjc_apo_alpha and 3mjs_holo_alpha: 2.778106451034546
# RMSD between 3mok_apo_alpha and 5iqx_holo_alpha: 0.1780480593442917
# RMSD between 3ncp_apo_alpha and 3ncr_holo_alpha: 0.3969190716743469
# RMSD between 3oif_apo_alpha and 3oif_holo_alpha: 0.1832527071237564
# RMSD between 2yz7_apo_alpha and 5b4t_holo_alpha: 0.17817546427249908
# RMSD between 8dqt_apo_alpha and 5lvo_holo_alpha: 13.869876861572266
# RMSD between 4bg9_apo_alpha and 4bga_holo_alpha: 1.832762360572815
# RMSD between 4ccr_apo_alpha and 4up3_holo_alpha: 6.806314945220947
# RMSD between 3uxm_apo_alpha and 3uwk_holo_alpha: 0.7449928522109985
# RMSD between 6epp_apo_alpha and 8onv_holo_alpha: 0.18208490312099457
# RMSD between 5chp_apo_alpha and 4gta_holo_alpha: 0.13978615403175354
# RMSD between 4gkb_apo_alpha and 4gkb_holo_alpha: 0.3138110935688019
# RMSD between 2rh5_apo_alpha and 4jl5_holo_alpha: 0.3402142822742462
# RMSD between 7qv9_apo_alpha and 4qnr_holo_alpha: 0.6525509357452393
# RMSD between 4trm_apo_alpha and 4ohu_holo_alpha: 0.29609060287475586
# RMSD between 5c4r_apo_alpha and 5c4n_holo_alpha: 0.49695563316345215
# RMSD between 4xyg_apo_alpha and 4xye_holo_alpha: 0.21518942713737488
# RMSD between 4zid_apo_alpha and 5aus_holo_alpha: 0.2258933186531067
# RMSD between 7qni_apo_alpha and 7r3d_holo_alpha: 0.1260613352060318
# RMSD between 5u95_apo_alpha and 5bst_holo_alpha: 0.229811429977417
# RMSD between 7g90_apo_alpha and 6v6u_holo_alpha: 0.19509048759937286
# RMSD between 4xap_apo_alpha and 4pmj_holo_alpha: 0.243107408285141
# RMSD between 6nlf_apo_alpha and 6nlg_holo_alpha: 0.12298715859651566
# RMSD between 5dcw_apo_alpha and 5dcy_holo_alpha: 0.27157682180404663
# RMSD between 5dna_apo_alpha and 6d4b_holo_alpha: 0.22627690434455872
# RMSD between 5ey7_apo_alpha and 5f0z_holo_alpha: 0.1928033083677292
# RMSD between 4z7y_apo_alpha and 5gme_holo_alpha: 0.28949856758117676
# RMSD between 5uxa_apo_alpha and 5iwu_holo_alpha: 0.30763110518455505
# RMSD between 5jbj_apo_alpha and 5jbg_holo_alpha: 0.6178407073020935
# RMSD between 5l40_apo_alpha and 5l3z_holo_alpha: 0.35685497522354126
# RMSD between 4cs6_apo_alpha and 5luh_holo_alpha: 0.5164214968681335
# RMSD between 6azp_apo_alpha and 6bmt_holo_alpha: 0.16361206769943237
# RMSD between 5ics_apo_alpha and 6h0m_holo_alpha: 0.12627820670604706
# RMSD between 1yl5_apo_alpha and 5ugv_holo_alpha: 2.4778544902801514
# RMSD between 4dcv_apo_alpha and 2hjg_holo_alpha: 1.1361645460128784
# RMSD between 5ggb_apo_alpha and 6m65_holo_alpha: 0.5563198328018188
# RMSD between 3x39_apo_alpha and 2exv_holo_alpha: 0.26399946212768555
# RMSD between 5y1d_apo_alpha and 5y1g_holo_alpha: 0.3327683210372925
# RMSD between 6iep_apo_alpha and 4qx6_holo_alpha: 0.39013463258743286
# RMSD between 4h7w_apo_alpha and 5v1m_holo_alpha: 0.39400750398635864
# RMSD between 6zx9_apo_alpha and 6qaj_holo_alpha: 0.4531109631061554
# RMSD between 4pd0_apo_alpha and 6fgd_holo_alpha: 13.426772117614746
# RMSD between 3tw8_apo_alpha and 6ekk_holo_alpha: 0.2369350641965866
# RMSD between 6jsd_apo_alpha and 6jsc_holo_alpha: 5.7790350914001465
# RMSD between 6n4a_apo_alpha and 6ntb_holo_alpha: 0.40886953473091125
# RMSD between 2fr2_apo_alpha and 6r3y_holo_alpha: 0.2796814739704132
# RMSD between 5jmt_apo_alpha and 5y6n_holo_alpha: 6.830386161804199
# RMSD between 6x2e_apo_alpha and 6ok4_holo_alpha: 0.1875123679637909
# RMSD between 6x99_apo_alpha and 6x9a_holo_alpha: 0.444022536277771
# RMSD between 6xxh_apo_alpha and 8a0f_holo_alpha: 0.2317538857460022
# RMSD between 7d48_apo_alpha and 7d4o_holo_alpha: 0.21706832945346832
# RMSD between 6iau_apo_alpha and 7qzn_holo_alpha: 0.40571877360343933
# RMSD between 1dkg_apo_alpha and 7kru_holo_alpha: 0.6008893847465515
# RMSD between 8eac_apo_alpha and 3apt_holo_alpha: 0.29015156626701355
# RMSD between 7zzx_apo_alpha and 8crh_holo_alpha: 0.31614235043525696
# RMSD between 6tuu_apo_alpha and 5j4l_holo_alpha: 0.5419476628303528
# RMSD between 8d0p_apo_alpha and 8d0u_holo_alpha: 0.6323317289352417
# RMSD between 8sbn_apo_alpha and 8u96_holo_alpha: 1.287519931793213
# RMSD between 9b1z_apo_alpha and 9b20_holo_alpha: 0.2844792902469635

# %%
df['APO_ALPHA_vs_HOLO_ALPHA'] = RMSD_map.values()
print(df)
# Out:
#    PDB_ID   Status  Conformers  Ligands    Ions Apo_PDB_ID Holo_PDB_ID  \
# 0    2w72  Success           3  ['HEM']   ['K']       5vmm        2w72
# 1    6tn5  Success           1       []  ['CL']       5j80        6tn5
# 2    1x8q  Success           1  ['HEM']      []       2ofm        1x8q
# 3    1e7s  Success           1  ['NAP']      []       1gfs        1e7s
# 4    1xgk  Success           1       []   ['K']       1k6i        1xgk
# ..    ...      ...         ...      ...     ...        ...         ...
# 85   8crh  Success           1  ['NDP']      []       7zzx        8crh
# 86   5j4l  Success           1       []  ['CL']       6tuu        5j4l
# 87   8d0u  Success           1  ['GDP']      []       8d0p        8d0u
# 88   8u96  Success           1  ['ATP']  ['CL']       8sbn        8u96
# 89   9b20  Success           1       []  ['MG']       9b1z        9b20
#
#     APO_vs_HOLO  APO_vs_HOLO_ALPHA  APO_vs_APO_ALPHA  HOLO_vs_HOLO_ALPHA  \
# 0      3.785067           0.727004          0.635192            0.712308
# 1      0.257624           0.272277          0.421065            0.267859
# 2      0.263629           0.328048          0.352440            0.231631
# 3      0.264183           0.283356          0.247993            0.202855
# 4      0.177352           0.243486          0.229911            0.194335
# ..          ...                ...               ...                 ...
# 85     0.715299           0.806879          0.911738            0.376641
# 86     0.482130           0.367491          0.427612            0.467868
# 87     0.070176           0.671693          0.520820            0.626351
# 88     0.383124           3.387932          2.237975            3.308408
# 89     0.357913           0.410729          0.463587            0.317411
#
#     APO_ALPHA_vs_HOLO_ALPHA
# 0                  0.356937
# 1                  4.640476
# 2                  0.183481
# 3                  0.144231
# 4                  0.152927
# ..                      ...
# 85                 0.316142
# 86                 0.541948
# 87                 0.632332
# 88                 1.287520
# 89                 0.284479
#
# [90 rows x 12 columns]

# %%
df.to_csv('RMSD_results.csv', index=False)
